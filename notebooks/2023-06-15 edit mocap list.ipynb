# %% [markdown]
# # Title
# []()

# %%
import pandas as pd
import sys
sys.path.append(r"C:\Users\silvh\OneDrive\lighthouse\custom_python")
sys.path.append(r"C:\Users\silvh\OneDrive\lighthouse\Ginkgo coding\content-summarization\src")
from silvhua import *
from datetime import datetime
from Sheets_api import *
# sys.path.append(r"C:\Users\silvh\OneDrive\lighthouse\portfolio-projects\online-PT-social-media-NLP\src")
# import json
# from pandas import json_normalize  
# from plotly.subplots import make_subplots
# import requests

# %%
# set the option to wrap text within cells
pd.set_option('display.max_colwidth', 100)
pd.set_option('display.max_rows', 20)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# %%
from wrangling import filter_df_all_conditions, filter_df_any_condition

# %% [markdown]
# # Load original mocap list

# %%
mocap1 = pull_from_Sheet(
    sheet_name='exercises_for_mocap_formatted_2023-05-04_1229', sheet_key='mocap_202306',
    sheets_id_json='google_sheet_id.json'
    )
mocap1
# Out:
# token.json
# ...
# Complete: Data copied for exercises_for_mocap_formatted_2023-05-04_1229 in spreadsheet
# Number of rows: 401
# Creating dataframe from existing data list
#           Exercise_id                                           Exercise  \
# 0     768         421                       1.5 Rep Reverse Nordic Curls
# 1      82         439                                  Abdominal Bracing
# 2     622         443                  Adductor Side Plank - Short Lever
# 3     623         444  Adductor Side Plank Hip Tap with Isometric Kne...
# 4     624         445  Adductor Side Plank Hip Tap with Isometric Kne...
# ..    ...         ...                                                ...
# 395   668        1558                         Weighted Standing Rotation
# 396  1564                           Kneeling Weighted Chop with Rotation
# 397    56                      Calf Raise - Single Leg Bent Knee on book
# 398    47                                   Calf Raise - Balance Support
# ...

# %%
help(save_output)
# Out:
# Help on function save_output in module silvhua:
#
# save_output(df, filename=None, description=None, append_version=True, iteration_id=None, csv_path='C:\\Users\\silvh\\OneDrive\\lighthouse\\Ginkgo coding\\content-summarization\\output\\CSV', pickle_path='C:\\Users\\silvh\\OneDrive\\lighthouse\\Ginkgo coding\\content-summarization\\output\\pickles')
#     Save an Python object as both pickle and CSV. Automatically create filename using date and time
#     if not provided.

# %%
save_output(mocap1, description='mocap_list', pickle_path='../../exercise-library/outputs/')
# Out:
# File saved:  ../../exercise-library/outputs//mocap_list_2023-06-15_1228.sav
# Time completed: 2023-06-15 12:28:26.028761
# 	Object saved as pickle
# File saved:  C:/Users/silvh/OneDrive/lighthouse/Ginkgo coding/content-summarization/output/CSV/mocap_list_2023-06-15_1228.csv
# Time completed: 2023-06-15 12:28:26.044383
# 	DataFrame saved as CSV

# %% [markdown]
# # Filter

# %%
exclude = mocap1[mocap1['Exercise'].str.lower().str.contains('swing')]['Exercise'].tolist()
exclude += mocap1[mocap1['Exercise'].str.lower().str.contains('clean')]['Exercise'].tolist()
exclude
# Out:
# ['Single Arm Alternating Kettlebell Swing',
#  'Single Arm Kettlebell Swing',
#  'Sprinter Hip Flexion - Bodyweight with Reciprocal Arm Swing',
#  'Staggered Stance Alternating Kettlebell Swing',
#  'Staggered Stance Kettlebell Swing',
#  'Reverse Lunge with Two Arm Kettlebell Hang Clean, Alternating',
#  'Reverse Lunge with Two Arm Kettlebell Hang Clean, Alternating - Timed',
#  'Reverse Lunge with Two Arm Kettlebell Hang Clean, Unilateral',
#  'Reverse Lunge with Two Arm Kettlebell Hang Clean, Unilateral - Timed',
#  'Two Arm Kettlebell Clean',
#  'Two Arm Kettlebell Clean - Timed',
#  'Two Arm Kettlebell Clean from Box',
#  'Two Arm Kettlebell Clean from Box - Timed',
#  'Two Arm Kettlebell Clean from Box to Squat',
#  'Two Arm Kettlebell Clean from Box to Squat - Timed',
#  'Two Arm Kettlebell Clean to Squat',
#  'Two Arm Kettlebell Clean to Squat - Timed',
#  'Two Arm Kettlebell Hang Clean',
#  'Two Arm Kettlebell Hang Clean - Timed',
# ...

# %%
filters = {
    'Exercise': exclude
}
filter_df_any_condition(mocap1, filters)
# Out:
# Filtered on Exercise in ['single arm alternating kettlebell swing', 'single arm kettlebell swing', 'sprinter hip flexion - bodyweight with reciprocal arm swing', 'staggered stance alternating kettlebell swing', 'staggered stance kettlebell swing', 'reverse lunge with two arm kettlebell hang clean, alternating', 'reverse lunge with two arm kettlebell hang clean, alternating - timed', 'reverse lunge with two arm kettlebell hang clean, unilateral', 'reverse lunge with two arm kettlebell hang clean, unilateral - timed', 'two arm kettlebell clean', 'two arm kettlebell clean - timed', 'two arm kettlebell clean from box', 'two arm kettlebell clean from box - timed', 'two arm kettlebell clean from box to squat', 'two arm kettlebell clean from box to squat - timed', 'two arm kettlebell clean to squat', 'two arm kettlebell clean to squat - timed', 'two arm kettlebell hang clean', 'two arm kettlebell hang clean - timed', 'two arm kettlebell hang clean to squat', 'two arm kettlebell hang clean t
# ...

# %% [markdown]
# # *End of Page*
