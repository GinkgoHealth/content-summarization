# %% [markdown]
# # Title
# []()

# %%
import pandas as pd
import sys
sys.path.append(r"C:\Users\silvh\OneDrive\lighthouse\custom_python")
from silvhua import *
from datetime import datetime
# sys.path.append(r"C:\Users\silvh\OneDrive\lighthouse\portfolio-projects\online-PT-social-media-NLP\src")

# %%
# set the option to wrap text within cells
pd.set_option('display.max_colwidth', 100)
pd.set_option('display.max_rows', 20)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# %% [markdown]
# # From  previous notebook

# %%
import sys
sys.path.append(r"C:\Users\silvh\OneDrive\lighthouse\Ginkgo coding\content-summarization\src")

from db_session import *
from sqlalchemy.orm import declarative_base
from sqlalchemy import Column, ForeignKey, Integer, String, Text, text
from sqlalchemy.dialects.postgresql import UUID
import uuid
import pandas as pd
# from sqlalchemy.dialects.postgresql import insert
from sqlalchemy.orm import mapped_column
from sqlalchemy.orm import relationship


Base = declarative_base()

class Publications(Base):
    __tablename__ = 'publications'
    id = mapped_column(Integer, primary_key=True)
    # id = Column(Integer, primary_key=True, server_default='DEFAULT', autoincrement=True)
    name = mapped_column(String(100))
    # article_id = Column(Integer, ForeignKey('articles.id'))
    article_id = mapped_column(Integer)
    articles = relationship('Article', back_populates='publication', uselist=True)

class Article(Base):
    __tablename__ = 'articles'
    # id = Column(Integer, primary_key=True, server_default='DEFAULT', autoincrement=True)
    id = mapped_column(Integer, primary_key=True)
    title = mapped_column(String(255))
    # publication_id = Column(String(100))
    publication_id = mapped_column(String(100), ForeignKey('publications.id'))
    # text_body = Column(Text, nullable=True)
    # uuid = Column(UUID, nullable=True)
    publication = relationship('Publications', back_populates='articles')
    
class Summaries(Base):
    __tablename__ = 'initial_summaries'
    id = Column(Integer, primary_key=True)
    summary_body = Column(String(1000))
    article_uuid = Column(UUID)

@remote_sql_session
def get_table(session, query='SELECT *', table='publications'):
    """
    Return a database table as a pandas dataframe.
    """
    q = session.execute(text(f'{query} from {table}'))
    df = pd.DataFrame(q.fetchall())
    return df

def bulk_insert(new_rows, engine=None):
    @remote_sql_session
    def insert_rows(session):
        print('Rows inserted:')
        for row in new_rows:
            session.add(row)
            session.commit()
            # print([f"\t{row['name']}"])
            # print([f"\t{row}"])

    return insert_rows

# def bulk_append(article_list, Journal_inst, engine=None):
#     @remote_sql_session
#     def insert_rows(session):
#         session.add(Journal_inst)
#         session.flush()  # Obtain the generated primary key value
#         print(f'Publication ID: {Journal_inst.id}')
#         print('Rows inserted:')

#         for row in article_list:
#             article = Article(title=row, publication_id=Journal_inst.id)
#             # article = Article(title=row)
#             print('before add')
#             session.add(article)
#             print('this: ', Journal_inst.articles)
#             # session.commit()
#             # print([f"\t{row['name']}"])
#             print([f"\t{row}"])
#     return insert_rows

def bulk_append(article_list, Journal_inst, engine=None):
    @remote_sql_session
    def insert_rows(session):
        print('Rows inserted:')
        session.add(Journal_inst)
        session.flush()  # Obtain the generated primary key value
        print(f'Publication ID: {Journal_inst.id}')

        for row in article_list:
            print('this: ', Journal_inst.articles)
            Journal_inst.articles.append(row)
            session.add(Journal_inst)
            session.commit()
            # print([f"\t{row['name']}"])
            print([f"\t{row}"])
            print(row.publication_id)
    return insert_rows

# values = [
#     Publications(
#         name='Journal of Applied Physiology',
#         ),
# ]
Journal_inst = Publications(name='Physiology & Behavior')
journal_list = [Journal_inst]

article_list = [
    # Article(
    #     title='Weight stigma and health behaviors: evidence from the Eating in America Study',
    #     # publication_id=Journal_inst.id
    #     ),
    Article(
        title='Food craving, cortisol and ghrelin responses in modeling highly palatable snack intake in the laboratory',
        ),
    # 'Food craving, cortisol and ghrelin responses in modeling highly palatable snack intake in the laboratory'
]
# bulk_insert(journal_list)()

bulk_append(article_list, Journal_inst)()
get_table()

# # get_table(table='articles')
# Out:
# Rows inserted:
# Publication ID: 43
# this:  []
# ---------------------------------------------------------------------------
# ForeignKeyViolation                       Traceback (most recent call last)
# File c:\Users\silvh\.conda\envs\ginkgo\Lib\site-packages\sqlalchemy\engine\base.py:1965, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1964     if not evt_handled:
# -> 1965         self.dialect.do_execute(
#    1966             cursor, str_statement, effective_parameters, context
#    1967         )
#    1969 if self._has_events or self.engine._has_events:
#
# File c:\Users\silvh\.conda\envs\ginkgo\Lib\site-packages\sqlalchemy\engine\default.py:921, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     920 def do_execute(self, cursor, statement, parameters, context=None):
# --> 921     cursor.execute(statement, parameters)
#
# ForeignKeyViolation: insert or update on table "articles" violates foreign key constraint "articles_fk"
# DETAIL:  Key (id)=(29) is not present in table "publications".
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# Cell In[2], line 121
#     109 article_list = [
#     110     # Article(
#     111     #     title='Weight stigma and health behaviors: evidence from the Eating in America Study',
#    (...)
#     117     # 'Food craving, cortisol and ghrelin responses in modeling highly palatable snack intake in the laboratory'
#     118 ]
#     119 # bulk_insert(journal_list)()
# --> 121 bulk_append(article_list, Journal_inst)()
#     122 get_table()
#     124 # # get_table(table='articles')
#
# File ~\OneDrive\lighthouse\Ginkgo coding\content-summarization\src\db_session.py:57, in remote_sql_session.<locals>.wrapper(*args, **kwargs)
#      55 @wraps(function)
#      56 def wrapper(*args, **kwargs):
# ---> 57     return with_remote_sql_session(function, *args, **kwargs)
#
# File ~\OneDrive\lighthouse\Ginkgo coding\content-summarization\src\db_session.py:45, in with_remote_sql_session(function, *args, **kwargs)
#      43 tunnel.start()
#      44 engine = get_engine_for_port(tunnel.local_bind_port)
# ---> 45 return with_sql_session(function, args, kwargs, engine=engine)
#
# File ~\OneDrive\lighthouse\Ginkgo coding\content-summarization\src\db_session.py:27, in with_sql_session(function, args, kwargs, engine)
#      25 session = Session()
#      26 try:
# ---> 27     return function(session, *args, **kwargs)
#      28 finally:
#      29     session.close()
#
# Cell In[2], line 95, in bulk_append.<locals>.insert_rows(session)
#      93 Journal_inst.articles.append(row)
#      94 session.add(Journal_inst)
# ---> 95 session.commit()
#      96 # print([f"\t{row['name']}"])
#      97 print([f"\t{row}"])
#
# File c:\Users\silvh\.conda\envs\ginkgo\Lib\site-packages\sqlalchemy\orm\session.py:1920, in Session.commit(self)
#    1917 if trans is None:
#    1918     trans = self._autobegin_t()
# -> 1920 trans.commit(_to_root=True)
#
# File <string>:2, in commit(self, _to_root)
#
# File c:\Users\silvh\.conda\envs\ginkgo\Lib\site-packages\sqlalchemy\orm\state_changes.py:139, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#     137 self._next_state = _StateChangeStates.CHANGE_IN_PROGRESS
#     138 try:
# --> 139     ret_value = fn(self, *arg, **kw)
#     140 except:
#     141     raise
#
# File c:\Users\silvh\.conda\envs\ginkgo\Lib\site-packages\sqlalchemy\orm\session.py:1236, in SessionTransaction.commit(self, _to_root)
#    1234 if self._state is not SessionTransactionState.PREPARED:
#    1235     with self._expect_state(SessionTransactionState.PREPARED):
# -> 1236         self._prepare_impl()
#    1238 if self._parent is None or self.nested:
#    1239     for conn, trans, should_commit, autoclose in set(
#    1240         self._connections.values()
#    1241     ):
#
# File <string>:2, in _prepare_impl(self)
#
# File c:\Users\silvh\.conda\envs\ginkgo\Lib\site-packages\sqlalchemy\orm\state_changes.py:139, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#     137 self._next_state = _StateChangeStates.CHANGE_IN_PROGRESS
#     138 try:
# --> 139     ret_value = fn(self, *arg, **kw)
#     140 except:
#     141     raise
#
# File c:\Users\silvh\.conda\envs\ginkgo\Lib\site-packages\sqlalchemy\orm\session.py:1211, in SessionTransaction._prepare_impl(self)
#    1209     if self.session._is_clean():
#    1210         break
# -> 1211     self.session.flush()
#    1212 else:
#    1213     raise exc.FlushError(
#    1214         "Over 100 subsequent flushes have occurred within "
#    1215         "session.commit() - is an after_flush() hook "
#    1216         "creating new objects?"
#    1217     )
#
# File c:\Users\silvh\.conda\envs\ginkgo\Lib\site-packages\sqlalchemy\orm\session.py:4163, in Session.flush(self, objects)
#    4161 try:
#    4162     self._flushing = True
# -> 4163     self._flush(objects)
#    4164 finally:
#    4165     self._flushing = False
#
# File c:\Users\silvh\.conda\envs\ginkgo\Lib\site-packages\sqlalchemy\orm\session.py:4298, in Session._flush(self, objects)
#    4295     transaction.commit()
#    4297 except:
# -> 4298     with util.safe_reraise():
#    4299         transaction.rollback(_capture_exception=True)
#
# File c:\Users\silvh\.conda\envs\ginkgo\Lib\site-packages\sqlalchemy\util\langhelpers.py:147, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     assert exc_value is not None
#     146     self._exc_info = None  # remove potential circular references
# --> 147     raise exc_value.with_traceback(exc_tb)
#     148 else:
#     149     self._exc_info = None  # remove potential circular references
#
# File c:\Users\silvh\.conda\envs\ginkgo\Lib\site-packages\sqlalchemy\orm\session.py:4259, in Session._flush(self, objects)
#    4257 self._warn_on_events = True
#    4258 try:
# -> 4259     flush_context.execute()
#    4260 finally:
#    4261     self._warn_on_events = False
#
# File c:\Users\silvh\.conda\envs\ginkgo\Lib\site-packages\sqlalchemy\orm\unitofwork.py:466, in UOWTransaction.execute(self)
#     464 else:
#     465     for rec in topological.sort(self.dependencies, postsort_actions):
# --> 466         rec.execute(self)
#
# File c:\Users\silvh\.conda\envs\ginkgo\Lib\site-packages\sqlalchemy\orm\unitofwork.py:642, in SaveUpdateAll.execute(self, uow)
#     640 @util.preload_module("sqlalchemy.orm.persistence")
#     641 def execute(self, uow):
# --> 642     util.preloaded.orm_persistence.save_obj(
#     643         self.mapper,
#     644         uow.states_for_mapper_hierarchy(self.mapper, False, False),
#     645         uow,
#     646     )
#
# File c:\Users\silvh\.conda\envs\ginkgo\Lib\site-packages\sqlalchemy\orm\persistence.py:93, in save_obj(base_mapper, states, uowtransaction, single)
#      81     update = _collect_update_commands(
#      82         uowtransaction, table, states_to_update
#      83     )
#      85     _emit_update_statements(
#      86         base_mapper,
#      87         uowtransaction,
#    (...)
#      90         update,
#      91     )
# ---> 93     _emit_insert_statements(
#      94         base_mapper,
#      95         uowtransaction,
#      96         mapper,
#      97         table,
#      98         insert,
#      99     )
#     101 _finalize_insert_update_commands(
#     102     base_mapper,
#     103     uowtransaction,
#    (...)
#     119     ),
#     120 )
#
# File c:\Users\silvh\.conda\envs\ginkgo\Lib\site-packages\sqlalchemy\orm\persistence.py:1226, in _emit_insert_statements(base_mapper, uowtransaction, mapper, table, insert, bookkeeping, use_orm_insert_stmt, execution_options)
#    1220     result = connection.execute(
#    1221         statement.values(value_params),
#    1222         params,
#    1223         execution_options=execution_options,
#    1224     )
#    1225 else:
# -> 1226     result = connection.execute(
#    1227         statement,
#    1228         params,
#    1229         execution_options=execution_options,
#    1230     )
#    1232 primary_key = result.inserted_primary_key
#    1233 if primary_key is None:
#
# File c:\Users\silvh\.conda\envs\ginkgo\Lib\site-packages\sqlalchemy\engine\base.py:1412, in Connection.execute(self, statement, parameters, execution_options)
#    1410     raise exc.ObjectNotExecutableError(statement) from err
#    1411 else:
# -> 1412     return meth(
#    1413         self,
#    1414         distilled_parameters,
#    1415         execution_options or NO_OPTIONS,
#    1416     )
#
# File c:\Users\silvh\.conda\envs\ginkgo\Lib\site-packages\sqlalchemy\sql\elements.py:483, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     481     if TYPE_CHECKING:
#     482         assert isinstance(self, Executable)
# --> 483     return connection._execute_clauseelement(
#     484         self, distilled_params, execution_options
#     485     )
#     486 else:
#     487     raise exc.ObjectNotExecutableError(self)
#
# File c:\Users\silvh\.conda\envs\ginkgo\Lib\site-packages\sqlalchemy\engine\base.py:1635, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1623 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1624     "compiled_cache", self.engine._compiled_cache
#    1625 )
#    1627 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1628     dialect=dialect,
#    1629     compiled_cache=compiled_cache,
#    (...)
#    1633     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1634 )
# -> 1635 ret = self._execute_context(
#    1636     dialect,
#    1637     dialect.execution_ctx_cls._init_compiled,
#    1638     compiled_sql,
#    1639     distilled_parameters,
#    1640     execution_options,
#    1641     compiled_sql,
#    1642     distilled_parameters,
#    1643     elem,
#    1644     extracted_params,
#    1645     cache_hit=cache_hit,
#    1646 )
#    1647 if has_events:
#    1648     self.dispatch.after_execute(
#    1649         self,
#    1650         elem,
#    (...)
#    1654         ret,
#    1655     )
#
# File c:\Users\silvh\.conda\envs\ginkgo\Lib\site-packages\sqlalchemy\engine\base.py:1844, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1839     return self._exec_insertmany_context(
#    1840         dialect,
#    1841         context,
#    1842     )
#    1843 else:
# -> 1844     return self._exec_single_context(
#    1845         dialect, context, statement, parameters
#    1846     )
#
# File c:\Users\silvh\.conda\envs\ginkgo\Lib\site-packages\sqlalchemy\engine\base.py:1984, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1981     result = context._setup_result_proxy()
#    1983 except BaseException as e:
# -> 1984     self._handle_dbapi_exception(
#    1985         e, str_statement, effective_parameters, cursor, context
#    1986     )
#    1988 return result
#
# File c:\Users\silvh\.conda\envs\ginkgo\Lib\site-packages\sqlalchemy\engine\base.py:2339, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2337 elif should_wrap:
#    2338     assert sqlalchemy_exception is not None
# -> 2339     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2340 else:
#    2341     assert exc_info[1] is not None
#
# File c:\Users\silvh\.conda\envs\ginkgo\Lib\site-packages\sqlalchemy\engine\base.py:1965, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1963                 break
#    1964     if not evt_handled:
# -> 1965         self.dialect.do_execute(
#    1966             cursor, str_statement, effective_parameters, context
#    1967         )
#    1969 if self._has_events or self.engine._has_events:
#    1970     self.dispatch.after_cursor_execute(
#    1971         self,
#    1972         cursor,
#    (...)
#    1976         context.executemany,
#    1977     )
#
# File c:\Users\silvh\.conda\envs\ginkgo\Lib\site-packages\sqlalchemy\engine\default.py:921, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     920 def do_execute(self, cursor, statement, parameters, context=None):
# --> 921     cursor.execute(statement, parameters)
#
# IntegrityError: (psycopg2.errors.ForeignKeyViolation) insert or update on table "articles" violates foreign key constraint "articles_fk"
# DETAIL:  Key (id)=(29) is not present in table "publications".
#
# [SQL: INSERT INTO articles (title, publication_id) VALUES (%(title)s, %(publication_id)s) RETURNING articles.id]
# [parameters: {'title': 'Food craving, cortisol and ghrelin responses in modeling highly palatable snack intake in the laboratory', 'publication_id': 43}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %% [markdown]
# # 1

# %%
import sys
sys.path.append(r"C:\Users\silvh\OneDrive\lighthouse\Ginkgo coding\content-summarization\src")

from db_session import *
from sqlalchemy.orm import declarative_base
from sqlalchemy import Column, ForeignKey, Integer, String, Text, text
from sqlalchemy.dialects.postgresql import UUID
import uuid
import pandas as pd
# from sqlalchemy.dialects.postgresql import insert
from sqlalchemy.orm import mapped_column
from sqlalchemy.orm import relationship


Base = declarative_base()

class Publications(Base):
    __tablename__ = 'publications'
    id = Column(Integer, primary_key=True, autoincrement=True)
    # id = mapped_column(Integer, primary_key=True)
    # id = Column(Integer, primary_key=True, server_default='DEFAULT', autoincrement=True)
    name = mapped_column(String(100))
    # article_id = Column(Integer, ForeignKey('articles.id'))
    article_id = mapped_column(Integer)
    articles = relationship('Article', back_populates='publication', uselist=True)

class Article(Base):
    __tablename__ = 'articles'
    # id = Column(Integer, primary_key=True, server_default='DEFAULT', autoincrement=True)
    id = mapped_column(Integer, primary_key=True)
    title = mapped_column(String(255))
    # publication_id = Column(String(100))
    publication_id = mapped_column(String(100), ForeignKey('publications.id'))
    # text_body = Column(Text, nullable=True)
    # uuid = Column(UUID, nullable=True)
    publication = relationship('Publications', back_populates='articles')
    
class Summaries(Base):
    __tablename__ = 'initial_summaries'
    id = Column(Integer, primary_key=True)
    summary_body = Column(String(1000))
    article_uuid = Column(UUID)

@remote_sql_session
def get_table(session, query='SELECT *', table='publications'):
    """
    Return a database table as a pandas dataframe.
    """
    q = session.execute(text(f'{query} from {table}'))
    df = pd.DataFrame(q.fetchall())
    return df

def bulk_insert(new_rows, engine=None):
    @remote_sql_session
    def insert_rows(session):
        print('Rows inserted:')
        for row in new_rows:
            session.add(row)
            session.commit()
            # print([f"\t{row['name']}"])
            # print([f"\t{row}"])

    return insert_rows

# def bulk_append(article_list, Journal_inst, engine=None):
#     @remote_sql_session
#     def insert_rows(session):
#         session.add(Journal_inst)
#         session.flush()  # Obtain the generated primary key value
#         print(f'Publication ID: {Journal_inst.id}')
#         print('Rows inserted:')

#         for row in article_list:
#             article = Article(title=row, publication_id=Journal_inst.id)
#             # article = Article(title=row)
#             print('before add')
#             session.add(article)
#             print('this: ', Journal_inst.articles)
#             # session.commit()
#             # print([f"\t{row['name']}"])
#             print([f"\t{row}"])
#     return insert_rows

def bulk_append(article_list, Journal_inst, engine=None):
    @remote_sql_session
    def insert_rows(session):
        try:
            print('Rows inserted:')
            session.add(Journal_inst)
            session.flush()  # Obtain the generated primary key value
            print(f'Publication ID: {Journal_inst.id}')

            for row in article_list:
                print('this: ', Journal_inst.articles)
                Journal_inst.articles.append(row)
                session.add(Journal_inst)
                session.commit()
                # print([f"\t{row['name']}"])
                print([f"\t{row}"])
                print(row.publication_id)
        except Exception as error:
            exc_type, exc_obj, tb = sys.exc_info()
            f = tb.tb_frame
            lineno = tb.tb_lineno
            filename = f.f_code.co_filename
            print("An error occurred on line", lineno, "in", filename, ":", error)
            session.close()
    return insert_rows

# values = [
#     Publications(
#         name='Journal of Applied Physiology',
#         ),
# ]
Journal_inst = Publications(name='Physiology & Behavior')
journal_list = [Journal_inst]

article_list = [
    # Article(
    #     title='Weight stigma and health behaviors: evidence from the Eating in America Study',
    #     # publication_id=Journal_inst.id
    #     ),
    Article(
        title='Food craving, cortisol and ghrelin responses in modeling highly palatable snack intake in the laboratory',
        ),
    # 'Food craving, cortisol and ghrelin responses in modeling highly palatable snack intake in the laboratory'
]
# bulk_insert(journal_list)()

bulk_append(article_list, Journal_inst)()
get_table()

# # get_table(table='articles')
# Out:
# Rows inserted:
# Publication ID: 51
# this:  []
# An error occurred on line 97 in C:\Users\silvh\AppData\Local\Temp\ipykernel_25096\4277501404.py : (psycopg2.errors.ForeignKeyViolation) insert or update on table "articles" violates foreign key constraint "articles_fk"
# DETAIL:  Key (id)=(36) is not present in table "publications".
#
# [SQL: INSERT INTO articles (title, publication_id) VALUES (%(title)s, %(publication_id)s) RETURNING articles.id]
# [parameters: {'title': 'Food craving, cortisol and ghrelin responses in modeling highly palatable snack intake in the laboratory', 'publication_id': 51}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
#    id                           name article_id
# 0   1                  PLOS Medicine       None
# 1   2                       PLOS One       None
# 2   3  Journal of Applied Physiology       None

# %% [markdown]
# ## 1.1

# %%
import sys
sys.path.append(r"C:\Users\silvh\OneDrive\lighthouse\Ginkgo coding\content-summarization\src")

from db_session import *
from sqlalchemy.orm import declarative_base
from sqlalchemy import Column, ForeignKey, Integer, String, Text, text
from sqlalchemy.dialects.postgresql import UUID
import uuid
import pandas as pd
# from sqlalchemy.dialects.postgresql import insert
from sqlalchemy.orm import mapped_column
from sqlalchemy.orm import relationship


Base = declarative_base()

class Publications(Base):
    __tablename__ = 'publications'
    id = Column(Integer, primary_key=True, server_default='DEFAULT', autoincrement=True)
    # id = Column(Integer, primary_key=True, autoincrement=True)
    # id = mapped_column(Integer, primary_key=True)
    # id = Column(Integer, primary_key=True, server_default='DEFAULT', autoincrement=True)
    name = mapped_column(String(100))
    # article_id = Column(Integer, ForeignKey('articles.id'))
    article_id = mapped_column(Integer, autoincrement=False)
    articles = relationship('Article', back_populates='publication', uselist=True)

class Article(Base):
    __tablename__ = 'articles'
    # id = Column(Integer, primary_key=True, autoincrement=False)
    # id = Column(Integer, primary_key=True, server_default='DEFAULT', autoincrement=True)
    id = mapped_column(Integer, primary_key=True)
    title = mapped_column(String(255))
    # publication_id = Column(String(100))
    publication_id = mapped_column(String(100), ForeignKey('publications.id'), autoincrement=False)
    # text_body = Column(Text, nullable=True)
    # uuid = Column(UUID, nullable=True)
    publication = relationship('Publications', back_populates='articles')
    
class Summaries(Base):
    __tablename__ = 'initial_summaries'
    id = Column(Integer, primary_key=True)
    summary_body = Column(String(1000))
    article_uuid = Column(UUID)

@remote_sql_session
def get_table(session, query='SELECT *', table='publications'):
    """
    Return a database table as a pandas dataframe.
    """
    q = session.execute(text(f'{query} from {table}'))
    df = pd.DataFrame(q.fetchall())
    return df

def bulk_insert(new_rows, engine=None):
    @remote_sql_session
    def insert_rows(session):
        print('Rows inserted:')
        for row in new_rows:
            session.add(row)
            session.commit()
            # print([f"\t{row['name']}"])
            # print([f"\t{row}"])

    return insert_rows

# def bulk_append(article_list, Journal_inst, engine=None):
#     @remote_sql_session
#     def insert_rows(session):
#         session.add(Journal_inst)
#         session.flush()  # Obtain the generated primary key value
#         print(f'Publication ID: {Journal_inst.id}')
#         print('Rows inserted:')

#         for row in article_list:
#             article = Article(title=row, publication_id=Journal_inst.id)
#             # article = Article(title=row)
#             print('before add')
#             session.add(article)
#             print('this: ', Journal_inst.articles)
#             # session.commit()
#             # print([f"\t{row['name']}"])
#             print([f"\t{row}"])
#     return insert_rows

def bulk_append(article_list, Journal_inst, engine=None):
    @remote_sql_session
    def insert_rows(session):
        try:
            print('Rows inserted:')
            session.add(Journal_inst)
            session.flush()  # Obtain the generated primary key value
            print(f'Publication ID: {Journal_inst.id}')

            for row in article_list:
                print('this: ', Journal_inst.articles)
                Journal_inst.articles.append(row)
                session.add(Journal_inst)
                session.commit()
                # print([f"\t{row['name']}"])
                print([f"\t{row}"])
                print(row.publication_id)
        except Exception as error:
            exc_type, exc_obj, tb = sys.exc_info()
            f = tb.tb_frame
            lineno = tb.tb_lineno
            filename = f.f_code.co_filename
            print("An error occurred on line", lineno, "in", filename, ":", error)
            session.close()
    return insert_rows

# values = [
#     Publications(
#         name='Journal of Applied Physiology',
#         ),
# ]
Journal_inst = Publications(name='Physiology & Behavior')
journal_list = [Journal_inst]

article_list = [
    # Article(
    #     title='Weight stigma and health behaviors: evidence from the Eating in America Study',
    #     # publication_id=Journal_inst.id
    #     ),
    Article(
        title='Food craving, cortisol and ghrelin responses in modeling highly palatable snack intake in the laboratory',
        ),
    # 'Food craving, cortisol and ghrelin responses in modeling highly palatable snack intake in the laboratory'
]
# bulk_insert(journal_list)()

bulk_append(article_list, Journal_inst)()
get_table()

# # get_table(table='articles')
# Out:
# Rows inserted:
# Publication ID: 58
# this:  []
# An error occurred on line 99 in C:\Users\silvh\AppData\Local\Temp\ipykernel_12824\444490820.py : (psycopg2.errors.ForeignKeyViolation) insert or update on table "articles" violates foreign key constraint "articles_fk"
# DETAIL:  Key (id)=(43) is not present in table "publications".
#
# [SQL: INSERT INTO articles (title, publication_id) VALUES (%(title)s, %(publication_id)s) RETURNING articles.id]
# [parameters: {'title': 'Food craving, cortisol and ghrelin responses in modeling highly palatable snack intake in the laboratory', 'publication_id': 58}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
#    id                           name article_id
# 0   1                  PLOS Medicine       None
# 1   2                       PLOS One       None
# 2   3  Journal of Applied Physiology       None

# %% [markdown]
# ## 1.12

# %%
import sys
sys.path.append(r"C:\Users\silvh\OneDrive\lighthouse\Ginkgo coding\content-summarization\src")

from db_session import *
from sqlalchemy.orm import declarative_base
from sqlalchemy import Column, ForeignKey, Integer, String, Text, text
from sqlalchemy.dialects.postgresql import UUID
import uuid
import pandas as pd
# from sqlalchemy.dialects.postgresql import insert
from sqlalchemy.orm import mapped_column
from sqlalchemy.orm import relationship


Base = declarative_base()

class Publications(Base):
    __tablename__ = 'publications'
    id = Column(Integer, primary_key=True, server_default='DEFAULT', autoincrement=True)
    # id = Column(Integer, primary_key=True, autoincrement=True)
    # id = mapped_column(Integer, primary_key=True)
    # id = Column(Integer, primary_key=True, server_default='DEFAULT', autoincrement=True)
    name = mapped_column(String(100))
    # article_id = Column(Integer, ForeignKey('articles.id'))
    article_id = mapped_column(Integer, autoincrement=False)
    articles = relationship('Article', back_populates='publication', uselist=True)

class Article(Base):
    __tablename__ = 'articles'
    # id = Column(Integer, primary_key=True, autoincrement=False)
    # id = Column(Integer, primary_key=True, server_default='DEFAULT', autoincrement=True)
    id = mapped_column(Integer, primary_key=True)
    title = mapped_column(String(255))
    # publication_id = Column(String(100))
    publication_id = mapped_column(String(100), ForeignKey('publications.id'), autoincrement=False)
    # text_body = Column(Text, nullable=True)
    # uuid = Column(UUID, nullable=True)
    publication = relationship('Publications', back_populates='articles')
    
class Summaries(Base):
    __tablename__ = 'initial_summaries'
    id = Column(Integer, primary_key=True)
    summary_body = Column(String(1000))
    article_uuid = Column(UUID)

@remote_sql_session
def get_table(session, query='SELECT *', table='publications'):
    """
    Return a database table as a pandas dataframe.
    """
    q = session.execute(text(f'{query} from {table}'))
    df = pd.DataFrame(q.fetchall())
    return df

def bulk_insert(new_rows, engine=None):
    @remote_sql_session
    def insert_rows(session):
        print('Rows inserted:')
        for row in new_rows:
            session.add(row)
            session.commit()
            # print([f"\t{row['name']}"])
            # print([f"\t{row}"])

    return insert_rows

def bulk_append(article_list, Journal_inst, engine=None):
    @remote_sql_session
    def insert_rows(session):
        try:
            session.add(Journal_inst)
            session.flush()  # Obtain the generated primary key value
            print(f'Publication ID: {Journal_inst.id}')
            print('Rows inserted:')

            for row in article_list:
                # article = Article(title=row, publication_id=Journal_inst.id)
                # # article = Article(title=row)
                # print('before add')
                # session.add(article)
                session.add(Article(title=row, publication_id=Journal_inst.id))
                print('this: ', Journal_inst.articles)
                # session.commit()
                # print([f"\t{row['name']}"])
                print([f"\t{row}"])
        except Exception as error:
            exc_type, exc_obj, tb = sys.exc_info()
            f = tb.tb_frame
            lineno = tb.tb_lineno
            filename = f.f_code.co_filename
            print("An error occurred on line", lineno, "in", filename, ":", error)
            session.close()
    return insert_rows

# def bulk_append(article_list, Journal_inst, engine=None):
#     @remote_sql_session
#     def insert_rows(session):
#         try:
#             print('Rows inserted:')
#             session.add(Journal_inst)
#             session.flush()  # Obtain the generated primary key value
#             print(f'Publication ID: {Journal_inst.id}')

#             for row in article_list:
#                 print('this: ', Journal_inst.articles)
#                 Journal_inst.articles.append(row)
#                 session.add(Journal_inst)
#                 session.commit()
#                 # print([f"\t{row['name']}"])
#                 print([f"\t{row}"])
#                 print(row.publication_id)
#         except Exception as error:
#             exc_type, exc_obj, tb = sys.exc_info()
#             f = tb.tb_frame
#             lineno = tb.tb_lineno
#             filename = f.f_code.co_filename
#             print("An error occurred on line", lineno, "in", filename, ":", error)
#             session.close()
#     return insert_rows

# values = [
#     Publications(
#         name='Journal of Applied Physiology',
#         ),
# ]
Journal_inst = Publications(name='Physiology & Behavior')
journal_list = [Journal_inst]

article_list = [
    # Article(
    #     title='Weight stigma and health behaviors: evidence from the Eating in America Study',
    #     # publication_id=Journal_inst.id
    #     ),
    # Article(
    #     title='Food craving, cortisol and ghrelin responses in modeling highly palatable snack intake in the laboratory',
    #     ),
    'Food craving, cortisol and ghrelin responses in modeling highly palatable snack intake in the laboratory'
]
# bulk_insert(journal_list)()

bulk_append(article_list, Journal_inst)()
get_table()

# # get_table(table='articles')
# Out:
# Publication ID: 61
# Rows inserted:
# An error occurred on line 82 in C:\Users\silvh\AppData\Local\Temp\ipykernel_29600\4157670741.py : (raised as a result of Query-invoked autoflush; consider using a session.no_autoflush block if this flush is occurring prematurely)
# (psycopg2.errors.ForeignKeyViolation) insert or update on table "articles" violates foreign key constraint "articles_fk"
# DETAIL:  Key (id)=(45) is not present in table "publications".
#
# [SQL: INSERT INTO articles (title, publication_id) VALUES (%(title)s, %(publication_id)s) RETURNING articles.id]
# [parameters: {'title': 'Food craving, cortisol and ghrelin responses in modeling highly palatable snack intake in the laboratory', 'publication_id': 61}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
#    id                           name article_id
# 0   1                  PLOS Medicine       None
# 1   2                       PLOS One       None
# 2   3  Journal of Applied Physiology       None
# 3  59          Physiology & Behavior       None

# %%
print(Article(
        title='Food craving, cortisol and ghrelin responses in modeling highly palatable snack intake in the laboratory',
        publication_id = 1
        ).publication_id)
print(Article(
        title='Food craving, cortisol and ghrelin responses in modeling highly palatable snack intake in the laboratory',
        ).title)
# Out:
# 1
# Food craving, cortisol and ghrelin responses in modeling highly palatable snack intake in the laboratory

# %% [markdown]
# # Update `with_sql_session` function to Keep session open

# %% [markdown]
# # *End of Page*
