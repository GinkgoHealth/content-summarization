# %% [markdown]
# # Title
# []()

# %%
from pandas import json_normalize  
import pandas as pd
import sys
sys.path.append(r"C:\Users\silvh\OneDrive\lighthouse\custom_python")
sys.path.append(r"C:\Users\silvh\OneDrive\lighthouse\portfolio-projects\online-PT-social-media-NLP\src")
from silvhua import *
from datetime import datetime
# import json
# from plotly.subplots import make_subplots
# import requests

# %%
# set the option to wrap text within cells
pd.set_option('display.max_colwidth', None)
# pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# %%
# from pypdf import PdfReader
import pandas as pd
import openai
import os
# from openai.embeddings_utils import get_embedding, cosine_similarity
import re

# %%
sys.path.append(r"C:\Users\silvh\OneDrive\lighthouse\Ginkgo coding\content-summarization\src")
from summarization import Chatbot, reply, batch_reply
from article_processing import create_text_dict

# %% [markdown]
# # Create text_dict

# %%
text1 = """The Impact of Sleep Duration on Performance Among Competitive Athletes: A Systematic Literature Review

DISCUSSION 
This literature review, although diverse in the range of sports, methods, and outcomes studied, provides several stylized facts that can inform sleep research and competitive athletes. First, out of all the published studies we reviewed, none found a negative association between sleep duration and any performance outcome. All of the results reviewed showed that either the increased sleep duration has a positive effect on athletic performance or the results were neutral. Note that among studies reporting significant positive results, effect sizes varied considerably (Tables 2-4), likely due to differences in the duration of sleep deprivation/extension experienced as well as differences in outcome measures. Second, when considering the aerobic and anaerobic characteristics of sports, it seems that aerobic activity is more sensitive to sleep duration compared to anaerobic activity, including strength testing. For instance, Mejri et al40 found that depriving competitive taekwondo boxers of a mere 3 to 4 hours of sleep significantly impaired performance on the Yo-Yo intermittent recovery test. By contrast, Blumert et al33 employed a relatively severe sleep deprivation protocol by depriving 9 national-caliber collegiate weightlifters of 24 hours of sleep and yet failed to identify adverse effects on any of the various weightlifting exercises examined. Relatedly, for both endurance and explosive, power-based exercises, it has been well documented that sleep deprivation is associated with increased perceived effort.56–58 Still, the relationship between perceived effort and objective performance has not been widely validated and is a topic for future investigation. Third, of the studies that measured outcomes requiring either tactical and/or technical skills, most find benefits of sleep on performance. Tennis serving accuracy and basketball shooting were both improved by long-term sleep extension interventions,35,39 and tennis serving accuracy suffered when players were deprived of 2 to 2.5 hours of sleep at the beginning of the preceding night.37 Regarding studies conducted in players of team sports that incorporated tactics and decision-based outcomes to a broader extent, soccer as well as rugby players exhibited performance deficits after nights of decreased sleep duration.34 These results are in line with other literature demonstrating clear neurocognitive deficits in the setting of inadequate sleep in the general population, reviewed thoroughly elsewhere.59,60 Finally, when looking at the methodologies of the experimental studies, we found that the studies that altered sleep duration on a longer-term timescale were more likely to show an effect than those that altered sleep duration acutely. Interestingly although most acute sleep interventions involved sleep deprivation and yielded positive results, there were inconsistent results among the 2 acute sleep extension studies.15,38 Conversely, the majority of longer-term sleep intervention studies involved sleep extension and showed positive results.35,39,49 Taken together, these findings suggest that on a short timescale, sleep deprivation may be more harmful than sleep extension is beneficial to performance, although in the longer term, sleep extension may contribute to improved performance. On the other hand, more research is warranted regarding potential adverse effects of chronic sleep loss on athletic performance. The reliability and precision of the various measurements may present challenges in interpretation of these studies. For example, “maximal” voluntary muscle contraction and voluntarily chosen training load are variable across subjects.61,62 On the other hand, “running economy,” the oxygen cost associated with a given running velocity, has low variability among highly trained runners and is significantly correlated with cardiorespiratory parameters used to assess aerobic capacity.63 A meta-analysis of the reliability of various measures of muscle power previously identified that field running tests tended to be more reliable than treadmill running tests, tests lasting up to 1 minute tended to be more reliable than those lasting greater than 1 minute (likely due to increased variability in muscle movement and limb positioning), and isokinetic tests tended to be more reliable when measuring muscle extension versus flexion.62 Somewhat reassuringly in the context of the present review, this metaanalysis also found that measurements taken from athletes were more reliable than those taken from non-athlete subjects. With respect to the validity of outcome measures reported as performance indicators, the nature of the sport (eg, team vs individual) may be an important determinant of whether what is measured in the laboratory translates to the actual game. For instance, for team-based sports requiring complex game structure such as soccer, measures of muscle force production or running speed are likely insufficient to provide an accurate assessment of in-game performance, although they may be helpful in making gross approximations and predictions.64 Of course, actual performance metrics from real or simulated games would be the ideal outcomes to quantify for such sports in future investigations. More specifically, for performance outcomes included in the current review, the following have been independently validated and shown to be reliable measures of athletic performance: Yo-Yo intermittent recovery (YYIR) test, isometric muscle contraction, squat, countermovement jump, free sthrow basketball shooting, tennis serving, shuttle-running tests, and Wingate test.42–48 In Table 1, we have indicated studies employing previously validated and reliable metrics of objective performance with asterisks (as per the criteria discussed above). Still, more work will be required to further validate the various performance outcomes measured in the studies reviewed in the present work, especially those involving complex, team-based measures such as composite game performance scores and passing accuracy. Likewise, given the high inter-individual variability of sleep variables used across the included studies, these metrics will also require further investigation to determine their precision and reliability as predictors of athletic performance. Importantly, we chose to require at least one objective performance measure among our inclusion criteria. The previous work relying on self-perceived performance, although informative in understanding the potential effect of sleep loss or gain on sports psychology,15 may not accurately reflect actual performance, as was the goal of the present work. However, under certain circumstances, self-perceived pre-game wellness (including self-reported sleep quality) may be predictive of objective in-game performance.65 More research will be needed to assess the validity of playerreported performance and objective performance, especially when athletes exhibit compromised sleep. Several experimental studies are particularly illustrative of the various trends in the results we have just outlined. To address the question of whether one night of sleep extension would be sufficient to improve various fitness indices among semi-professional soccer players, Fullagar et al15 tested a sleep hygiene intervention. The investigators implemented a sleep hygiene strategy (SHS) designed to maximize sleep duration and limit stimulation before bedtime to test whether this would be sufficient to improve either anaerobic (jumping height and force production) or aerobic endurance (Yo–Yo intermittent recovery level 2, YYIR2) performance after latenight soccer matches. Implementing a randomized design, they assigned 20 participants to follow either their normal post-match sleep routine [non-SHS (NSHS)] or a SHS involving early dimming of lights and lights out by midnight, cool room temperature, and no technology or light stimulation for 15 to 30 minutes before bedtime. Actigraphy was used to measure sleep patterns, and sleep diary was used for subjective recall of sleep quality. Despite finding that those assigned to the SHS indeed exhibited increased sleep duration after the night match relative to those in the NSHS group, the investigators failed to identify any improvements in countermovement jump height, countermovement jump force production, or YYIR2 performance, tested over the following 2 days. On the other hand, as we have discussed, studies of acute sleep deprivation, especially those measuring technical performance outcomes, tended to yield positive results. Given that sleep is often disrupted the night before athletic competition,66 athletes involved in sports requiring these types of skills are likely to be particularly sensitive to sleep manipulations and thus should be counseled regarding the importance of sleep for game performance. Relatedly, chronic sleep extension studies have demonstrated significant benefits to athletes.35,49 Thus, strategies to improve sleep not only the night before an important sports event but also in the weeks leading up to this event are likely to be fruitful in improving performance. In this review, we have summarized and synthesized recent findings in the realm of sports and sleep science. One of the challenges of conducting such a literature review is that the study methodologies vary a great deal, as do the individual sports, making comparisons of effects and magnitudes of effect sizes across studies difficult. Additionally, unlike many studies of athletic performance and sleep conducted in nonathletes and recreational sports players, studies incorporating high-level competitors are limited, especially those implementing experimental approaches. Even among the best-controlled studies, sample sizes are small and sleep measurements vary considerably, with some studies measuring sleep duration objectively through polysomnography or actigraphy and others relying on self-report. All of these factors limit the scope of the conclusions that can be drawn. Nevertheless, they do provide valuable information about when sleep does or particularly when sleep does not seem to play a key role in influencing performance. Future research may seek to use larger sample sizes and standardize tests of athletic performance in order to identify optimal sleep standards, in addition to standardizing sleep metrics and incorporating more objective sleep data. In particular, here we focused on studies investigating sleep duration, although sleep timing is likely to be a relevant factor as well. As sleep onset and wake time have previously been shown to influence performance and recovery,5 future studies should aim to incorporate this information. Given these suggestions for improving future research, there are many opportunities for innovative research on this topic. One area in particular may be about how generalizable these findings are to other sports. Given the wide range of methodologies and used in these studies, another research goal would be to harmonize measures across studies and conduct a meta-analysis. Another area to investigate is trade-offs between wake time activities (eg, athletic practice) and sleep. For example, is it beneficial for swimmers to practice early in the morning even at the expense of their sleep? Research also should seek to investigate the mechanisms by which aerobic, tactical, and technical performance attributes may be preferentially sensitive to changes in sleep patterns. One limitation of the present work is that although the number of hours and/or nights of sleep interventions across studies varied, sleep duration was only measured the night before performance assessment. Thus, in order to obtain a more complete picture of sleep quantity and quality, future research should aim to measure sleep across the entire study period. Another limitation is that few of the studies examined explicitly the relationship between subjective sleep quality and performance, especially using validated sleep quality questionnaires such as the PSQI and ESS. Thus, this remains an open question that will be important to be investigated in the future. Once all these data are gathered, feasible and effective interventions should be developed, implemented, and evaluated to improve the sleep health and optimal performance of athletes. In conclusion, the importance of sleep for professional athletes to achieve high performance varies by the cognitive and physical demands of the sport. However, because most sports require integration of aerobic fitness, tactical skills, and technical skills, competitive athletes will likely benefit from an increase in sleep duration.  
"""

text2 = """Food craving, cortisol and ghrelin responses in modeling highly palatable snack intake in the laboratory

DISCUSSION
This preliminary study is the first to directly compare the effects of both food cue and stress exposure on HP food craving and HP food intake in a 3-day human laboratory experiment conducted within a controlled hospital-based setting with healthy community adults. As both the ubiquitous HP food environment and stressors are known to increase HP food intake and obesity risk, a direct comparison of these contexts could identify similar and differential processes that may underlie food motivation and intake. As hypothesized, and similar to our previous work in addiction [18], we found that exposure to both personal food cues and to personal stressors relative to a neutral relaxing control cue resulted in increases in HP food craving and subsequent increased snacking of HP foods in a standardized Food Snack Test (FST), but with differential effects in lean and overweight BMI groups. Furthermore, we found that increased food craving in these contexts was highly associated with subsequent amounts of HP food snack intake. Finally, both ghrelin and cortisol were found to significantly impact food motivation but differentially across lean and overweight individuals. Together, these results support the need for further investigation of biobehavioral processes underlying HP food motivation and intake, especially in the context of weight-related physiological adaptations.
Exposure to food cue imagery led to significant increases in HP food craving prior to the presentation of the FST at the pre-snack timepoint in both lean and OW individuals. Moreover, food cue-related increases in food craving predicted significant increases in HP snack intake across both lean and OW individuals. These data are consistent with a significant literature indicating that rewarding stimuli and their related contexts increase motivation and wanting of rewarding stimuli via conditioning and/or incentive salience mechanisms [4, 20, 42]. Also, a number of basic science and human neuroimaging studies have shown that food cue stimulus exposure increases food craving and activate brain reward and motivation regions [4, 7-11, 18, 43, 44]. Current findings further indicate that such food cue-related increases in HP food craving promote HP snack intake with greater intake of HP foods in the food cue context relative to the neutral relaxing contexts across individuals. These data validate the real-world contexts of advertising of HP foods to promote greater sales and intake of HP foods.
In contrast, we found a differential impact of stress on HP food craving and intake by BMI group where stress significantly increased food craving relative to the neutral condition, but only in the overweight and not the lean group. Furthermore, stress-induced HP food craving predicted subsequent HP snack intake in the overweight but not the lean group, suggesting that food motivational processes may be relevant in identifying those who are vulnerable to stress-induced eating. Previous laboratory studies have shown mixed results with some showing stress increasing food intake [17, 24], but others reporting no consistent increases in intake [23, 45]. While the methodology has varied across these studies, current findings suggest the need for direct comparison of BMI groups and consideration of weight-related adaptations in assessing stress effects on HP food motivation and intake. Current findings are also supported by a growing literature suggesting that BMI-related alterations impact not only metabolic hormones but also stress and reward processes that may contribute to increased food motivation and intake [18, 20, 44]. Together our findings on food cue- and stress- related effects on HP food motivation and intake suggests differential effects by BMI, that may in turn, point to different mechanisms that may drive weight gain and obesity risk in individuals who are lean versus those who are overweight.
Our findings also show differential effects of food cue and stress exposure on total ghrelin responses and their contribution to HP food motivation and intake. Stress and food cue exposure increased ghrelin responses, but significantly for the OW and not the LN group. Furthermore, only in the OW group was stress-induced ghrelin increases significantly associated with both HP food craving and subsequent HP food intake. While ghrelin has well known homeostatic effects on feeding function [46, 47], recent focus has been on its role in both stress and mood regulation as well as in hedonically motivated feeding behavior, partially via its effects on mesolimbic reward circuits [37, 48]. Findings indicate that ghrelin can shift preferences to high palatable foods and increase the motivational aspects of food reward [48]. Ghrelin is also known to increase with stress and is involved in regulating anxiety and mood (36, 49-51). Neuroimaging studies have demonstrated that ghrelin administration increases the neural response to food pictures in areas associated with hedonic eating (i.e., amygdala, hippocampus, orbitofrontal cortex, striatum, and ventral tegmental area) [52]. Additionally, there is growing evidence that feed-forward circuitry between stress and food reward maybe partly mediated by ghrelin [52, 53]. In the current study, as the effects were specific to the OW group, they suggest that weight-related adaptations in ghrelin modulated pathways could potentially shift food motivation towards hedonic regulation, especially under stress conditions.
Finally, our findings also showed differential effects of cortisol responses to stress and food cue exposure. Notably, there was a significant increase in cortisol in the food cue relative to the neutral condition that was due to significant increases in cortisol in the lean group and not so in the OW group. Furthermore, food cue-related increases in cortisol was associated with greater food cue-related HP craving, suggesting a role for cortisol in food motivation. While glucocorticoids are often associated with the stress response, they are also known to play an important role in energy intake and regulation. Cortisol increases have been noted with intake of specific macronutrients, including carbohydrates, fats and proteins in animals and humans [6, 54], with the source of cortisol increases to be via both adrenal and extra-adrenal production [54]. Furthermore, in our previous neuroimaging study, increases in cortisol during a mild hypoglycemic state was associated with greater activation of brain reward regions that promoted greater food craving [44]. Together, this previous research supports current findings of the association between greater cortisol responses to food cue exposure with food cue-induced HP food craving.
We did not see an overall significant increase in cortisol during stress exposure, but this was largely due to a lack of response in the OW group. Remarkably, the OW group showed blunted cortisol responses during stress and food cue relative to neutral conditions. This finding is consistent with growing evidence of blunted cortisol and autonomic responses to stress challenge in people who are OW or obese, along with altered autonomic and peripheral catecholamine responses to stress challenge in those weight groups [18, 21-25, 55]. HPA axis adaptations with low cortisol awakening responses have been reported in higher BMI groups, along with blunted responses to stress and reduced dopamine activity [20, 56]. Thus, the current findings of lack of cortisol increases in the OW group leads one to speculate that such HPA axis adaptations may contribute to higher HP food craving and intake in food cue and in stress contexts. However, this is speculation and would need further testing in future studies.
Several limitations of the current study need to be considered. First, the sample size was small and thus the findings are preliminary and need further validation. Also, due to the small sample size, sex differences and differential responses within the overweight groups were not assessed. It is possible that men and women differ in their food motivation and intake responses in food cue and stress contexts as shown in previous work [26,27]. Also, continuous assessment of BMI rather than arbitrary cutoffs for individuals in the lean, overweight and obese BMI range may provide greater sensitivity in assessing weight related adaptations. Thus, research with larger samples is required to replicate current findings and address these issues. Finally, as this study was conducted while participants were in a hospital, it is not clear whether the findings are generalizable to an outpatient experimental context or to real world food motivation and intake settings. On the other hand, as food cues and stress are among the most common contexts in which overeating of HP foods occur in the real world, the current study presents a well-controlled experimental model to study the biobehavioral processes that may contribute to increased food motivation and intake of highly palatable foods. Evidence of HP food motivation and increased snacking in these contexts is consistent with reports of obesogenic environments promoting increased HP food intake and weight gain in the real world. Furthermore, positive associations of HP food craving and intake by total ghrelin and cortisol responses suggests a role for metabolic and neuroendocrine adaptations in increased HP food motivation and intake.
"""

text_dict = create_text_dict([text1, text2])
text_dict.keys()
# Out:
# dict_keys([1, 2])

# %% [markdown]
# ## Create relevance_prompts_df

# %%
from itertools import product
prompts_dict = dict()
experiment_num = 1
relevance_prompts_dict = dict()

prep_step = [
    # "Take the key points to",
    "Take the key points and numerical descriptors to",
    # ""
]

task_part1 = [
    # "Summarize the article in under 300 characters",
    "Summarize for a LinkedIn post",
    # "Summarize for a tweet",
    # "Summarize in an engaging way",
    "Describe the interesting points to your coworker at the water cooler"
    # "Summarize the article for a Tiktok post"
]
audience = [
    # "lay audience",
    # "",
    "seniors",
    "people who enjoy sports"
]
task_part2 = [
    "",
    "Use terms a 12-year-old can understand.",
    # "Assume your audience has no science background."
    # "Include the most interesting findings.",
    # "Include the key take-aways for the reader.",
    # "Include the implications of the article."
]

task_part3 =[
    "Add 1-2 sentences to make this relevant for"
    # "Add 1-2 sentences to make this relevant for older adults."
    # "Once you are done, add 1-2 sentences to make this relevant for older adults.",
    ""
]

# prompts_df = pd.DataFrame(product(prep_step, task_part1, task_part2, task_part3, audience), 
#     columns=['prep_step', 'task part 1', 'task part 2', 'task part 3', 'audience'])

prompts_df = pd.DataFrame(product(prep_step, task_part1), 
    columns=['prep_step', 'task part 1'])

relevance_prompts_df = pd.DataFrame(product(task_part3, audience), 
    columns=['task part 3', 'audience'])



prompts_df['prompt'] = prompts_df.apply(
    lambda row: f"{row['prep_step']} {row['task part 1']}.", 
    axis=1)
# prompts_df['simplify'] = prompts_df.apply(
#     lambda row: f" {row['task part 2'] if row['task part 2'] else ''}", 
#     axis=1)
relevance_prompts_df['relevance'] = relevance_prompts_df.apply(
    lambda row: f" {row['task part 3']} {row['audience']} " if row['audience'] else '', 
    axis=1) 
relevance_prompts_dict[experiment_num] = relevance_prompts_df
relevance_prompts_df
# Out:
#                                    task part 3                 audience  \
# 0  Add 1-2 sentences to make this relevant for                  seniors
# 1  Add 1-2 sentences to make this relevant for  people who enjoy sports
#
#                                                                relevance
# 0                   Add 1-2 sentences to make this relevant for seniors
# 1   Add 1-2 sentences to make this relevant for people who enjoy sports

# %%
prompts_df
# Out:
#                                           prep_step  \
# 0  Take the key points and numerical descriptors to
# 1  Take the key points and numerical descriptors to
#
#                                                             task part 1  \
# 0                                         Summarize for a LinkedIn post
# 1  Describe the interesting points to your coworker at the water cooler
#
#                                                                                                                    prompt
# 0                                         Take the key points and numerical descriptors to Summarize for a LinkedIn post.
# 1  Take the key points and numerical descriptors to Describe the interesting points to your coworker at the water cooler.

# %% [markdown]
# # Iteration 1

# %%
import traceback
import time
# from collections import OrderedDict

class Chaining:

    def __init__(self, text):
        self.text = text

    def summarize(self, task, model="gpt-3.5-turbo", temperature=0.7, n_choices=5, max_tokens=1000,
          text_key=['text_discussion'],
        system_role = "You are an expert at science communication."
        ):
        """
        SH 2023-04-11 12:18: Same as the user-defined `reply` function, but re-written as a class method.
        Send a ChatCompletion request to ChatGPT via the Chatbot class.

        Requrired paramaters:
            - task (str): Task to include in ChatGPT prompt.
            - text (str): Text to feed to GPT for summarization.

        Optional parameters
            - system_role (str): ChatGPT parameter. 
                Default is "You are an expert at science communication."
            - temperature (float): ChatGPT parameter. Default is 0.7.
            - n_choices (int): Number of ChatGPT responses to generate. Default is 5.
            - max_tokens (int): Token limit for ChatGPT response.
            - model (str): ChatGPT model to use. Default is "gpt-3.5-turbo".
        """
        chatbot = Chatbot(self.text,
            system_role=system_role, model=model, temperature=temperature, n_choices=n_choices,
            max_tokens=max_tokens
            )
        prompt = chatbot.create_prompt(task)
        firstline_pattern = r'\s?(\S*)(\n*)(.+)'
        title = re.match(firstline_pattern, self.text)[0]
        self.qna = dict() 
        self.qna['article_title'] = title
        self.qna['system_role'] = system_role
        self.qna['prompt'] = task
        self.qna['model'] = model
        self.summaries_dict = dict()
        self.article_title = title

        try:
            response = chatbot.gpt(prompt)
        except:
            print('\t**API request failed**')
            return self.qna
        try:
            for index, choice in enumerate(response.choices):
                self.qna[f'response_{"{:02d}".format(index+1)}'] = choice["message"]["content"]
                self.summaries_dict[f'response_{"{:02d}".format(index+1)}'] = choice["message"]["content"]
            self.qna[f'text'] = self.text
            return self.qna
        except:
            print('\t**Error with response parsing**')
            return self.qna


    def simplify(self, simplify_task, system_role='You are an expert at science communication.',
                    model="gpt-3.5-turbo", temperature=0.0, n_choices=1, max_tokens=1000, 
                    simplify_iteration=None
                    ):
        self.simplify_bot_dict = dict()
        self.simple_summary_dict = dict()
        for key, summary in self.summaries_dict.items():
            new_key = re.sub(r'response', rf'simple_summary{str(simplify_iteration)}', key)
            print(f'\t\t...Preparing to summarize {key}')
            self.simplify_bot_dict[new_key] = Chatbot(
                summary, system_role=system_role,
                model=model, temperature=temperature, n_choices=n_choices, max_tokens=max_tokens
                )
            simplify_prompt = self.simplify_bot_dict[new_key].create_prompt(simplify_task)
            try:
                self.simple_summary_dict[new_key] = self.simplify_bot_dict[new_key].gpt(simplify_prompt).choices[0]["message"]["content"]
                print(f'\t...Summary given')
            except:
                self.simple_summary_dict[new_key] = self.simplify_bot_dict[new_key].gpt(simplify_prompt)
                print(f'\t...Error parsing response for summary request')
        self.simple_summary_dict['simplify_task'] = simplify_task
        self.qna = {**self.qna, **self.simple_summary_dict}
        try:
            self.qna.update({'text': self.qna.pop('text')})
        except:
            pass
        return self.simple_summary_dict
    
    def add_relevance(self, task, system_role='You are an expert at science communication.',
                    model="gpt-3.5-turbo", temperature=0.0, n_choices=1, max_tokens=1000, 
                    relevance_iteration=None, pause_per_request=20
                    ):
        self.relevance_bot_dict = dict()
        self.relevance_dict = dict()
        if relevance_iteration == None:
            relevance_iteration = 1
        for key, summary in self.summaries_dict.items():
            new_key = re.sub(r'response', rf'relevance{str(relevance_iteration)}', key)
            print(f'\t\t...Preparing to summarize {key}')
            self.relevance_bot_dict[new_key] = Chatbot(
                summary, system_role=system_role,
                model=model, temperature=temperature, n_choices=n_choices, max_tokens=max_tokens
                )
            relevance_prompt = self.relevance_bot_dict[new_key].create_prompt(task)
            try:
                for index, choice in enumerate(self.relevance_bot_dict[new_key].gpt(relevance_prompt).choices):
                    self.relevance_dict[f'{new_key}_{"{:02d}".format(index+1)}'] = choice["message"]["content"]
                    print(f'\t...Relevance given')
            except:
                try:
                    self.relevance_dict[new_key] = self.relevance_bot_dict[new_key].gpt(relevance_prompt).choices[0]["message"]["content"]
                    print(f'\t...First relevance response given')
                except:
                    self.relevance_dict[new_key] = self.relevance_bot_dict[new_key].gpt(relevance_prompt)
                    print(f'\t...Error parsing response for added relevance request')
            print(f'[add_relevance method] Sleeping {pause_per_request} sec to avoid exceeding API rate limit')
            time.sleep(pause_per_request) # Account for API rate limit of 3 API requests/limit 
        self.relevance_dict[f'relevance_task{"{:02d}".format(index+1)}'] = task
        self.qna = {**self.qna, **self.relevance_dict}
        try:
            self.qna.update({'text': self.qna.pop('text')})
        except:
            pass
        return self.relevance_dict

def batch_summarize_chain(text_dict, prompts_df, qna_dict,  chaining_bot_dict, iteration_id, n_choices=5,
    prompt_column='prompt',
    save_outputs=False, filename=None, append_version=False,
    csv_path=r'C:\Users\silvh\OneDrive\lighthouse\Ginkgo coding\content-summarization\output',
    pickle_path=r'C:\Users\silvh\OneDrive\lighthouse\Ginkgo coding\content-summarization\output\pickles'
    ):
    """
    Summarize multiple texts using the same prompts.
    Parameters:
        - prompts_df: DataFrame containing the prompts.
        - qna_dict: Dictionary to store the input and outputs.
        - iteration_id (int, float, or string): Unique ID serving as the key for results in the qna_dict
        - prompt_column (str): Name of the column in the prompts_df containing the user input.

    """
    temp_qna_dict = dict()
    prompts_df = prompts_df.reset_index(drop=True)
    qna_dfs_list = []
    chaining_bot_dict[iteration_id] = dict()
    for key in text_dict:
        text = text_dict[key]
        temp_qna_dict[key] = dict()
        for index, input in prompts_df[prompt_column].items():
            print(f'**Text #{key} prompt #{index} of {prompts_df.index.max()}**')
            try:
                chatbot = Chaining(text)
                temp_qna_dict[key][index] = chatbot.summarize(input, n_choices=n_choices)
                chatbot_dict[iteration_id][f'text{key}_prompt{"{:02d}".format(index)}'] = chatbot
                print('\t...Success!')
            except:
                print('\t...Error making chatbot request')
                break
        try:
            prompts_df = prompts_df.drop(prompt_column)
        except:
            pass
        try:
            updated_qna_dict = pd.concat([
                pd.DataFrame(temp_qna_dict[key]),
                prompts_df.transpose()
            ])
        except Exception as error:
            exc_type, exc_obj, tb = sys.exc_info()
            f = tb.tb_frame
            lineno = tb.tb_lineno
            filename = f.f_code.co_filename
            print("An error occurred on line", lineno, "in", filename, ":", error)
            print('Error concatenating prompts DataFrame')
            return temp_qna_dict, chatbot_dict
        try:
            qna_dfs_list.append(updated_qna_dict)
            qna_dict[iteration_id] = pd.concat(qna_dfs_list, axis=1)
            if save_outputs:
                try:
                    append_version = append_version if filename else False
                    filename = filename if filename else f'{datetime.now().strftime("%Y-%m-%d_%H%M")}_prompt_experiments_{"{:02d}".format(iteration_id)}'
                    savepickle(qna_dict[iteration_id], filename=filename, path=pickle_path, append_version=append_version)
                    save_csv(qna_dict[iteration_id], filename=filename, path=pickle_path, append_version=append_version)
                except:
                    print('Unable to save outputs')
        except:
            print('Error concatenating DataFrames')
    return qna_dict, chatbot_dict

def prompt_chaining_dict(simplify_prompts, qna_chain_dict, chaining_bot_dict, iteration_id,
    summary_iteration_id=None, n_choices=None, pause_per_request=20,
    prompt_column='simplify', simplify_iteration=None
    ):
    """
    Simplify or add context to a summary.
    """
    summary_iteration_id = summary_iteration_id if summary_iteration_id else iteration_id
    print('summary_iteration_id:', summary_iteration_id)
    if n_choices == None:
        n_choices = 1 if prompt_column == 'simplify' else 5
    print('n_choices:', n_choices)
    simple_summaries_dict = dict()
    if type(simplify_prompts) == str:
        simplify_prompts = [simplify_prompts]
    elif type(simplify_prompts) == pd.core.frame.DataFrame:
        simplify_prompts = [prompt for prompt in simplify_prompts[prompt_column].unique() if len(prompt) >1]
    else:
        simplify_prompts = list(set([prompt for prompt in simplify_prompts if len(prompt) >1]))
    simple_summaries_master_dict = dict()
    simple_summaries_df = pd.DataFrame()
    for column, text_prompt_key in enumerate(chaining_bot_dict):
        print(f'**{text_prompt_key}')
        simple_summaries_master_dict[text_prompt_key] = dict()

        for index, prompt in enumerate(simplify_prompts):
            relevance_iteration=index if len(simplify_prompts) > 1 else simplify_iteration
            print(f'\t...Prompt: {prompt}, iteration {relevance_iteration}')
            # simple_summaries_dict[index] = dict()
            if prompt_column == 'simplify':
                summary_dict = chaining_bot_dict[text_prompt_key].simplify(
                    prompt, n_choices=n_choices,
                    simplify_iteration=index if len(simplify_prompts) > 1 else simplify_iteration
                    )
                simple_summaries_master_dict[text_prompt_key].append(summary_dict)
            else: 
                summary_dict = chaining_bot_dict[text_prompt_key].add_relevance(
                    prompt, n_choices=n_choices, pause_per_request=pause_per_request, 
                    relevance_iteration=index if len(simplify_prompts) > 1 else simplify_iteration
                    )
                simple_summaries_master_dict[text_prompt_key] = {**simple_summaries_master_dict[text_prompt_key], **summary_dict}
        simple_summaries_df[column] = pd.concat([
            pd.Series(value) for value in simple_summaries_master_dict[text_prompt_key]
        ])   
    try:
        qna_chain_dict[summary_iteration_id].columns = [i for i in range(len(qna_chain_dict[summary_iteration_id].columns))]
        
        # simple_summaries_df = pd.concat([pd.DataFrame(value) for key, value in simple_summaries_master_dict.items()])
        # simple_summaries_df.columns = [i for i in range(simple_summaries_df.shape[1])]
        temp_qna_chain_dict = pd.concat([
            qna_chain_dict[summary_iteration_id], 
            simple_summaries_df
            ])
        qna_chain_dict[iteration_id] = temp_qna_chain_dict
        print(f"{'Simple summaries' if prompt_column=='simplify' else 'Article relevance for user'} added to original DataFrame")
    except Exception as error:
        exc_type, exc_obj, tb = sys.exc_info()
        f = tb.tb_frame
        lineno = tb.tb_lineno
        filename = f.f_code.co_filename
        print("An error occurred on line", lineno, "in", filename, ":", error)
        print('Unable to concatenate simple summary DataFrame to original DataFrame')
        qna_chain_dict[iteration_id+0.001] = simple_summaries_master_dict

    return qna_chain_dict

iteration_id = 1
n_choices = 2
qna_dict = dict()
qna_chain_dict = dict()
chatbot_dict = dict()

qna_dict, chaining_dict = batch_summarize_chain(text_dict, prompts_df, qna_dict, chatbot_dict, 
    iteration_id=iteration_id, n_choices=n_choices)

# simplify_prompts = task_part2
# qna_dict = simplify_chaining_dict(simplify_prompts, qna_dict, chaining_dict[iteration_id], iteration_id,
#     simplify_iteration=1, summary_iteration_id=None
#     )



# summary_iteration_id = iteration_id
# summary_iteration_id = 4
# n_choices = 2
# relevance_prompts = relevance_prompts_df
# qna_dict = prompt_chaining_dict(relevance_prompts, qna_dict, chaining_dict[summary_iteration_id], iteration_id,
#     prompt_column='relevance', n_choices=n_choices,
#     simplify_iteration=2, summary_iteration_id=summary_iteration_id
#     )
# Out:
# **Text #1 prompt #0 of 1**
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Success!
# **Text #1 prompt #1 of 1**
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Success!
# **Text #2 prompt #0 of 1**
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Success!
# **Text #2 prompt #1 of 1**
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Success!

# %%
qna_dict[iteration_id]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# article_title                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# system_role                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# prompt                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# model                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# response_01                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# response_02                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# text           The Impact of Sleep Duration on Performance Among Competitive Athletes: A Systematic Literature Review\n\nDISCUSSION \nThis literature review, although diverse in the range of sports, methods, and outcomes studied, provides several stylized facts that can inform sleep research and competitive athletes. First, out of all the published studies we reviewed, none found a negative association between sleep duration and any performance outcome. All of the results reviewed showed that either the increased sleep duration has a positive effect on athletic performance or the results were neutral. Note that among studies reporting significant positive results, effect sizes varied considerably (Tables 2-4), likely due to differences in the duration of sleep deprivation/extension experienced as well as differences in outcome measures. Second, when considering the aerobic and anaerobic characteristics of sports, it seems that aerobic activity is more sensitive to sleep duration compared to anaerobic activity, including strength testing. For instance, Mejri et al40 found that depriving competitive taekwondo boxers of a mere 3 to 4 hours of sleep significantly impaired performance on the Yo-Yo intermittent recovery test. By contrast, Blumert et al33 employed a relatively severe sleep deprivation protocol by depriving 9 national-caliber collegiate weightlifters of 24 hours of sleep and yet failed to identify adverse effects on any of the various weightlifting exercises examined. Relatedly, for both endurance and explosive, power-based exercises, it has been well documented that sleep deprivation is associated with increased perceived effort.56–58 Still, the relationship between perceived effort and objective performance has not been widely validated and is a topic for future investigation. Third, of the studies that measured outcomes requiring either tactical and/or technical skills, most find benefits of sleep on performance. Tennis serving accuracy and basketball shooting were both improved by long-term sleep extension interventions,35,39 and tennis serving accuracy suffered when players were deprived of 2 to 2.5 hours of sleep at the beginning of the preceding night.37 Regarding studies conducted in players of team sports that incorporated tactics and decision-based outcomes to a broader extent, soccer as well as rugby players exhibited performance deficits after nights of decreased sleep duration.34 These results are in line with other literature demonstrating clear neurocognitive deficits in the setting of inadequate sleep in the general population, reviewed thoroughly elsewhere.59,60 Finally, when looking at the methodologies of the experimental studies, we found that the studies that altered sleep duration on a longer-term timescale were more likely to show an effect than those that altered sleep duration acutely. Interestingly although most acute sleep interventions involved sleep deprivation and yielded positive results, there were inconsistent results among the 2 acute sleep extension studies.15,38 Conversely, the majority of longer-term sleep intervention studies involved sleep extension and showed positive results.35,39,49 Taken together, these findings suggest that on a short timescale, sleep deprivation may be more harmful than sleep extension is beneficial to performance, although in the longer term, sleep extension may contribute to improved performance. On the other hand, more research is warranted regarding potential adverse effects of chronic sleep loss on athletic performance. The reliability and precision of the various measurements may present challenges in interpretation of these studies. For example, “maximal” voluntary muscle contraction and voluntarily chosen training load are variable across subjects.61,62 On the other hand, “running economy,” the oxygen cost associated with a given running velocity, has low variability among highly trained runners and is significantly correlated with cardiorespiratory ...
# prep_step                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# task part 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# prompt                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
#
# ...
# prep_step                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# task part 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# prompt                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...

# %%
summary_iteration_id = iteration_id
# summary_iteration_id = 4
n_choices = 2
relevance_prompts = relevance_prompts_df
qna_dict = prompt_chaining_dict(relevance_prompts, qna_dict, chaining_dict[summary_iteration_id], iteration_id,
    prompt_column='relevance', n_choices=n_choices,
    simplify_iteration=2, summary_iteration_id=summary_iteration_id
    )
# Out:
# summary_iteration_id: 1
# n_choices: 2
# **text1_prompt00
# 	...Prompt:  Add 1-2 sentences to make this relevant for seniors , iteration 0
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 	...Prompt:  Add 1-2 sentences to make this relevant for people who enjoy sports , iteration 1
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# **text1_prompt01
# 	...Prompt:  Add 1-2 sentences to make this relevant for seniors , iteration 0
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 	...Prompt:  Add 1-2 sentences to make this relevant for people who enjoy sports , iteration 1
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# **text2_prompt00
# 	...Prompt:  Add 1-2 sentences to make this relevant for seniors , iteration 0
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 	...Prompt:  Add 1-2 sentences to make this relevant for people who enjoy sports , iteration 1
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# **text2_prompt01
# 	...Prompt:  Add 1-2 sentences to make this relevant for seniors , iteration 0
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 	...Prompt:  Add 1-2 sentences to make this relevant for people who enjoy sports , iteration 1
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# Article relevance for user added to original DataFrame

# %%
qna_dict[iteration_id]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# article_title                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# system_role                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# prompt                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# model                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# response_01                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# response_02                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# text           The Impact of Sleep Duration on Performance Among Competitive Athletes: A Systematic Literature Review\n\nDISCUSSION \nThis literature review, although diverse in the range of sports, methods, and outcomes studied, provides several stylized facts that can inform sleep research and competitive athletes. First, out of all the published studies we reviewed, none found a negative association between sleep duration and any performance outcome. All of the results reviewed showed that either the increased sleep duration has a positive effect on athletic performance or the results were neutral. Note that among studies reporting significant positive results, effect sizes varied considerably (Tables 2-4), likely due to differences in the duration of sleep deprivation/extension experienced as well as differences in outcome measures. Second, when considering the aerobic and anaerobic characteristics of sports, it seems that aerobic activity is more sensitive to sleep duration compared to anaerobic activity, including strength testing. For instance, Mejri et al40 found that depriving competitive taekwondo boxers of a mere 3 to 4 hours of sleep significantly impaired performance on the Yo-Yo intermittent recovery test. By contrast, Blumert et al33 employed a relatively severe sleep deprivation protocol by depriving 9 national-caliber collegiate weightlifters of 24 hours of sleep and yet failed to identify adverse effects on any of the various weightlifting exercises examined. Relatedly, for both endurance and explosive, power-based exercises, it has been well documented that sleep deprivation is associated with increased perceived effort.56–58 Still, the relationship between perceived effort and objective performance has not been widely validated and is a topic for future investigation. Third, of the studies that measured outcomes requiring either tactical and/or technical skills, most find benefits of sleep on performance. Tennis serving accuracy and basketball shooting were both improved by long-term sleep extension interventions,35,39 and tennis serving accuracy suffered when players were deprived of 2 to 2.5 hours of sleep at the beginning of the preceding night.37 Regarding studies conducted in players of team sports that incorporated tactics and decision-based outcomes to a broader extent, soccer as well as rugby players exhibited performance deficits after nights of decreased sleep duration.34 These results are in line with other literature demonstrating clear neurocognitive deficits in the setting of inadequate sleep in the general population, reviewed thoroughly elsewhere.59,60 Finally, when looking at the methodologies of the experimental studies, we found that the studies that altered sleep duration on a longer-term timescale were more likely to show an effect than those that altered sleep duration acutely. Interestingly although most acute sleep interventions involved sleep deprivation and yielded positive results, there were inconsistent results among the 2 acute sleep extension studies.15,38 Conversely, the majority of longer-term sleep intervention studies involved sleep extension and showed positive results.35,39,49 Taken together, these findings suggest that on a short timescale, sleep deprivation may be more harmful than sleep extension is beneficial to performance, although in the longer term, sleep extension may contribute to improved performance. On the other hand, more research is warranted regarding potential adverse effects of chronic sleep loss on athletic performance. The reliability and precision of the various measurements may present challenges in interpretation of these studies. For example, “maximal” voluntary muscle contraction and voluntarily chosen training load are variable across subjects.61,62 On the other hand, “running economy,” the oxygen cost associated with a given running velocity, has low variability among highly trained runners and is significantly correlated with cardiorespiratory ...
# prep_step                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# task part 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# prompt                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# ...
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...

# %%
chatbot_dict[iteration_id]['text1_prompt00'].qna
# Out:
# {'article_title': 'The Impact of Sleep Duration on Performance Among Competitive Athletes: A Systematic Literature Review',
#  'system_role': 'You are an expert at science communication.',
#  'prompt': 'Take the key points and numerical descriptors to Summarize for a LinkedIn post.',
#  'model': 'gpt-3.5-turbo',
#  'response_01': 'A literature review found no negative association between sleep duration and athletic performance, with increased sleep duration having a positive or neutral effect. Aerobic activity was found to be more sensitive to sleep duration compared to anaerobic activity. Studies measuring outcomes requiring tactical and technical skills found benefits of sleep on performance. Longer-term sleep extension was shown to contribute to improved performance. However, more research is needed to investigate potential adverse effects of chronic sleep loss on athletic performance. Standardized tests of athletic performance and objective sleep data are needed for future research. Competitive athletes may benefit from an increase in sleep duration.',
#  'response_02': '"Systematic literature review finds no negative association between sleep duration and athletic performance. Instead, increased sleep duration has a positive effect or is neutral. Aerobic activity is more sensitive to sleep duration compared to anaerobic activity. Sleep extension interventions improve technical and tactical skills, while sleep deprivation impairs them. Strategies to improve sleep not only the night before an important sports event but also in the weeks leading up to it are likely to be fruitful in improving performance. Future research should aim to harmonize measures across studies and investigate the mechanisms by which different performance attributes may be preferentially sensitive to changes in sleep patterns." #SportsScience #SleepResearch #AthleticPerformance',
#  'relevance0_01_01': 'For seniors who engage in physical activity, ensuring adequate sleep duration may contribute to improved performance and overall health. However, it is important to consult with a healthcare provider to determine individual sleep needs and any potential risks associated with sleep loss.',
#  'relevance0_01_02': 'For seniors who engage in physical activity, ensuring adequate sleep duration may contribute to improved performance and overall health. However, it is important to consult with a healthcare provider to determine individual sleep needs and any potential risks associated with sleep loss.',
#  'relevance0_02_01': 'For seniors who are interested in maintaining their physical fitness, this study suggests that getting enough sleep is important for optimal athletic performance. It also highlights the benefits of sleep extension interventions and strategies to improve sleep leading up to important events.',
#  'relevance0_02_02': 'For seniors who are interested in maintaining their physical fitness, this study suggests that getting enough sleep is important for optimal athletic performance. It also highlights the benefits of sleep extension interventions and strategies to improve sleep leading up to important events.',
#  'relevance_task02': ' Add 1-2 sentences to make this relevant for people who enjoy sports ',
#  'relevance1_01_01': "If you're an athlete looking to improve your performance, getting enough sleep is crucial. Studies have shown that increasing your sleep duration can have a positive impact on your athletic abilities, especially for activities that require tactical and technical skills. So, make sure to prioritize your sleep to give yourself the best chance of success on the field or court.",
#  'relevance1_01_02': "If you're an athlete looking to improve your performance, getting enough sleep is crucial. Studies have shown that increasing your sleep duration can have a positive impact on your athletic abilities, especially for activities that require tactical and technical skills. So, make sure to prioritize your sleep to give yourself the best chance of success on the field or court.",
#  'relevance1_02_01': "If you're an athlete looking to improve your performance, this study suggests that getting enough sleep is crucial. Not only can sleep extension interventions improve your technical and tactical skills, but ensuring you get enough sleep in the weeks leading up to an important event can also make a big difference.",
#  'relevance1_02_02': "If you're an athlete looking to improve your performance, this study suggests that getting enough sleep is crucial. Not only can sleep extension interventions improve your technical and tactical skills, but ensuring you get enough sleep in the weeks leading up to an important event can also make a big difference.",
#  'text': 'The Impact of Sleep Duration on Performance Among Competitive Athletes: A Systematic Literature Review\n\nDISCUSSION \nThis literature review, although diverse in the range of sports, methods, and outcomes studied, provides several stylized facts that can inform sleep research and competitive athletes. First, out of all the published studies we reviewed, none found a negative association between sleep duration and any performance outcome. All of the results reviewed showed that either the increased sleep duration has a positive effect on athletic performance or the results were neutral. Note that among studies reporting significant positive results, effect sizes varied considerably (Tables 2-4), likely due to differences in the duration of sleep deprivation/extension experienced as well as differences in outcome measures. Second, when considering the aerobic and anaerobic characteristics of sports, it seems that aerobic activity is more sensitive to sleep duration compared to anaerobic activity, including strength testing. For instance, Mejri et al40 found that depriving competitive taekwondo boxers of a mere 3 to 4 hours of sleep significantly impaired performance on the Yo-Yo intermittent recovery test. By contrast, Blumert et al33 employed a relatively severe sleep deprivation protocol by depriving 9 national-caliber collegiate weightlifters of 24 hours of sleep and yet failed to identify adverse effects on any of the various weightlifting exercises examined. Relatedly, for both endurance and explosive, power-based exercises, it has been well documented that sleep deprivation is associated with increased perceived effort.56–58 Still, the relationship between perceived effort and objective performance has not been widely validated and is a topic for future investigation. Third, of the studies that measured outcomes requiring either tactical and/or technical skills, most find benefits of sleep on performance. Tennis serving accuracy and basketball shooting were both improved by long-term sleep extension interventions,35,39 and tennis serving accuracy suffered when players were deprived of 2 to 2.5 hours of sleep at the beginning of the preceding night.37 Regarding studies conducted in players of team sports that incorporated tactics and decision-based outcomes to a broader extent, soccer as well as rugby players exhibited performance deficits after nights of decreased sleep duration.34 These results are in line with other literature demonstrating clear neurocognitive deficits in the setting of inadequate sleep in the general population, reviewed thoroughly elsewhere.59,60 Finally, when looking at the methodologies of the experimental studies, we found that the studies that altered sleep duration on a longer-term timescale were more likely to show an effect than those that altered sleep duration acutely. Interestingly although most acute sleep interventions involved sleep deprivation and yielded positive results, there were inconsistent results among the 2 acute sleep extension studies.15,38 Conversely, the majority of longer-term sleep intervention studies involved sleep extension and showed positive results.35,39,49 Taken together, these findings suggest that on a short timescale, sleep deprivation may be more harmful than sleep extension is beneficial to performance, although in the longer term, sleep extension may contribute to improved performance. On the other hand, more research is warranted regarding potential adverse effects of chronic sleep loss on athletic performance. The reliability and precision of the various measurements may present challenges in interpretation of these studies. For example, “maximal” voluntary muscle contraction and voluntarily chosen training load are variable across subjects.61,62 On the other hand, “running economy,” the oxygen cost associated with a given running velocity, has low variability among highly trained runners and is significantly correlated with cardiorespiratory para ...

# %%
qna_dict[iteration_id] = qna_dict[iteration_id].head(10)

# %% [markdown]
# ## 1.1

# %%
import traceback
import time
# from collections import OrderedDict

class Chaining:

    def __init__(self, text):
        self.text = text

    def summarize(self, task, model="gpt-3.5-turbo", temperature=0.7, n_choices=5, max_tokens=1000,
          text_key=['text_discussion'],
        system_role = "You are an expert at science communication."
        ):
        """
        SH 2023-04-11 12:18: Same as the user-defined `reply` function, but re-written as a class method.
        Send a ChatCompletion request to ChatGPT via the Chatbot class.

        Requrired paramaters:
            - task (str): Task to include in ChatGPT prompt.
            - text (str): Text to feed to GPT for summarization.

        Optional parameters
            - system_role (str): ChatGPT parameter. 
                Default is "You are an expert at science communication."
            - temperature (float): ChatGPT parameter. Default is 0.7.
            - n_choices (int): Number of ChatGPT responses to generate. Default is 5.
            - max_tokens (int): Token limit for ChatGPT response.
            - model (str): ChatGPT model to use. Default is "gpt-3.5-turbo".
        """
        chatbot = Chatbot(self.text,
            system_role=system_role, model=model, temperature=temperature, n_choices=n_choices,
            max_tokens=max_tokens
            )
        prompt = chatbot.create_prompt(task)
        firstline_pattern = r'\s?(\S*)(\n*)(.+)'
        title = re.match(firstline_pattern, self.text)[0]
        self.qna = dict() 
        self.qna['article_title'] = title
        self.qna['system_role'] = system_role
        self.qna['prompt'] = task
        self.qna['model'] = model
        self.summaries_dict = dict()
        self.article_title = title

        try:
            response = chatbot.gpt(prompt)
        except:
            print('\t**API request failed**')
            return self.qna
        try:
            for index, choice in enumerate(response.choices):
                self.qna[f'response_{"{:02d}".format(index+1)}'] = choice["message"]["content"]
                self.summaries_dict[f'response_{"{:02d}".format(index+1)}'] = choice["message"]["content"]
            self.qna[f'text'] = self.text
            return self.qna
        except:
            print('\t**Error with response parsing**')
            return self.qna


    def simplify(self, simplify_task, system_role='You are an expert at science communication.',
                    model="gpt-3.5-turbo", temperature=0.0, n_choices=1, max_tokens=1000, 
                    simplify_iteration=None
                    ):
        self.simplify_bot_dict = dict()
        self.simple_summary_dict = dict()
        for key, summary in self.summaries_dict.items():
            new_key = re.sub(r'response', rf'simple_summary{str(simplify_iteration)}', key)
            print(f'\t\t...Preparing to summarize {key}')
            self.simplify_bot_dict[new_key] = Chatbot(
                summary, system_role=system_role,
                model=model, temperature=temperature, n_choices=n_choices, max_tokens=max_tokens
                )
            simplify_prompt = self.simplify_bot_dict[new_key].create_prompt(simplify_task)
            try:
                self.simple_summary_dict[new_key] = self.simplify_bot_dict[new_key].gpt(simplify_prompt).choices[0]["message"]["content"]
                print(f'\t...Summary given')
            except:
                self.simple_summary_dict[new_key] = self.simplify_bot_dict[new_key].gpt(simplify_prompt)
                print(f'\t...Error parsing response for summary request')
        self.simple_summary_dict['simplify_task'] = simplify_task
        self.qna = {**self.qna, **self.simple_summary_dict}
        try:
            self.qna.update({'text': self.qna.pop('text')})
        except:
            pass
        return self.simple_summary_dict
    
    def add_relevance(self, task, system_role='You are an expert at science communication.',
                    model="gpt-3.5-turbo", temperature=0.0, n_choices=1, max_tokens=1000, 
                    relevance_iteration=None, pause_per_request=20
                    ):
        self.relevance_bot_dict = dict()
        self.relevance_dict = dict()
        if relevance_iteration == None:
            relevance_iteration = 1
        for key, summary in self.summaries_dict.items():
            new_key = re.sub(r'response', rf'relevance{str(relevance_iteration)}', key)
            print(f'\t\t...Preparing to summarize {key}')
            self.relevance_bot_dict[new_key] = Chatbot(
                summary, system_role=system_role,
                model=model, temperature=temperature, n_choices=n_choices, max_tokens=max_tokens
                )
            relevance_prompt = self.relevance_bot_dict[new_key].create_prompt(task)
            try:
                for index, choice in enumerate(self.relevance_bot_dict[new_key].gpt(relevance_prompt).choices):
                    self.relevance_dict[f'{new_key}_{"{:02d}".format(index+1)}'] = choice["message"]["content"]
                    print(f'\t...Relevance given')
            except:
                try:
                    self.relevance_dict[new_key] = self.relevance_bot_dict[new_key].gpt(relevance_prompt).choices[0]["message"]["content"]
                    print(f'\t...First relevance response given')
                except:
                    self.relevance_dict[new_key] = self.relevance_bot_dict[new_key].gpt(relevance_prompt)
                    print(f'\t...Error parsing response for added relevance request')
            print(f'[add_relevance method] Sleeping {pause_per_request} sec to avoid exceeding API rate limit')
            time.sleep(pause_per_request) # Account for API rate limit of 3 API requests/limit 
        self.relevance_dict[f'relevance_task{"{:02d}".format(relevance_iteration)}'] = task
        self.qna = {**self.qna, **self.relevance_dict}
        try:
            self.qna.update({'text': self.qna.pop('text')})
        except:
            pass
        return self.relevance_dict

def batch_summarize_chain(text_dict, prompts_df, qna_dict,  chaining_bot_dict, iteration_id, n_choices=5,
    prompt_column='prompt',
    save_outputs=False, filename=None, append_version=False,
    csv_path=r'C:\Users\silvh\OneDrive\lighthouse\Ginkgo coding\content-summarization\output',
    pickle_path=r'C:\Users\silvh\OneDrive\lighthouse\Ginkgo coding\content-summarization\output\pickles'
    ):
    """
    Summarize multiple texts using the same prompts.
    Parameters:
        - prompts_df: DataFrame containing the prompts.
        - qna_dict: Dictionary to store the input and outputs.
        - iteration_id (int, float, or string): Unique ID serving as the key for results in the qna_dict
        - prompt_column (str): Name of the column in the prompts_df containing the user input.

    """
    temp_qna_dict = dict()
    prompts_df = prompts_df.reset_index(drop=True)
    qna_dfs_list = []
    chaining_bot_dict[iteration_id] = dict()
    for key in text_dict:
        text = text_dict[key]
        temp_qna_dict[key] = dict()
        for index, input in prompts_df[prompt_column].items():
            print(f'**Text #{key} prompt #{index} of {prompts_df.index.max()}**')
            try:
                chatbot = Chaining(text)
                temp_qna_dict[key][index] = chatbot.summarize(input, n_choices=n_choices)
                chatbot_dict[iteration_id][f'text{key}_prompt{"{:02d}".format(index)}'] = chatbot
                print('\t...Success!')
            except:
                print('\t...Error making chatbot request')
                break
        try:
            prompts_df = prompts_df.drop(prompt_column)
        except:
            pass
        try:
            updated_qna_dict = pd.concat([
                pd.DataFrame(temp_qna_dict[key]),
                prompts_df.transpose()
            ])
        except Exception as error:
            exc_type, exc_obj, tb = sys.exc_info()
            f = tb.tb_frame
            lineno = tb.tb_lineno
            filename = f.f_code.co_filename
            print("An error occurred on line", lineno, "in", filename, ":", error)
            print('Error concatenating prompts DataFrame')
            return temp_qna_dict, chatbot_dict
        try:
            qna_dfs_list.append(updated_qna_dict)
            qna_dict[iteration_id] = pd.concat(qna_dfs_list, axis=1)
            if save_outputs:
                try:
                    append_version = append_version if filename else False
                    filename = filename if filename else f'{datetime.now().strftime("%Y-%m-%d_%H%M")}_prompt_experiments_{"{:02d}".format(iteration_id)}'
                    savepickle(qna_dict[iteration_id], filename=filename, path=pickle_path, append_version=append_version)
                    save_csv(qna_dict[iteration_id], filename=filename, path=pickle_path, append_version=append_version)
                except:
                    print('Unable to save outputs')
        except:
            print('Error concatenating DataFrames')
    return qna_dict, chatbot_dict

def prompt_chaining_dict(simplify_prompts, qna_chain_dict, chaining_bot_dict, iteration_id,
    summary_iteration_id=None, n_choices=None, pause_per_request=20,
    prompt_column='simplify', simplify_iteration=None
    ):
    """
    Simplify or add context to a summary.
    """
    summary_iteration_id = summary_iteration_id if summary_iteration_id else iteration_id
    print('summary_iteration_id:', summary_iteration_id)
    if n_choices == None:
        n_choices = 1 if prompt_column == 'simplify' else 5
    print('n_choices:', n_choices)
    simple_summaries_dict = dict()
    if type(simplify_prompts) == str:
        simplify_prompts = [simplify_prompts]
    elif type(simplify_prompts) == pd.core.frame.DataFrame:
        simplify_prompts = [prompt for prompt in simplify_prompts[prompt_column].unique() if len(prompt) >1]
    else:
        simplify_prompts = list(set([prompt for prompt in simplify_prompts if len(prompt) >1]))
    simple_summaries_master_dict = dict()
    simple_summaries_df = pd.DataFrame()
    for column, text_prompt_key in enumerate(chaining_bot_dict):
        print(f'**{text_prompt_key}')
        simple_summaries_master_dict[text_prompt_key] = dict()

        for index, prompt in enumerate(simplify_prompts):
            relevance_iteration=index if len(simplify_prompts) > 1 else simplify_iteration
            print(f'\t...Prompt: {prompt}, iteration {relevance_iteration}')
            # simple_summaries_dict[index] = dict()
            if prompt_column == 'simplify':
                summary_dict = chaining_bot_dict[text_prompt_key].simplify(
                    prompt, n_choices=n_choices,
                    simplify_iteration=index if len(simplify_prompts) > 1 else simplify_iteration
                    )
                simple_summaries_master_dict[text_prompt_key].append(summary_dict)
            else: 
                summary_dict = chaining_bot_dict[text_prompt_key].add_relevance(
                    prompt, n_choices=n_choices, pause_per_request=pause_per_request, 
                    relevance_iteration=index if len(simplify_prompts) > 1 else simplify_iteration
                    )
                simple_summaries_master_dict[text_prompt_key] = {**simple_summaries_master_dict[text_prompt_key], **summary_dict}
        simple_summaries_df[column] = pd.concat([
            pd.Series(value) for value in simple_summaries_master_dict[text_prompt_key]
        ])   
    return simple_summaries_master_dict
    try:
        qna_chain_dict[summary_iteration_id].columns = [i for i in range(len(qna_chain_dict[summary_iteration_id].columns))]
        
        # simple_summaries_df = pd.concat([pd.DataFrame(value) for key, value in simple_summaries_master_dict.items()])
        # simple_summaries_df.columns = [i for i in range(simple_summaries_df.shape[1])]
        temp_qna_chain_dict = pd.concat([
            qna_chain_dict[summary_iteration_id], 
            simple_summaries_df
            ])
        qna_chain_dict[iteration_id] = temp_qna_chain_dict
        print(f"{'Simple summaries' if prompt_column=='simplify' else 'Article relevance for user'} added to original DataFrame")
    except Exception as error:
        exc_type, exc_obj, tb = sys.exc_info()
        f = tb.tb_frame
        lineno = tb.tb_lineno
        filename = f.f_code.co_filename
        print("An error occurred on line", lineno, "in", filename, ":", error)
        print('Unable to concatenate simple summary DataFrame to original DataFrame')
        qna_chain_dict[iteration_id+0.001] = simple_summaries_master_dict

    return qna_chain_dict

iteration_id = 1.1
n_choices = 2
# qna_dict = dict()
# qna_chain_dict = dict()
# chatbot_dict = dict()

# qna_dict, chaining_dict = batch_summarize_chain(text_dict, prompts_df, qna_dict, chatbot_dict, 
#     iteration_id=iteration_id, n_choices=n_choices)

# simplify_prompts = task_part2
# qna_dict = simplify_chaining_dict(simplify_prompts, qna_dict, chaining_dict[iteration_id], iteration_id,
#     simplify_iteration=1, summary_iteration_id=None
#     )



# summary_iteration_id = iteration_id
summary_iteration_id = 1
n_choices = 2
relevance_prompts = relevance_prompts_df
qna_dict = prompt_chaining_dict(relevance_prompts, qna_dict, chaining_dict[summary_iteration_id], iteration_id,
    prompt_column='relevance', n_choices=n_choices,
    simplify_iteration=2, summary_iteration_id=summary_iteration_id
    )
# Out:
# summary_iteration_id: 1
# n_choices: 2
# **text1_prompt00
# 	...Prompt:  Add 1-2 sentences to make this relevant for seniors , iteration 0
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 	...Prompt:  Add 1-2 sentences to make this relevant for people who enjoy sports , iteration 1
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# **text1_prompt01
# 	...Prompt:  Add 1-2 sentences to make this relevant for seniors , iteration 0
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 	...Prompt:  Add 1-2 sentences to make this relevant for people who enjoy sports , iteration 1
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# **text2_prompt00
# 	...Prompt:  Add 1-2 sentences to make this relevant for seniors , iteration 0
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 	...Prompt:  Add 1-2 sentences to make this relevant for people who enjoy sports , iteration 1
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# **text2_prompt01
# 	...Prompt:  Add 1-2 sentences to make this relevant for seniors , iteration 0
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 	...Prompt:  Add 1-2 sentences to make this relevant for people who enjoy sports , iteration 1
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit

# %%
qna_dict['text1_prompt00']
# Out:
# {'relevance0_01_01': 'For seniors who engage in physical activity, ensuring adequate sleep duration may contribute to improved performance and overall health. However, it is important to consult with a healthcare provider to determine individual sleep needs and any potential risks associated with sleep loss.',
#  'relevance0_01_02': 'For seniors who engage in physical activity, ensuring adequate sleep duration may contribute to improved performance and overall health. However, it is important to consult with a healthcare provider to determine individual sleep needs and any potential risks associated with sleep loss.',
#  'relevance0_02_01': 'For seniors who are interested in maintaining their physical fitness, this study suggests that getting enough sleep is important for optimal athletic performance. It also highlights the benefits of sleep extension interventions and strategies to improve sleep leading up to important events.',
#  'relevance0_02_02': 'For seniors who are interested in maintaining their physical fitness, this study suggests that getting enough sleep is important for optimal athletic performance. It also highlights the benefits of sleep extension interventions and strategies to improve sleep leading up to important events.',
#  'relevance_task02': ' Add 1-2 sentences to make this relevant for people who enjoy sports ',
#  'relevance1_01_01': "If you're an athlete looking to improve your performance, getting enough sleep is crucial. Studies have shown that increasing your sleep duration can have a positive impact on your athletic abilities, especially for activities that require tactical and technical skills. So, make sure to prioritize your sleep to give yourself the best chance of success on the field or court.",
#  'relevance1_01_02': "If you're an athlete looking to improve your performance, getting enough sleep is crucial. Studies have shown that increasing your sleep duration can have a positive impact on your athletic abilities, especially for activities that require tactical and technical skills. So, make sure to prioritize your sleep to give yourself the best chance of success on the field or court.",
#  'relevance1_02_01': "If you're an athlete looking to improve your performance, this study suggests that getting enough sleep is crucial. Not only can sleep extension interventions improve your technical and tactical skills, but ensuring you get enough sleep in the weeks leading up to an important event can also make a big difference.",
#  'relevance1_02_02': "If you're an athlete looking to improve your performance, this study suggests that getting enough sleep is crucial. Not only can sleep extension interventions improve your technical and tactical skills, but ensuring you get enough sleep in the weeks leading up to an important event can also make a big difference."}

# %% [markdown]
# ## 1.2

# %%
import traceback
import time
# from collections import OrderedDict

class Chaining:

    def __init__(self, text):
        self.text = text

    def summarize(self, task, model="gpt-3.5-turbo", temperature=0.7, n_choices=5, max_tokens=1000,
          text_key=['text_discussion'],
        system_role = "You are an expert at science communication."
        ):
        """
        SH 2023-04-11 12:18: Same as the user-defined `reply` function, but re-written as a class method.
        Send a ChatCompletion request to ChatGPT via the Chatbot class.

        Requrired paramaters:
            - task (str): Task to include in ChatGPT prompt.
            - text (str): Text to feed to GPT for summarization.

        Optional parameters
            - system_role (str): ChatGPT parameter. 
                Default is "You are an expert at science communication."
            - temperature (float): ChatGPT parameter. Default is 0.7.
            - n_choices (int): Number of ChatGPT responses to generate. Default is 5.
            - max_tokens (int): Token limit for ChatGPT response.
            - model (str): ChatGPT model to use. Default is "gpt-3.5-turbo".
        """
        chatbot = Chatbot(self.text,
            system_role=system_role, model=model, temperature=temperature, n_choices=n_choices,
            max_tokens=max_tokens
            )
        prompt = chatbot.create_prompt(task)
        firstline_pattern = r'\s?(\S*)(\n*)(.+)'
        title = re.match(firstline_pattern, self.text)[0]
        self.qna = dict() 
        self.qna['article_title'] = title
        self.qna['system_role'] = system_role
        self.qna['prompt'] = task
        self.qna['model'] = model
        self.summaries_dict = dict()
        self.article_title = title

        try:
            response = chatbot.gpt(prompt)
        except:
            print('\t**API request failed**')
            return self.qna
        try:
            for index, choice in enumerate(response.choices):
                self.qna[f'response_{"{:02d}".format(index+1)}'] = choice["message"]["content"]
                self.summaries_dict[f'response_{"{:02d}".format(index+1)}'] = choice["message"]["content"]
            self.qna[f'text'] = self.text
            return self.qna
        except:
            print('\t**Error with response parsing**')
            return self.qna


    def simplify(self, simplify_task, system_role='You are an expert at science communication.',
                    model="gpt-3.5-turbo", temperature=0.0, n_choices=1, max_tokens=1000, 
                    simplify_iteration=None
                    ):
        self.simplify_bot_dict = dict()
        self.simple_summary_dict = dict()
        for key, summary in self.summaries_dict.items():
            new_key = re.sub(r'response', rf'simple_summary{str(simplify_iteration)}', key)
            print(f'\t\t...Preparing to summarize {key}')
            self.simplify_bot_dict[new_key] = Chatbot(
                summary, system_role=system_role,
                model=model, temperature=temperature, n_choices=n_choices, max_tokens=max_tokens
                )
            simplify_prompt = self.simplify_bot_dict[new_key].create_prompt(simplify_task)
            try:
                self.simple_summary_dict[new_key] = self.simplify_bot_dict[new_key].gpt(simplify_prompt).choices[0]["message"]["content"]
                print(f'\t...Summary given')
            except:
                self.simple_summary_dict[new_key] = self.simplify_bot_dict[new_key].gpt(simplify_prompt)
                print(f'\t...Error parsing response for summary request')
        self.simple_summary_dict['simplify_task'] = simplify_task
        self.qna = {**self.qna, **self.simple_summary_dict}
        try:
            self.qna.update({'text': self.qna.pop('text')})
        except:
            pass
        return self.simple_summary_dict
    
    def add_relevance(self, task, system_role='You are an expert at science communication.',
                    model="gpt-3.5-turbo", temperature=0.0, n_choices=1, max_tokens=1000, 
                    relevance_iteration=None, pause_per_request=20
                    ):
        self.relevance_bot_dict = dict()
        self.relevance_dict = dict()
        if relevance_iteration == None:
            relevance_iteration = 1
        for key, summary in self.summaries_dict.items():
            new_key = re.sub(r'response', rf'relevance{str(relevance_iteration)}', key)
            print(f'\t\t...Preparing to summarize {key}')
            self.relevance_bot_dict[new_key] = Chatbot(
                summary, system_role=system_role,
                model=model, temperature=temperature, n_choices=n_choices, max_tokens=max_tokens
                )
            relevance_prompt = self.relevance_bot_dict[new_key].create_prompt(task)
            try:
                for index, choice in enumerate(self.relevance_bot_dict[new_key].gpt(relevance_prompt).choices):
                    self.relevance_dict[f'{new_key}_{"{:02d}".format(index+1)}'] = choice["message"]["content"]
                    print(f'\t...Relevance given')
            except:
                try:
                    self.relevance_dict[new_key] = self.relevance_bot_dict[new_key].gpt(relevance_prompt).choices[0]["message"]["content"]
                    print(f'\t...First relevance response given')
                except:
                    self.relevance_dict[new_key] = self.relevance_bot_dict[new_key].gpt(relevance_prompt)
                    print(f'\t...Error parsing response for added relevance request')
            print(f'[add_relevance method] Sleeping {pause_per_request} sec to avoid exceeding API rate limit')
            time.sleep(pause_per_request) # Account for API rate limit of 3 API requests/limit 
        self.relevance_dict[f'relevance_task{"{:02d}".format(relevance_iteration)}'] = task
        self.qna = {**self.qna, **self.relevance_dict}
        try:
            self.qna.update({'text': self.qna.pop('text')})
        except:
            pass
        return self.relevance_dict

def batch_summarize_chain(text_dict, prompts_df, qna_dict,  chaining_bot_dict, iteration_id, n_choices=5,
    prompt_column='prompt',
    save_outputs=False, filename=None, append_version=False,
    csv_path=r'C:\Users\silvh\OneDrive\lighthouse\Ginkgo coding\content-summarization\output',
    pickle_path=r'C:\Users\silvh\OneDrive\lighthouse\Ginkgo coding\content-summarization\output\pickles'
    ):
    """
    Summarize multiple texts using the same prompts.
    Parameters:
        - prompts_df: DataFrame containing the prompts.
        - qna_dict: Dictionary to store the input and outputs.
        - iteration_id (int, float, or string): Unique ID serving as the key for results in the qna_dict
        - prompt_column (str): Name of the column in the prompts_df containing the user input.

    """
    temp_qna_dict = dict()
    prompts_df = prompts_df.reset_index(drop=True)
    qna_dfs_list = []
    chaining_bot_dict[iteration_id] = dict()
    for key in text_dict:
        text = text_dict[key]
        temp_qna_dict[key] = dict()
        for index, input in prompts_df[prompt_column].items():
            print(f'**Text #{key} prompt #{index} of {prompts_df.index.max()}**')
            try:
                chatbot = Chaining(text)
                temp_qna_dict[key][index] = chatbot.summarize(input, n_choices=n_choices)
                chatbot_dict[iteration_id][f'text{key}_prompt{"{:02d}".format(index)}'] = chatbot
                print('\t...Success!')
            except:
                print('\t...Error making chatbot request')
                break
        try:
            prompts_df = prompts_df.drop(prompt_column)
        except:
            pass
        try:
            updated_qna_dict = pd.concat([
                pd.DataFrame(temp_qna_dict[key]),
                prompts_df.transpose()
            ])
        except Exception as error:
            exc_type, exc_obj, tb = sys.exc_info()
            f = tb.tb_frame
            lineno = tb.tb_lineno
            filename = f.f_code.co_filename
            print("An error occurred on line", lineno, "in", filename, ":", error)
            print('Error concatenating prompts DataFrame')
            return temp_qna_dict, chatbot_dict
        try:
            qna_dfs_list.append(updated_qna_dict)
            qna_dict[iteration_id] = pd.concat(qna_dfs_list, axis=1)
            if save_outputs:
                try:
                    append_version = append_version if filename else False
                    filename = filename if filename else f'{datetime.now().strftime("%Y-%m-%d_%H%M")}_prompt_experiments_{"{:02d}".format(iteration_id)}'
                    savepickle(qna_dict[iteration_id], filename=filename, path=pickle_path, append_version=append_version)
                    save_csv(qna_dict[iteration_id], filename=filename, path=pickle_path, append_version=append_version)
                except:
                    print('Unable to save outputs')
        except:
            print('Error concatenating DataFrames')
    return qna_dict, chatbot_dict

def prompt_chaining_dict(simplify_prompts, qna_chain_dict, chaining_bot_dict, iteration_id,
    summary_iteration_id=None, n_choices=None, pause_per_request=20,
    prompt_column='simplify', simplify_iteration=None
    ):
    """
    Simplify or add context to a summary.
    """
    summary_iteration_id = summary_iteration_id if summary_iteration_id else iteration_id
    print('summary_iteration_id:', summary_iteration_id)
    if n_choices == None:
        n_choices = 1 if prompt_column == 'simplify' else 5
    print('n_choices:', n_choices)
    simple_summaries_dict = dict()
    if type(simplify_prompts) == str:
        simplify_prompts = [simplify_prompts]
    elif type(simplify_prompts) == pd.core.frame.DataFrame:
        simplify_prompts = [prompt for prompt in simplify_prompts[prompt_column].unique() if len(prompt) >1]
    else:
        simplify_prompts = list(set([prompt for prompt in simplify_prompts if len(prompt) >1]))
    simple_summaries_master_dict = dict()
    simple_summaries_df = pd.DataFrame()
    for column, text_prompt_key in enumerate(chaining_bot_dict):
        print(f'**{text_prompt_key}')
        simple_summaries_master_dict[text_prompt_key] = dict()

        for index, prompt in enumerate(simplify_prompts):
            relevance_iteration=index if len(simplify_prompts) > 1 else simplify_iteration
            print(f'\t...Prompt: {prompt}, iteration {relevance_iteration}')
            # simple_summaries_dict[index] = dict()
            if prompt_column == 'simplify':
                summary_dict = chaining_bot_dict[text_prompt_key].simplify(
                    prompt, n_choices=n_choices,
                    simplify_iteration=index if len(simplify_prompts) > 1 else simplify_iteration
                    )
                simple_summaries_master_dict[text_prompt_key].append(summary_dict)
            else: 
                summary_dict = chaining_bot_dict[text_prompt_key].add_relevance(
                    prompt, n_choices=n_choices, pause_per_request=pause_per_request, 
                    relevance_iteration=index if len(simplify_prompts) > 1 else simplify_iteration
                    )
            simple_summaries_master_dict[text_prompt_key] = {**simple_summaries_master_dict[text_prompt_key], **summary_dict}
        simple_summaries_df[column] = pd.concat([
            pd.Series(value) for value in simple_summaries_master_dict[text_prompt_key]
        ])   
    qna_dict[iteration_id] = simple_summaries_master_dict
    return qna_dict
    try:
        qna_chain_dict[summary_iteration_id].columns = [i for i in range(len(qna_chain_dict[summary_iteration_id].columns))]
        
        # simple_summaries_df = pd.concat([pd.DataFrame(value) for key, value in simple_summaries_master_dict.items()])
        # simple_summaries_df.columns = [i for i in range(simple_summaries_df.shape[1])]
        temp_qna_chain_dict = pd.concat([
            qna_chain_dict[summary_iteration_id], 
            simple_summaries_df
            ])
        qna_chain_dict[iteration_id] = temp_qna_chain_dict
        print(f"{'Simple summaries' if prompt_column=='simplify' else 'Article relevance for user'} added to original DataFrame")
    except Exception as error:
        exc_type, exc_obj, tb = sys.exc_info()
        f = tb.tb_frame
        lineno = tb.tb_lineno
        filename = f.f_code.co_filename
        print("An error occurred on line", lineno, "in", filename, ":", error)
        print('Unable to concatenate simple summary DataFrame to original DataFrame')
        qna_chain_dict[iteration_id+0.001] = simple_summaries_master_dict

    return qna_chain_dict

iteration_id = 1.2
n_choices = 2
qna_dict = dict()
# qna_chain_dict = dict()
# chatbot_dict = dict()

# qna_dict, chaining_dict = batch_summarize_chain(text_dict, prompts_df, qna_dict, chatbot_dict, 
#     iteration_id=iteration_id, n_choices=n_choices)

# simplify_prompts = task_part2
# qna_dict = simplify_chaining_dict(simplify_prompts, qna_dict, chaining_dict[iteration_id], iteration_id,
#     simplify_iteration=1, summary_iteration_id=None
#     )



# summary_iteration_id = iteration_id
summary_iteration_id = 1
n_choices = 2
relevance_prompts = relevance_prompts_df
qna_dict = prompt_chaining_dict(relevance_prompts, qna_dict, chaining_dict[summary_iteration_id], iteration_id,
    prompt_column='relevance', n_choices=n_choices,
    simplify_iteration=2, summary_iteration_id=summary_iteration_id
    )
# Out:
# summary_iteration_id: 1
# n_choices: 2
# **text1_prompt00
# 	...Prompt:  Add 1-2 sentences to make this relevant for seniors , iteration 0
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 	...Prompt:  Add 1-2 sentences to make this relevant for people who enjoy sports , iteration 1
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# **text1_prompt01
# 	...Prompt:  Add 1-2 sentences to make this relevant for seniors , iteration 0
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 	...Prompt:  Add 1-2 sentences to make this relevant for people who enjoy sports , iteration 1
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# **text2_prompt00
# 	...Prompt:  Add 1-2 sentences to make this relevant for seniors , iteration 0
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 	...Prompt:  Add 1-2 sentences to make this relevant for people who enjoy sports , iteration 1
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# **text2_prompt01
# 	...Prompt:  Add 1-2 sentences to make this relevant for seniors , iteration 0
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 	...Prompt:  Add 1-2 sentences to make this relevant for people who enjoy sports , iteration 1
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit

# %%
qna_dict[iteration_id]

# %%
qna_dict[iteration_id]['text1_prompt00']
# Out:
# {'relevance0_01_01': 'For seniors who engage in physical activity, ensuring adequate sleep duration may contribute to improved performance and overall health. However, it is important to consult with a healthcare provider to determine individual sleep needs and any potential risks associated with sleep loss.',
#  'relevance0_01_02': 'For seniors who engage in physical activity, ensuring adequate sleep duration may contribute to improved performance and overall health. However, it is important to consult with a healthcare provider to determine individual sleep needs and any potential risks associated with sleep loss.',
#  'relevance0_02_01': 'For seniors who are interested in maintaining their physical fitness, this study suggests that getting enough sleep is important for optimal athletic performance. It also highlights the benefits of sleep extension interventions and strategies to improve sleep leading up to important events.',
#  'relevance0_02_02': 'For seniors who are interested in maintaining their physical fitness, this study suggests that getting enough sleep is important for optimal athletic performance. It also highlights the benefits of sleep extension interventions and strategies to improve sleep leading up to important events.',
#  'relevance_task02': ' Add 1-2 sentences to make this relevant for people who enjoy sports ',
#  'relevance1_01_01': "If you're an athlete looking to improve your performance, getting enough sleep is crucial. Studies have shown that increasing your sleep duration can have a positive impact on your athletic abilities, especially for activities that require tactical and technical skills. So, make sure to prioritize your sleep to give yourself the best chance of success on the field or court.",
#  'relevance1_01_02': "If you're an athlete looking to improve your performance, getting enough sleep is crucial. Studies have shown that increasing your sleep duration can have a positive impact on your athletic abilities, especially for activities that require tactical and technical skills. So, make sure to prioritize your sleep to give yourself the best chance of success on the field or court.",
#  'relevance1_02_01': "If you're an athlete looking to improve your performance, this study suggests that getting enough sleep is crucial. Not only can sleep extension interventions improve your technical and tactical skills, but ensuring you get enough sleep in the weeks leading up to an important event can also make a big difference.",
#  'relevance1_02_02': "If you're an athlete looking to improve your performance, this study suggests that getting enough sleep is crucial. Not only can sleep extension interventions improve your technical and tactical skills, but ensuring you get enough sleep in the weeks leading up to an important event can also make a big difference."}

# %%
chatbot_dict[summary_iteration_id]['text1_prompt00'].qna
# Out:
# {'article_title': 'The Impact of Sleep Duration on Performance Among Competitive Athletes: A Systematic Literature Review',
#  'system_role': 'You are an expert at science communication.',
#  'prompt': 'Take the key points and numerical descriptors to Summarize for a LinkedIn post.',
#  'model': 'gpt-3.5-turbo',
#  'response_01': 'A literature review found no negative association between sleep duration and athletic performance, with increased sleep duration having a positive or neutral effect. Aerobic activity was found to be more sensitive to sleep duration compared to anaerobic activity. Studies measuring outcomes requiring tactical and technical skills found benefits of sleep on performance. Longer-term sleep extension was shown to contribute to improved performance. However, more research is needed to investigate potential adverse effects of chronic sleep loss on athletic performance. Standardized tests of athletic performance and objective sleep data are needed for future research. Competitive athletes may benefit from an increase in sleep duration.',
#  'response_02': '"Systematic literature review finds no negative association between sleep duration and athletic performance. Instead, increased sleep duration has a positive effect or is neutral. Aerobic activity is more sensitive to sleep duration compared to anaerobic activity. Sleep extension interventions improve technical and tactical skills, while sleep deprivation impairs them. Strategies to improve sleep not only the night before an important sports event but also in the weeks leading up to it are likely to be fruitful in improving performance. Future research should aim to harmonize measures across studies and investigate the mechanisms by which different performance attributes may be preferentially sensitive to changes in sleep patterns." #SportsScience #SleepResearch #AthleticPerformance',
#  'relevance0_01_01': 'For seniors who engage in physical activity, ensuring adequate sleep duration may contribute to improved performance and overall health. However, it is important to consult with a healthcare provider to determine individual sleep needs and any potential risks associated with sleep loss.',
#  'relevance0_01_02': 'For seniors who engage in physical activity, ensuring adequate sleep duration may contribute to improved performance and overall health. However, it is important to consult with a healthcare provider to determine individual sleep needs and any potential risks associated with sleep loss.',
#  'relevance0_02_01': 'For seniors who are interested in maintaining their physical fitness, this study suggests that getting enough sleep is important for optimal athletic performance. It also highlights the benefits of sleep extension interventions and strategies to improve sleep leading up to important events.',
#  'relevance0_02_02': 'For seniors who are interested in maintaining their physical fitness, this study suggests that getting enough sleep is important for optimal athletic performance. It also highlights the benefits of sleep extension interventions and strategies to improve sleep leading up to important events.',
#  'relevance_task02': ' Add 1-2 sentences to make this relevant for people who enjoy sports ',
#  'relevance1_01_01': "If you're an athlete looking to improve your performance, getting enough sleep is crucial. Studies have shown that increasing your sleep duration can have a positive impact on your athletic abilities, especially for activities that require tactical and technical skills. So, make sure to prioritize your sleep to give yourself the best chance of success on the field or court.",
#  'relevance1_01_02': "If you're an athlete looking to improve your performance, getting enough sleep is crucial. Studies have shown that increasing your sleep duration can have a positive impact on your athletic abilities, especially for activities that require tactical and technical skills. So, make sure to prioritize your sleep to give yourself the best chance of success on the field or court.",
#  'relevance1_02_01': "If you're an athlete looking to improve your performance, this study suggests that getting enough sleep is crucial. Not only can sleep extension interventions improve your technical and tactical skills, but ensuring you get enough sleep in the weeks leading up to an important event can also make a big difference.",
#  'relevance1_02_02': "If you're an athlete looking to improve your performance, this study suggests that getting enough sleep is crucial. Not only can sleep extension interventions improve your technical and tactical skills, but ensuring you get enough sleep in the weeks leading up to an important event can also make a big difference.",
#  'text': 'The Impact of Sleep Duration on Performance Among Competitive Athletes: A Systematic Literature Review\n\nDISCUSSION \nThis literature review, although diverse in the range of sports, methods, and outcomes studied, provides several stylized facts that can inform sleep research and competitive athletes. First, out of all the published studies we reviewed, none found a negative association between sleep duration and any performance outcome. All of the results reviewed showed that either the increased sleep duration has a positive effect on athletic performance or the results were neutral. Note that among studies reporting significant positive results, effect sizes varied considerably (Tables 2-4), likely due to differences in the duration of sleep deprivation/extension experienced as well as differences in outcome measures. Second, when considering the aerobic and anaerobic characteristics of sports, it seems that aerobic activity is more sensitive to sleep duration compared to anaerobic activity, including strength testing. For instance, Mejri et al40 found that depriving competitive taekwondo boxers of a mere 3 to 4 hours of sleep significantly impaired performance on the Yo-Yo intermittent recovery test. By contrast, Blumert et al33 employed a relatively severe sleep deprivation protocol by depriving 9 national-caliber collegiate weightlifters of 24 hours of sleep and yet failed to identify adverse effects on any of the various weightlifting exercises examined. Relatedly, for both endurance and explosive, power-based exercises, it has been well documented that sleep deprivation is associated with increased perceived effort.56–58 Still, the relationship between perceived effort and objective performance has not been widely validated and is a topic for future investigation. Third, of the studies that measured outcomes requiring either tactical and/or technical skills, most find benefits of sleep on performance. Tennis serving accuracy and basketball shooting were both improved by long-term sleep extension interventions,35,39 and tennis serving accuracy suffered when players were deprived of 2 to 2.5 hours of sleep at the beginning of the preceding night.37 Regarding studies conducted in players of team sports that incorporated tactics and decision-based outcomes to a broader extent, soccer as well as rugby players exhibited performance deficits after nights of decreased sleep duration.34 These results are in line with other literature demonstrating clear neurocognitive deficits in the setting of inadequate sleep in the general population, reviewed thoroughly elsewhere.59,60 Finally, when looking at the methodologies of the experimental studies, we found that the studies that altered sleep duration on a longer-term timescale were more likely to show an effect than those that altered sleep duration acutely. Interestingly although most acute sleep interventions involved sleep deprivation and yielded positive results, there were inconsistent results among the 2 acute sleep extension studies.15,38 Conversely, the majority of longer-term sleep intervention studies involved sleep extension and showed positive results.35,39,49 Taken together, these findings suggest that on a short timescale, sleep deprivation may be more harmful than sleep extension is beneficial to performance, although in the longer term, sleep extension may contribute to improved performance. On the other hand, more research is warranted regarding potential adverse effects of chronic sleep loss on athletic performance. The reliability and precision of the various measurements may present challenges in interpretation of these studies. For example, “maximal” voluntary muscle contraction and voluntarily chosen training load are variable across subjects.61,62 On the other hand, “running economy,” the oxygen cost associated with a given running velocity, has low variability among highly trained runners and is significantly correlated with cardiorespiratory para ...

# %% [markdown]
# ## Iteration 1.3

# %%
import traceback
import time
# from collections import OrderedDict

class Chaining:

    def __init__(self, text):
        self.text = text

    def summarize(self, task, model="gpt-3.5-turbo", temperature=0.7, n_choices=5, max_tokens=1000,
          text_key=['text_discussion'],
        system_role = "You are an expert at science communication."
        ):
        """
        SH 2023-04-11 12:18: Same as the user-defined `reply` function, but re-written as a class method.
        Send a ChatCompletion request to ChatGPT via the Chatbot class.

        Requrired paramaters:
            - task (str): Task to include in ChatGPT prompt.
            - text (str): Text to feed to GPT for summarization.

        Optional parameters
            - system_role (str): ChatGPT parameter. 
                Default is "You are an expert at science communication."
            - temperature (float): ChatGPT parameter. Default is 0.7.
            - n_choices (int): Number of ChatGPT responses to generate. Default is 5.
            - max_tokens (int): Token limit for ChatGPT response.
            - model (str): ChatGPT model to use. Default is "gpt-3.5-turbo".
        """
        chatbot = Chatbot(self.text,
            system_role=system_role, model=model, temperature=temperature, n_choices=n_choices,
            max_tokens=max_tokens
            )
        prompt = chatbot.create_prompt(task)
        firstline_pattern = r'\s?(\S*)(\n*)(.+)'
        title = re.match(firstline_pattern, self.text)[0]
        self.qna = dict() 
        self.qna['article_title'] = title
        self.qna['system_role'] = system_role
        self.qna['prompt'] = task
        self.qna['model'] = model
        self.summaries_dict = dict()
        self.article_title = title

        try:
            response = chatbot.gpt(prompt)
        except:
            print('\t**API request failed**')
            return self.qna
        try:
            for index, choice in enumerate(response.choices):
                self.qna[f'response_{"{:02d}".format(index+1)}'] = choice["message"]["content"]
                self.summaries_dict[f'response_{"{:02d}".format(index+1)}'] = choice["message"]["content"]
            self.qna[f'text'] = self.text
            return self.qna
        except:
            print('\t**Error with response parsing**')
            return self.qna


    def simplify(self, simplify_task, system_role='You are an expert at science communication.',
                    model="gpt-3.5-turbo", temperature=0.0, n_choices=1, max_tokens=1000, 
                    simplify_iteration=None
                    ):
        self.simplify_bot_dict = dict()
        self.simple_summary_dict = dict()
        for key, summary in self.summaries_dict.items():
            new_key = re.sub(r'response', rf'simple_summary{str(simplify_iteration)}', key)
            print(f'\t\t...Preparing to summarize {key}')
            self.simplify_bot_dict[new_key] = Chatbot(
                summary, system_role=system_role,
                model=model, temperature=temperature, n_choices=n_choices, max_tokens=max_tokens
                )
            simplify_prompt = self.simplify_bot_dict[new_key].create_prompt(simplify_task)
            try:
                self.simple_summary_dict[new_key] = self.simplify_bot_dict[new_key].gpt(simplify_prompt).choices[0]["message"]["content"]
                print(f'\t...Summary given')
            except:
                self.simple_summary_dict[new_key] = self.simplify_bot_dict[new_key].gpt(simplify_prompt)
                print(f'\t...Error parsing response for summary request')
        self.simple_summary_dict['simplify_task'] = simplify_task
        self.qna = {**self.qna, **self.simple_summary_dict}
        try:
            self.qna.update({'text': self.qna.pop('text')})
        except:
            pass
        return self.simple_summary_dict
    
    def add_relevance(self, task, system_role='You are an expert at science communication.',
                    model="gpt-3.5-turbo", temperature=0.0, n_choices=1, max_tokens=1000, 
                    relevance_iteration=None, pause_per_request=20
                    ):
        self.relevance_bot_dict = dict()
        self.relevance_dict = dict()
        if relevance_iteration == None:
            relevance_iteration = 1
        for key, summary in self.summaries_dict.items():
            new_key = re.sub(r'response', rf'relevance{str(relevance_iteration)}', key)
            print(f'\t\t...Preparing to summarize {key}')
            self.relevance_bot_dict[new_key] = Chatbot(
                summary, system_role=system_role,
                model=model, temperature=temperature, n_choices=n_choices, max_tokens=max_tokens
                )
            relevance_prompt = self.relevance_bot_dict[new_key].create_prompt(task)
            try:
                for index, choice in enumerate(self.relevance_bot_dict[new_key].gpt(relevance_prompt).choices):
                    self.relevance_dict[f'{new_key}_{"{:02d}".format(index+1)}'] = choice["message"]["content"]
                    print(f'\t...Relevance given')
            except:
                try:
                    self.relevance_dict[new_key] = self.relevance_bot_dict[new_key].gpt(relevance_prompt).choices[0]["message"]["content"]
                    print(f'\t...First relevance response given')
                except:
                    self.relevance_dict[new_key] = self.relevance_bot_dict[new_key].gpt(relevance_prompt)
                    print(f'\t...Error parsing response for added relevance request')
            print(f'[add_relevance method] Sleeping {pause_per_request} sec to avoid exceeding API rate limit')
            time.sleep(pause_per_request) # Account for API rate limit of 3 API requests/limit 
        self.relevance_dict[f'relevance_task{"{:02d}".format(relevance_iteration)}'] = task
        self.qna = {**self.qna, **self.relevance_dict}
        try:
            self.qna.update({'text': self.qna.pop('text')})
        except:
            pass
        return self.relevance_dict

def batch_summarize_chain(text_dict, prompts_df, qna_dict,  chaining_bot_dict, iteration_id, n_choices=5,
    prompt_column='prompt',
    save_outputs=False, filename=None, append_version=False,
    csv_path=r'C:\Users\silvh\OneDrive\lighthouse\Ginkgo coding\content-summarization\output',
    pickle_path=r'C:\Users\silvh\OneDrive\lighthouse\Ginkgo coding\content-summarization\output\pickles'
    ):
    """
    Summarize multiple texts using the same prompts.
    Parameters:
        - prompts_df: DataFrame containing the prompts.
        - qna_dict: Dictionary to store the input and outputs.
        - iteration_id (int, float, or string): Unique ID serving as the key for results in the qna_dict
        - prompt_column (str): Name of the column in the prompts_df containing the user input.

    """
    temp_qna_dict = dict()
    prompts_df = prompts_df.reset_index(drop=True)
    qna_dfs_list = []
    chaining_bot_dict[iteration_id] = dict()
    for key in text_dict:
        text = text_dict[key]
        temp_qna_dict[key] = dict()
        for index, input in prompts_df[prompt_column].items():
            print(f'**Text #{key} prompt #{index} of {prompts_df.index.max()}**')
            try:
                chatbot = Chaining(text)
                temp_qna_dict[key][index] = chatbot.summarize(input, n_choices=n_choices)
                chatbot_dict[iteration_id][f'text{key}_prompt{"{:02d}".format(index)}'] = chatbot
                print('\t...Success!')
            except:
                print('\t...Error making chatbot request')
                break
        try:
            prompts_df = prompts_df.drop(prompt_column)
        except:
            pass
        try:
            updated_qna_dict = pd.concat([
                pd.DataFrame(temp_qna_dict[key]),
                prompts_df.transpose()
            ])
        except Exception as error:
            exc_type, exc_obj, tb = sys.exc_info()
            f = tb.tb_frame
            lineno = tb.tb_lineno
            filename = f.f_code.co_filename
            print("An error occurred on line", lineno, "in", filename, ":", error)
            print('Error concatenating prompts DataFrame')
            return temp_qna_dict, chatbot_dict
        try:
            qna_dfs_list.append(updated_qna_dict)
            qna_dict[iteration_id] = pd.concat(qna_dfs_list, axis=1)
            if save_outputs:
                try:
                    append_version = append_version if filename else False
                    filename = filename if filename else f'{datetime.now().strftime("%Y-%m-%d_%H%M")}_prompt_experiments_{"{:02d}".format(iteration_id)}'
                    savepickle(qna_dict[iteration_id], filename=filename, path=pickle_path, append_version=append_version)
                    save_csv(qna_dict[iteration_id], filename=filename, path=pickle_path, append_version=append_version)
                except:
                    print('Unable to save outputs')
        except:
            print('Error concatenating DataFrames')
    return qna_dict, chatbot_dict

def prompt_chaining_dict(simplify_prompts, qna_chain_dict, chaining_bot_dict, iteration_id,
    summary_iteration_id=None, n_choices=None, pause_per_request=20,
    prompt_column='simplify', simplify_iteration=None
    ):
    """
    Simplify or add context to a summary.
    """
    summary_iteration_id = summary_iteration_id if summary_iteration_id else iteration_id
    print('summary_iteration_id:', summary_iteration_id)
    if n_choices == None:
        n_choices = 1 if prompt_column == 'simplify' else 5
    print('n_choices:', n_choices)
    simple_summaries_dict = dict()
    if type(simplify_prompts) == str:
        simplify_prompts = [simplify_prompts]
    elif type(simplify_prompts) == pd.core.frame.DataFrame:
        simplify_prompts = [prompt for prompt in simplify_prompts[prompt_column].unique() if len(prompt) >1]
    else:
        simplify_prompts = list(set([prompt for prompt in simplify_prompts if len(prompt) >1]))
    simple_summaries_master_dict = dict()
    simple_summaries_df = pd.DataFrame()
    for column, text_prompt_key in enumerate(chaining_bot_dict):
        print(f'**{text_prompt_key}')
        simple_summaries_master_dict[text_prompt_key] = dict()

        for index, prompt in enumerate(simplify_prompts):
            relevance_iteration=index if len(simplify_prompts) > 1 else simplify_iteration
            print(f'\t...Prompt: {prompt}, iteration {relevance_iteration}')
            # simple_summaries_dict[index] = dict()
            if prompt_column == 'simplify':
                summary_dict = chaining_bot_dict[text_prompt_key].simplify(
                    prompt, n_choices=n_choices,
                    simplify_iteration=index if len(simplify_prompts) > 1 else simplify_iteration
                    )
                simple_summaries_master_dict[text_prompt_key].append(summary_dict)
            else: 
                summary_dict = chaining_bot_dict[text_prompt_key].add_relevance(
                    prompt, n_choices=n_choices, pause_per_request=pause_per_request, 
                    relevance_iteration=index if len(simplify_prompts) > 1 else simplify_iteration
                    )
            simple_summaries_master_dict[text_prompt_key] = {**simple_summaries_master_dict[text_prompt_key], **summary_dict}
        simple_summaries_df[column] = pd.concat([
            pd.Series(value) for value in simple_summaries_master_dict[text_prompt_key]
        ])   
    # qna_dict[iteration_id] = simple_summaries_master_dict
    # return qna_dict
    try:
        qna_chain_dict[summary_iteration_id].columns = [i for i in range(len(qna_chain_dict[summary_iteration_id].columns))]
        
        # simple_summaries_df = pd.concat([pd.DataFrame(value) for key, value in simple_summaries_master_dict.items()])
        # simple_summaries_df.columns = [i for i in range(simple_summaries_df.shape[1])]
        temp_qna_chain_dict = pd.concat([
            qna_chain_dict[summary_iteration_id], 
            simple_summaries_df
            ])
        qna_chain_dict[iteration_id] = temp_qna_chain_dict
        print(f"{'Simple summaries' if prompt_column=='simplify' else 'Article relevance for user'} added to original DataFrame")
    except Exception as error:
        exc_type, exc_obj, tb = sys.exc_info()
        f = tb.tb_frame
        lineno = tb.tb_lineno
        filename = f.f_code.co_filename
        print("An error occurred on line", lineno, "in", filename, ":", error)
        print('Unable to concatenate simple summary DataFrame to original DataFrame')
        qna_chain_dict[iteration_id+0.001] = simple_summaries_master_dict

    return qna_chain_dict

iteration_id = 1.3
n_choices = 2
# qna_dict = dict()
# qna_chain_dict = dict()
# chatbot_dict = dict()

# qna_dict, chaining_dict = batch_summarize_chain(text_dict, prompts_df, qna_dict, chatbot_dict, 
#     iteration_id=iteration_id, n_choices=n_choices)

# simplify_prompts = task_part2
# qna_dict = simplify_chaining_dict(simplify_prompts, qna_dict, chaining_dict[iteration_id], iteration_id,
#     simplify_iteration=1, summary_iteration_id=None
#     )



# summary_iteration_id = iteration_id
summary_iteration_id = 1
n_choices = 2
relevance_prompts = relevance_prompts_df
qna_dict = prompt_chaining_dict(relevance_prompts, qna_dict, chaining_dict[summary_iteration_id], iteration_id,
    prompt_column='relevance', n_choices=n_choices,
    simplify_iteration=2, summary_iteration_id=summary_iteration_id
    )
# Out:
# summary_iteration_id: 1
# n_choices: 2
# **text1_prompt00
# 	...Prompt:  Add 1-2 sentences to make this relevant for seniors , iteration 0
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 	...Prompt:  Add 1-2 sentences to make this relevant for people who enjoy sports , iteration 1
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# **text1_prompt01
# 	...Prompt:  Add 1-2 sentences to make this relevant for seniors , iteration 0
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 	...Prompt:  Add 1-2 sentences to make this relevant for people who enjoy sports , iteration 1
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# **text2_prompt00
# 	...Prompt:  Add 1-2 sentences to make this relevant for seniors , iteration 0
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 	...Prompt:  Add 1-2 sentences to make this relevant for people who enjoy sports , iteration 1
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# **text2_prompt01
# 	...Prompt:  Add 1-2 sentences to make this relevant for seniors , iteration 0
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 	...Prompt:  Add 1-2 sentences to make this relevant for people who enjoy sports , iteration 1
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# An error occurred on line 237 in C:\Users\silvh\AppData\Local\Temp\ipykernel_7488\57116322.py : 1
# Unable to concatenate simple summary DataFrame to original DataFrame

# %%
qna_dict[iteration_id+0.001]
# Out:
# {'text1_prompt00': {'relevance0_01_01': 'For seniors who engage in physical activity, ensuring adequate sleep duration may contribute to improved performance and overall health. However, it is important to consult with a healthcare provider to determine individual sleep needs and any potential risks associated with sleep loss.',
#   'relevance0_01_02': 'For seniors who engage in physical activity, ensuring adequate sleep duration may contribute to improved performance and overall health. However, it is important to consult with a healthcare provider to determine individual sleep needs and any potential risks associated with sleep loss.',
#   'relevance0_02_01': 'For seniors who are interested in maintaining their physical fitness, this study suggests that getting enough sleep is important for optimal athletic performance. It also highlights the benefits of sleep extension interventions and strategies to improve sleep leading up to important events.',
#   'relevance0_02_02': 'For seniors who are interested in maintaining their physical fitness, this study suggests that getting enough sleep is important for optimal athletic performance. It also highlights the benefits of sleep extension interventions and strategies to improve sleep leading up to important events.',
#   'relevance_task02': ' Add 1-2 sentences to make this relevant for people who enjoy sports ',
#   'relevance1_01_01': "If you're an athlete looking to improve your performance, getting enough sleep is crucial. Studies have shown that increasing your sleep duration can have a positive impact on your athletic abilities, especially for activities that require tactical and technical skills. So, make sure to prioritize your sleep to give yourself the best chance of success on the field or court.",
#   'relevance1_01_02': "If you're an athlete looking to improve your performance, getting enough sleep is crucial. Studies have shown that increasing your sleep duration can have a positive impact on your athletic abilities, especially for activities that require tactical and technical skills. So, make sure to prioritize your sleep to give yourself the best chance of success on the field or court.",
#   'relevance1_02_01': "If you're an athlete looking to improve your performance, this study suggests that getting enough sleep is crucial. Not only can sleep extension interventions improve your technical and tactical skills, but ensuring you get enough sleep in the weeks leading up to an important event can also make a big difference.",
#   'relevance1_02_02': "If you're an athlete looking to improve your performance, this study suggests that getting enough sleep is crucial. Not only can sleep extension interventions improve your technical and tactical skills, but ensuring you get enough sleep in the weeks leading up to an important event can also make a big difference."},
#  'text1_prompt01': {'relevance0_01_01': 'For seniors, it is important to note that sleep duration can also have a significant impact on their physical performance and overall health. Adequate sleep can help improve balance, reduce the risk of falls, and enhance cognitive function. Therefore, seniors should prioritize getting enough sleep to maintain their physical and mental well-being.',
#   'relevance0_01_02': 'For seniors, it is important to note that sleep duration can also have a significant impact on their physical performance and overall health. Adequate sleep can help improve balance, reduce the risk of falls, and enhance cognitive function. Therefore, seniors should prioritize getting enough sleep to maintain their physical and mental well-being.',
#   'relevance0_02_01': 'For seniors, it is important to note that getting enough sleep can also have a positive impact on their physical performance and overall health. Studies have shown that sleep deprivation can lead to decreased balance, coordination, and reaction time, which can increase the risk of falls and injuries. Therefore, seniors should prioritize getting enough sleep to maintain their physical abilities and reduce the risk of accidents.',
#   'relevance0_02_02': 'For seniors, it is important to note that getting enough sleep can also have a positive impact on their physical performance and overall health. Studies have shown that sleep deprivation can lead to decreased balance, coordination, and reaction time, which can increase the risk of falls and injuries. Therefore, seniors should prioritize getting enough sleep to maintain their physical abilities and reduce the risk of accidents.',
#   'relevance_task02': ' Add 1-2 sentences to make this relevant for people who enjoy sports ',
#   'relevance1_01_01': "If you're an athlete looking to improve your performance, getting enough sleep is crucial. This systematic literature review found that increasing your sleep duration can have a positive effect on your athletic performance, especially for activities that require tactical and technical skills.",
#   'relevance1_01_02': "If you're an athlete looking to improve your performance, getting enough sleep is crucial. This systematic literature review found that increasing your sleep duration can have a positive effect on your athletic performance, especially for activities that require tactical and technical skills.",
#   'relevance1_02_01': "So, if you're an athlete looking to improve your performance, it's important to prioritize getting enough sleep, especially if you're involved in aerobic activities or require tactical and technical skills. While more research is needed to fully understand the effects of chronic sleep loss, it's clear that increasing your sleep duration can have a positive impact on your athletic abilities.",
#   'relevance1_02_02': "So, if you're an athlete looking to improve your performance, it's important to prioritize getting enough sleep, especially if you're involved in aerobic activities or require tactical and technical skills. While more research is needed to fully understand the effects of chronic sleep loss, it's clear that increasing your sleep duration can have a positive impact on your athletic abilities."},
#  'text2_prompt00': {'relevance0_01_01': 'These findings are particularly relevant for seniors who may be more susceptible to stress and have a higher risk of weight-related health issues. Understanding the biobehavioral processes that contribute to increased food motivation and intake of highly palatable foods can help seniors make informed decisions about their diet and manage their weight effectively.',
#   'relevance0_01_02': 'These findings are particularly relevant for seniors who may be more susceptible to stress and have a higher risk of weight-related health issues. Understanding the biobehavioral processes that contribute to increased food motivation and intake of highly palatable foods can help seniors make informed decisions about their diet and manage their weight effectively.',
#   'relevance0_02_01': 'This study highlights the importance of managing stress and avoiding personal food cues for seniors who are looking to maintain a healthy weight and avoid overeating. It also emphasizes the need for further research on the biobehavioral processes that impact food motivation and intake in older adults.',
#   'relevance0_02_02': 'This study highlights the importance of managing stress and avoiding personal food cues for seniors who are looking to maintain a healthy weight and avoid overeating. It also emphasizes the need for further research on the biobehavioral processes that impact food motivation and intake in older adults.',
#   'relevance_task02': ' Add 1-2 sentences to make this relevant for people who enjoy sports ',
#   'relevance1_01_01': "For athletes and sports enthusiasts, understanding the biobehavioral processes that drive food motivation and intake can be crucial for optimizing performance and maintaining a healthy weight. This study's findings highlight the potential impact of personal stressors and food cues on snacking habits, which could have implications for athletes looking to manage their diet and maintain a competitive edge.",
#   'relevance1_01_02': "For athletes and sports enthusiasts, understanding the biobehavioral processes that drive food motivation and intake can be crucial for optimizing performance and maintaining a healthy weight. This study's findings highlight the potential impact of personal stressors and food cues on snacking habits, which could have implications for athletes looking to manage their diet and maintain a competitive edge.",
#   'relevance1_02_01': 'This study may be of interest to athletes and fitness enthusiasts who are looking to optimize their nutrition and performance. Understanding the biobehavioral processes that drive food motivation and intake can help athletes make informed decisions about their diet and avoid overindulging in highly palatable foods that may negatively impact their health and performance.',
#   'relevance1_02_02': 'This study may be of interest to athletes and fitness enthusiasts who are looking to optimize their nutrition and performance. Understanding the biobehavioral processes that drive food motivation and intake can help athletes make informed decisions about their diet and avoid overindulging in highly palatable foods that may negatively impact their health and performance.'},
#  'text2_prompt01': {'relevance0_01_01': 'This study is particularly relevant for seniors as they may experience stressors related to aging, such as health concerns or social isolation, which could lead to increased food cravings and snacking. Understanding the biobehavioral processes underlying food motivation and intake can help seniors make informed decisions about their diet and manage stress-induced eating.',
#   'relevance0_01_02': 'This study is particularly relevant for seniors as they may experience stressors related to aging, such as health concerns or social isolation, which could lead to increased food cravings and snacking. Understanding the biobehavioral processes underlying food motivation and intake can help seniors make informed decisions about their diet and manage stress-induced eating.',
#   'relevance0_02_01': 'This study is particularly relevant for seniors as they may be more susceptible to stressors and may have a higher likelihood of being overweight or obese. Understanding the biobehavioral processes underlying highly palatable food motivation and intake can help seniors make informed decisions about their diet and manage their weight.',
#   'relevance0_02_02': 'This study is particularly relevant for seniors as they may be more susceptible to stressors and may have a higher likelihood of being overweight or obese. Understanding the biobehavioral processes underlying highly palatable food motivation and intake can help seniors make informed decisions about their diet and manage their weight.',
#   'relevance_task02': ' Add 1-2 sentences to make this relevant for people who enjoy sports ',
#   'relevance1_01_01': 'For athletes and sports enthusiasts, understanding the biobehavioral processes underlying food motivation and intake can be crucial in maintaining a healthy diet and achieving optimal performance. This study sheds light on the impact of stress and personal food cues on food cravings and snacking, which can be particularly relevant for athletes who may experience stressors related to training and competition.',
#   'relevance1_01_02': 'For athletes and sports enthusiasts, understanding the biobehavioral processes underlying food motivation and intake can be crucial in maintaining a healthy diet and achieving optimal performance. This study sheds light on the impact of stress and personal food cues on food cravings and snacking, which can be particularly relevant for athletes who may experience stressors related to training and competition.',
#   'relevance1_02_01': "This study's findings could be relevant for athletes who are looking to optimize their nutrition and performance. Understanding how stress and food cues impact food cravings and intake can help athletes make informed decisions about their diet and avoid overconsumption of highly palatable snacks that may negatively impact their athletic performance.",
#   'relevance1_02_02': "This study's findings could be relevant for athletes who are looking to optimize their nutrition and performance. Understanding how stress and food cues impact food cravings and intake can help athletes make informed decisions about their diet and avoid overconsumption of highly palatable snacks that may negatively impact their athletic performance."}}

# %%
qna_dict[1.3+0.001]['text1_prompt00'].keys()
# Out:
# dict_keys(['relevance0_01_01', 'relevance0_01_02', 'relevance0_02_01', 'relevance0_02_02', 'relevance_task02', 'relevance1_01_01', 'relevance1_01_02', 'relevance1_02_01', 'relevance1_02_02'])

# %%
test = pd.concat([pd.Series(value) for key, value in qna_dict[1.3+0.001]['text1_prompt00'].items()])
test.index = qna_dict[1.3+0.001]['text1_prompt00'].keys()
test
# Out:
# relevance0_01_01                                                                                             For seniors who engage in physical activity, ensuring adequate sleep duration may contribute to improved performance and overall health. However, it is important to consult with a healthcare provider to determine individual sleep needs and any potential risks associated with sleep loss.
# relevance0_01_02                                                                                             For seniors who engage in physical activity, ensuring adequate sleep duration may contribute to improved performance and overall health. However, it is important to consult with a healthcare provider to determine individual sleep needs and any potential risks associated with sleep loss.
# relevance0_02_01                                                                                         For seniors who are interested in maintaining their physical fitness, this study suggests that getting enough sleep is important for optimal athletic performance. It also highlights the benefits of sleep extension interventions and strategies to improve sleep leading up to important events.
# relevance0_02_02                                                                                         For seniors who are interested in maintaining their physical fitness, this study suggests that getting enough sleep is important for optimal athletic performance. It also highlights the benefits of sleep extension interventions and strategies to improve sleep leading up to important events.
# relevance_task02                                                                                                                                                                                                                                                                                                                        Add 1-2 sentences to make this relevant for people who enjoy sports
# relevance1_01_01    If you're an athlete looking to improve your performance, getting enough sleep is crucial. Studies have shown that increasing your sleep duration can have a positive impact on your athletic abilities, especially for activities that require tactical and technical skills. So, make sure to prioritize your sleep to give yourself the best chance of success on the field or court.
# relevance1_01_02    If you're an athlete looking to improve your performance, getting enough sleep is crucial. Studies have shown that increasing your sleep duration can have a positive impact on your athletic abilities, especially for activities that require tactical and technical skills. So, make sure to prioritize your sleep to give yourself the best chance of success on the field or court.
# relevance1_02_01                                                                  If you're an athlete looking to improve your performance, this study suggests that getting enough sleep is crucial. Not only can sleep extension interventions improve your technical and tactical skills, but ensuring you get enough sleep in the weeks leading up to an important event can also make a big difference.
# relevance1_02_02                                                                  If you're an athlete looking to improve your performance, this study suggests that getting enough sleep is crucial. Not only can sleep extension interventions improve your technical and tactical skills, but ensuring you get enough sleep in the weeks leading up to an important event can also make a big difference.
# dtype: object

# %%
test2 = pd.DataFrame([pd.Series(value, name=key) for key, value in qna_dict[1.3+0.001]['text1_prompt00'].items()])
# test.index = qna_dict[1.3+0.001]['text1_prompt00'].keys()
test2
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                          0
# relevance0_01_01                                                                                           For seniors who engage in physical activity, ensuring adequate sleep duration may contribute to improved performance and overall health. However, it is important to consult with a healthcare provider to determine individual sleep needs and any potential risks associated with sleep loss.
# relevance0_01_02                                                                                           For seniors who engage in physical activity, ensuring adequate sleep duration may contribute to improved performance and overall health. However, it is important to consult with a healthcare provider to determine individual sleep needs and any potential risks associated with sleep loss.
# relevance0_02_01                                                                                       For seniors who are interested in maintaining their physical fitness, this study suggests that getting enough sleep is important for optimal athletic performance. It also highlights the benefits of sleep extension interventions and strategies to improve sleep leading up to important events.
# relevance0_02_02                                                                                       For seniors who are interested in maintaining their physical fitness, this study suggests that getting enough sleep is important for optimal athletic performance. It also highlights the benefits of sleep extension interventions and strategies to improve sleep leading up to important events.
# relevance_task02                                                                                                                                                                                                                                                                                                                      Add 1-2 sentences to make this relevant for people who enjoy sports
# relevance1_01_01  If you're an athlete looking to improve your performance, getting enough sleep is crucial. Studies have shown that increasing your sleep duration can have a positive impact on your athletic abilities, especially for activities that require tactical and technical skills. So, make sure to prioritize your sleep to give yourself the best chance of success on the field or court.
# relevance1_01_02  If you're an athlete looking to improve your performance, getting enough sleep is crucial. Studies have shown that increasing your sleep duration can have a positive impact on your athletic abilities, especially for activities that require tactical and technical skills. So, make sure to prioritize your sleep to give yourself the best chance of success on the field or court.
# relevance1_02_01                                                                If you're an athlete looking to improve your performance, this study suggests that getting enough sleep is crucial. Not only can sleep extension interventions improve your technical and tactical skills, but ensuring you get enough sleep in the weeks leading up to an important event can also make a big difference.
# relevance1_02_02                                                                If you're an athlete looking to improve your performance, this study suggests that getting enough sleep is crucial. Not only can sleep extension interventions improve your technical and tactical skills, but ensuring you get enough sleep in the weeks leading up to an important event can also make a big difference.

# %% [markdown]
# # Iteration 2

# %%
import traceback
import time
# from collections import OrderedDict

class Chaining:

    def __init__(self, text):
        self.text = text

    def summarize(self, task, model="gpt-3.5-turbo", temperature=0.7, n_choices=5, max_tokens=1000,
          text_key=['text_discussion'],
        system_role = "You are an expert at science communication."
        ):
        """
        SH 2023-04-11 12:18: Same as the user-defined `reply` function, but re-written as a class method.
        Send a ChatCompletion request to ChatGPT via the Chatbot class.

        Requrired paramaters:
            - task (str): Task to include in ChatGPT prompt.
            - text (str): Text to feed to GPT for summarization.

        Optional parameters
            - system_role (str): ChatGPT parameter. 
                Default is "You are an expert at science communication."
            - temperature (float): ChatGPT parameter. Default is 0.7.
            - n_choices (int): Number of ChatGPT responses to generate. Default is 5.
            - max_tokens (int): Token limit for ChatGPT response.
            - model (str): ChatGPT model to use. Default is "gpt-3.5-turbo".
        """
        chatbot = Chatbot(self.text,
            system_role=system_role, model=model, temperature=temperature, n_choices=n_choices,
            max_tokens=max_tokens
            )
        prompt = chatbot.create_prompt(task)
        firstline_pattern = r'\s?(\S*)(\n*)(.+)'
        title = re.match(firstline_pattern, self.text)[0]
        self.qna = dict() 
        self.qna['article_title'] = title
        self.qna['system_role'] = system_role
        self.qna['prompt'] = task
        self.qna['model'] = model
        self.summaries_dict = dict()
        self.article_title = title

        try:
            response = chatbot.gpt(prompt)
        except:
            print('\t**API request failed**')
            return self.qna
        try:
            for index, choice in enumerate(response.choices):
                self.qna[f'response_{"{:02d}".format(index+1)}'] = choice["message"]["content"]
                self.summaries_dict[f'response_{"{:02d}".format(index+1)}'] = choice["message"]["content"]
            self.qna[f'text'] = self.text
            return self.qna
        except:
            print('\t**Error with response parsing**')
            return self.qna


    def simplify(self, simplify_task, system_role='You are an expert at science communication.',
                    model="gpt-3.5-turbo", temperature=0.0, n_choices=1, max_tokens=1000, 
                    simplify_iteration=None
                    ):
        self.simplify_bot_dict = dict()
        self.simple_summary_dict = dict()
        for key, summary in self.summaries_dict.items():
            new_key = re.sub(r'response', rf'simple_summary{str(simplify_iteration)}', key)
            print(f'\t\t...Preparing to summarize {key}')
            self.simplify_bot_dict[new_key] = Chatbot(
                summary, system_role=system_role,
                model=model, temperature=temperature, n_choices=n_choices, max_tokens=max_tokens
                )
            simplify_prompt = self.simplify_bot_dict[new_key].create_prompt(simplify_task)
            try:
                self.simple_summary_dict[new_key] = self.simplify_bot_dict[new_key].gpt(simplify_prompt).choices[0]["message"]["content"]
                print(f'\t...Summary given')
            except:
                self.simple_summary_dict[new_key] = self.simplify_bot_dict[new_key].gpt(simplify_prompt)
                print(f'\t...Error parsing response for summary request')
        self.simple_summary_dict['simplify_task'] = simplify_task
        self.qna = {**self.qna, **self.simple_summary_dict}
        try:
            self.qna.update({'text': self.qna.pop('text')})
        except:
            pass
        return self.simple_summary_dict
    
    def add_relevance(self, task, system_role='You are an expert at science communication.',
                    model="gpt-3.5-turbo", temperature=0.0, n_choices=1, max_tokens=1000, 
                    relevance_iteration=None, pause_per_request=20
                    ):
        self.relevance_bot_dict = dict()
        self.relevance_dict = dict()
        if relevance_iteration == None:
            relevance_iteration = 1
        for key, summary in self.summaries_dict.items():
            new_key = re.sub(r'response', rf'relevance{str(relevance_iteration)}', key)
            print(f'\t\t...Preparing to summarize {key}')
            self.relevance_bot_dict[new_key] = Chatbot(
                summary, system_role=system_role,
                model=model, temperature=temperature, n_choices=n_choices, max_tokens=max_tokens
                )
            relevance_prompt = self.relevance_bot_dict[new_key].create_prompt(task)
            try:
                for index, choice in enumerate(self.relevance_bot_dict[new_key].gpt(relevance_prompt).choices):
                    self.relevance_dict[f'{new_key}_{"{:02d}".format(index+1)}'] = choice["message"]["content"]
                    print(f'\t...Relevance given')
            except:
                try:
                    self.relevance_dict[new_key] = self.relevance_bot_dict[new_key].gpt(relevance_prompt).choices[0]["message"]["content"]
                    print(f'\t...First relevance response given')
                except:
                    self.relevance_dict[new_key] = self.relevance_bot_dict[new_key].gpt(relevance_prompt)
                    print(f'\t...Error parsing response for added relevance request')
            print(f'[add_relevance method] Sleeping {pause_per_request} sec to avoid exceeding API rate limit')
            time.sleep(pause_per_request) # Account for API rate limit of 3 API requests/limit 
        self.relevance_dict[f'relevance_task{"{:02d}".format(relevance_iteration)}'] = task
        self.qna = {**self.qna, **self.relevance_dict}
        try:
            self.qna.update({'text': self.qna.pop('text')})
        except:
            pass
        return self.relevance_dict

def batch_summarize_chain(text_dict, prompts_df, qna_dict,  chaining_bot_dict, iteration_id, n_choices=5,
    prompt_column='prompt',
    save_outputs=False, filename=None, append_version=False,
    csv_path=r'C:\Users\silvh\OneDrive\lighthouse\Ginkgo coding\content-summarization\output',
    pickle_path=r'C:\Users\silvh\OneDrive\lighthouse\Ginkgo coding\content-summarization\output\pickles'
    ):
    """
    Summarize multiple texts using the same prompts.
    Parameters:
        - prompts_df: DataFrame containing the prompts.
        - qna_dict: Dictionary to store the input and outputs.
        - iteration_id (int, float, or string): Unique ID serving as the key for results in the qna_dict
        - prompt_column (str): Name of the column in the prompts_df containing the user input.

    """
    temp_qna_dict = dict()
    prompts_df = prompts_df.reset_index(drop=True)
    qna_dfs_list = []
    chaining_bot_dict[iteration_id] = dict()
    for key in text_dict:
        text = text_dict[key]
        temp_qna_dict[key] = dict()
        for index, input in prompts_df[prompt_column].items():
            print(f'**Text #{key} prompt #{index} of {prompts_df.index.max()}**')
            try:
                chatbot = Chaining(text)
                temp_qna_dict[key][index] = chatbot.summarize(input, n_choices=n_choices)
                chatbot_dict[iteration_id][f'text{key}_prompt{"{:02d}".format(index)}'] = chatbot
                print('\t...Success!')
            except:
                print('\t...Error making chatbot request')
                break
        try:
            prompts_df = prompts_df.drop(prompt_column)
        except:
            pass
        try:
            updated_qna_dict = pd.concat([
                pd.DataFrame(temp_qna_dict[key]),
                prompts_df.transpose()
            ])
        except Exception as error:
            exc_type, exc_obj, tb = sys.exc_info()
            f = tb.tb_frame
            lineno = tb.tb_lineno
            filename = f.f_code.co_filename
            print("An error occurred on line", lineno, "in", filename, ":", error)
            print('Error concatenating prompts DataFrame')
            return temp_qna_dict, chatbot_dict
        try:
            qna_dfs_list.append(updated_qna_dict)
            qna_dict[iteration_id] = pd.concat(qna_dfs_list, axis=1)
            if save_outputs:
                try:
                    append_version = append_version if filename else False
                    filename = filename if filename else f'{datetime.now().strftime("%Y-%m-%d_%H%M")}_prompt_experiments_{"{:02d}".format(iteration_id)}'
                    savepickle(qna_dict[iteration_id], filename=filename, path=pickle_path, append_version=append_version)
                    save_csv(qna_dict[iteration_id], filename=filename, path=pickle_path, append_version=append_version)
                except:
                    print('Unable to save outputs')
        except:
            print('Error concatenating DataFrames')
    return qna_dict, chatbot_dict

def prompt_chaining_dict(simplify_prompts, qna_chain_dict, chaining_bot_dict, iteration_id,
    summary_iteration_id=None, n_choices=None, pause_per_request=20,
    prompt_column='simplify', simplify_iteration=None
    ):
    """
    Simplify or add context to a summary.
    """
    summary_iteration_id = summary_iteration_id if summary_iteration_id else iteration_id
    print('summary_iteration_id:', summary_iteration_id)
    if n_choices == None:
        n_choices = 1 if prompt_column == 'simplify' else 5
    print('n_choices:', n_choices)
    simple_summaries_dict = dict()
    if type(simplify_prompts) == str:
        simplify_prompts = [simplify_prompts]
    elif type(simplify_prompts) == pd.core.frame.DataFrame:
        simplify_prompts = [prompt for prompt in simplify_prompts[prompt_column].unique() if len(prompt) >1]
    else:
        simplify_prompts = list(set([prompt for prompt in simplify_prompts if len(prompt) >1]))
    simple_summaries_master_dict = dict()
    simple_summaries_df = pd.DataFrame()
    for column, text_prompt_key in enumerate(chaining_bot_dict):
        print(f'**{text_prompt_key}')
        simple_summaries_master_dict[text_prompt_key] = dict()

        for index, prompt in enumerate(simplify_prompts):
            relevance_iteration=index if len(simplify_prompts) > 1 else simplify_iteration
            print(f'\t...Prompt: {prompt}, iteration {relevance_iteration}')
            # simple_summaries_dict[index] = dict()
            if prompt_column == 'simplify':
                summary_dict = chaining_bot_dict[text_prompt_key].simplify(
                    prompt, n_choices=n_choices,
                    simplify_iteration=index if len(simplify_prompts) > 1 else simplify_iteration
                    )
                simple_summaries_master_dict[text_prompt_key].append(summary_dict)
            else: 
                summary_dict = chaining_bot_dict[text_prompt_key].add_relevance(
                    prompt, n_choices=n_choices, pause_per_request=pause_per_request, 
                    relevance_iteration=index if len(simplify_prompts) > 1 else simplify_iteration
                    )
            simple_summaries_master_dict[text_prompt_key] = {**simple_summaries_master_dict[text_prompt_key], **summary_dict}
        simple_summaries_df[column] = pd.concat([
            pd.Series(value) for value in simple_summaries_master_dict[text_prompt_key]
        ])   
    # qna_dict[iteration_id] = simple_summaries_master_dict
    # return qna_dict
    try:
        qna_chain_dict[summary_iteration_id].columns = [i for i in range(len(qna_chain_dict[summary_iteration_id].columns))]
        
        # simple_summaries_df = pd.concat([pd.DataFrame(value) for key, value in simple_summaries_master_dict.items()])
        # simple_summaries_df.columns = [i for i in range(simple_summaries_df.shape[1])]
        temp_qna_chain_dict = pd.concat([
            qna_chain_dict[summary_iteration_id], 
            simple_summaries_df
            ])
        qna_chain_dict[iteration_id] = temp_qna_chain_dict
        print(f"{'Simple summaries' if prompt_column=='simplify' else 'Article relevance for user'} added to original DataFrame")
    except Exception as error:
        exc_type, exc_obj, tb = sys.exc_info()
        f = tb.tb_frame
        lineno = tb.tb_lineno
        filename = f.f_code.co_filename
        print("An error occurred on line", lineno, "in", filename, ":", error)
        print('Unable to concatenate simple summary DataFrame to original DataFrame')
        qna_chain_dict[iteration_id+0.001] = simple_summaries_master_dict

    return qna_chain_dict

iteration_id = 2
n_choices = 2
# qna_dict = dict()
# qna_chain_dict = dict()
# chatbot_dict = dict()

qna_dict, chaining_dict = batch_summarize_chain(text_dict, prompts_df, qna_dict, chatbot_dict, 
    iteration_id=iteration_id, n_choices=n_choices)

# simplify_prompts = task_part2
# qna_dict = simplify_chaining_dict(simplify_prompts, qna_dict, chaining_dict[iteration_id], iteration_id,
#     simplify_iteration=1, summary_iteration_id=None
#     )



# summary_iteration_id = iteration_id
# # summary_iteration_id = 1
# n_choices = 2
# relevance_prompts = relevance_prompts_df
# pause_per_request=None
# qna_dict = prompt_chaining_dict(relevance_prompts, qna_dict, chaining_dict[summary_iteration_id], iteration_id,
#     prompt_column='relevance', n_choices=n_choices, pause_per_request=pause_per_request,
#     simplify_iteration=2, summary_iteration_id=summary_iteration_id
#     )
# Out:
# **Text #1 prompt #0 of 1**
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Success!
# **Text #1 prompt #1 of 1**
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Success!
# **Text #2 prompt #0 of 1**
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Success!
# **Text #2 prompt #1 of 1**
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Success!

# %%
qna_dict[iteration_id]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# article_title                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# system_role                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# prompt                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# model                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# response_01                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# response_02                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# text           The Impact of Sleep Duration on Performance Among Competitive Athletes: A Systematic Literature Review\n\nDISCUSSION \nThis literature review, although diverse in the range of sports, methods, and outcomes studied, provides several stylized facts that can inform sleep research and competitive athletes. First, out of all the published studies we reviewed, none found a negative association between sleep duration and any performance outcome. All of the results reviewed showed that either the increased sleep duration has a positive effect on athletic performance or the results were neutral. Note that among studies reporting significant positive results, effect sizes varied considerably (Tables 2-4), likely due to differences in the duration of sleep deprivation/extension experienced as well as differences in outcome measures. Second, when considering the aerobic and anaerobic characteristics of sports, it seems that aerobic activity is more sensitive to sleep duration compared to anaerobic activity, including strength testing. For instance, Mejri et al40 found that depriving competitive taekwondo boxers of a mere 3 to 4 hours of sleep significantly impaired performance on the Yo-Yo intermittent recovery test. By contrast, Blumert et al33 employed a relatively severe sleep deprivation protocol by depriving 9 national-caliber collegiate weightlifters of 24 hours of sleep and yet failed to identify adverse effects on any of the various weightlifting exercises examined. Relatedly, for both endurance and explosive, power-based exercises, it has been well documented that sleep deprivation is associated with increased perceived effort.56–58 Still, the relationship between perceived effort and objective performance has not been widely validated and is a topic for future investigation. Third, of the studies that measured outcomes requiring either tactical and/or technical skills, most find benefits of sleep on performance. Tennis serving accuracy and basketball shooting were both improved by long-term sleep extension interventions,35,39 and tennis serving accuracy suffered when players were deprived of 2 to 2.5 hours of sleep at the beginning of the preceding night.37 Regarding studies conducted in players of team sports that incorporated tactics and decision-based outcomes to a broader extent, soccer as well as rugby players exhibited performance deficits after nights of decreased sleep duration.34 These results are in line with other literature demonstrating clear neurocognitive deficits in the setting of inadequate sleep in the general population, reviewed thoroughly elsewhere.59,60 Finally, when looking at the methodologies of the experimental studies, we found that the studies that altered sleep duration on a longer-term timescale were more likely to show an effect than those that altered sleep duration acutely. Interestingly although most acute sleep interventions involved sleep deprivation and yielded positive results, there were inconsistent results among the 2 acute sleep extension studies.15,38 Conversely, the majority of longer-term sleep intervention studies involved sleep extension and showed positive results.35,39,49 Taken together, these findings suggest that on a short timescale, sleep deprivation may be more harmful than sleep extension is beneficial to performance, although in the longer term, sleep extension may contribute to improved performance. On the other hand, more research is warranted regarding potential adverse effects of chronic sleep loss on athletic performance. The reliability and precision of the various measurements may present challenges in interpretation of these studies. For example, “maximal” voluntary muscle contraction and voluntarily chosen training load are variable across subjects.61,62 On the other hand, “running economy,” the oxygen cost associated with a given running velocity, has low variability among highly trained runners and is significantly correlated with cardiorespiratory ...
# prep_step                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# task part 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# prompt                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
#
# ...
# prep_step                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# task part 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# prompt                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...

# %%
summary_iteration_id = iteration_id
# summary_iteration_id = 1
n_choices = 2
relevance_prompts = relevance_prompts_df
pause_per_request=20
qna_dict = prompt_chaining_dict(relevance_prompts, qna_dict, chaining_dict[summary_iteration_id], iteration_id,
    prompt_column='relevance', n_choices=n_choices, pause_per_request=pause_per_request,
    simplify_iteration=2, summary_iteration_id=summary_iteration_id
    )
# Out:
# summary_iteration_id: 2
# n_choices: 2
# **text1_prompt00
# 	...Prompt:  Add 1-2 sentences to make this relevant for seniors , iteration 0
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 	...Prompt:  Add 1-2 sentences to make this relevant for people who enjoy sports , iteration 1
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# **text1_prompt01
# 	...Prompt:  Add 1-2 sentences to make this relevant for seniors , iteration 0
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 	...Prompt:  Add 1-2 sentences to make this relevant for people who enjoy sports , iteration 1
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# **text2_prompt00
# 	...Prompt:  Add 1-2 sentences to make this relevant for seniors , iteration 0
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 	...Prompt:  Add 1-2 sentences to make this relevant for people who enjoy sports , iteration 1
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# **text2_prompt01
# 	...Prompt:  Add 1-2 sentences to make this relevant for seniors , iteration 0
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 	...Prompt:  Add 1-2 sentences to make this relevant for people who enjoy sports , iteration 1
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# Article relevance for user added to original DataFrame

# %%
qna_dict[iteration_id].tail(10)
# Out:
#                   0                 1                 2                 3
# 0  relevance0_01_01  relevance0_01_01  relevance0_01_01  relevance0_01_01
# 0  relevance0_01_02  relevance0_01_02  relevance0_01_02  relevance0_01_02
# 0  relevance0_02_01  relevance0_02_01  relevance0_02_01  relevance0_02_01
# 0  relevance0_02_02  relevance0_02_02  relevance0_02_02  relevance0_02_02
# 0  relevance_task00  relevance_task00  relevance_task00  relevance_task00
# 0  relevance1_01_01  relevance1_01_01  relevance1_01_01  relevance1_01_01
# 0  relevance1_01_02  relevance1_01_02  relevance1_01_02  relevance1_01_02
# 0  relevance1_02_01  relevance1_02_01  relevance1_02_01  relevance1_02_01
# 0  relevance1_02_02  relevance1_02_02  relevance1_02_02  relevance1_02_02
# 0  relevance_task01  relevance_task01  relevance_task01  relevance_task01

# %%
qna_dict[iteration_id] = qna_dict[iteration_id].head(10)

# %%
chatbot_dict[iteration_id]['text1_prompt00'].qna
# Out:
# {'article_title': 'The Impact of Sleep Duration on Performance Among Competitive Athletes: A Systematic Literature Review',
#  'system_role': 'You are an expert at science communication.',
#  'prompt': 'Take the key points and numerical descriptors to Summarize for a LinkedIn post.',
#  'model': 'gpt-3.5-turbo',
#  'response_01': 'A systematic literature review found that increased sleep duration has a positive effect on athletic performance, with no negative associations found. Aerobic activity is more sensitive to sleep duration compared to anaerobic activity. Studies that altered sleep duration on a longer-term timescale were more likely to show an effect than those that altered sleep duration acutely. Strategies to improve sleep not only the night before an important sports event but also in the weeks leading up to the event are likely to be fruitful in improving performance. The review provides valuable information about when sleep does or particularly when sleep does not seem to play a key role in influencing performance.',
#  'response_02': 'Summary for a LinkedIn post:\nA systematic literature review on the impact of sleep duration on performance among competitive athletes showed that increased sleep duration has a positive effect on athletic performance or the results were neutral. Aerobic activity is more sensitive to sleep duration compared to anaerobic activity. The studies that altered sleep duration on a longer-term timescale were more likely to show an effect than those that altered sleep duration acutely. Studies that measured outcomes requiring either tactical and/or technical skills found benefits of sleep on performance. The study provides valuable information about when sleep does or particularly when sleep does not seem to play a key role in influencing performance. Future research may seek to use larger sample sizes and standardize tests of athletic performance in order to identify optimal sleep standards, in addition to standardizing sleep metrics and incorporating more objective sleep data.',
#  'relevance0_01_01': 'For seniors who are involved in athletic activities, it is important to prioritize getting enough sleep as it has been found to have a positive impact on athletic performance. This review suggests that implementing strategies to improve sleep in the weeks leading up to an event can be particularly beneficial.',
#  'relevance0_01_02': 'For seniors who are involved in athletic activities, it is important to prioritize getting enough sleep as it has been found to have a positive impact on athletic performance. This review suggests that implementing strategies to improve sleep in the weeks leading up to an event can be particularly beneficial.',
#  'relevance0_02_01': 'For seniors who are still active in sports or exercise, this study highlights the importance of getting enough sleep for optimal performance. It suggests that longer-term changes in sleep habits may have a greater impact on performance than short-term changes, and that sleep may be especially important for activities that require tactical or technical skills.',
#  'relevance0_02_02': 'For seniors who are still active in sports or exercise, this study highlights the importance of getting enough sleep for optimal performance. It suggests that longer-term changes in sleep habits may have a greater impact on performance than short-term changes, and that sleep may be especially important for activities that require tactical or technical skills.',
#  'relevance_task00': ' Add 1-2 sentences to make this relevant for seniors ',
#  'relevance1_01_01': "If you're an athlete looking to improve your performance, this review suggests that getting enough sleep is crucial. Not only should you prioritize getting a good night's sleep before a big event, but also make sure to consistently prioritize sleep in the weeks leading up to it.",
#  'relevance1_01_02': "If you're an athlete looking to improve your performance, this review suggests that getting enough sleep is crucial. Not only should you prioritize getting a good night's sleep before a big event, but also make sure to consistently prioritize sleep in the weeks leading up to it.",
#  'relevance1_02_01': "If you're an athlete looking to improve your performance, this study suggests that getting enough sleep is crucial. Whether you're a runner, swimmer, or weightlifter, ensuring you get enough sleep can help you perform better and achieve your goals.",
#  'relevance1_02_02': "If you're an athlete looking to improve your performance, this study suggests that getting enough sleep is crucial. Whether you're a runner, swimmer, or weightlifter, ensuring you get enough sleep can help you perform better and achieve your goals.",
#  'relevance_task01': ' Add 1-2 sentences to make this relevant for people who enjoy sports ',
#  'text': 'The Impact of Sleep Duration on Performance Among Competitive Athletes: A Systematic Literature Review\n\nDISCUSSION \nThis literature review, although diverse in the range of sports, methods, and outcomes studied, provides several stylized facts that can inform sleep research and competitive athletes. First, out of all the published studies we reviewed, none found a negative association between sleep duration and any performance outcome. All of the results reviewed showed that either the increased sleep duration has a positive effect on athletic performance or the results were neutral. Note that among studies reporting significant positive results, effect sizes varied considerably (Tables 2-4), likely due to differences in the duration of sleep deprivation/extension experienced as well as differences in outcome measures. Second, when considering the aerobic and anaerobic characteristics of sports, it seems that aerobic activity is more sensitive to sleep duration compared to anaerobic activity, including strength testing. For instance, Mejri et al40 found that depriving competitive taekwondo boxers of a mere 3 to 4 hours of sleep significantly impaired performance on the Yo-Yo intermittent recovery test. By contrast, Blumert et al33 employed a relatively severe sleep deprivation protocol by depriving 9 national-caliber collegiate weightlifters of 24 hours of sleep and yet failed to identify adverse effects on any of the various weightlifting exercises examined. Relatedly, for both endurance and explosive, power-based exercises, it has been well documented that sleep deprivation is associated with increased perceived effort.56–58 Still, the relationship between perceived effort and objective performance has not been widely validated and is a topic for future investigation. Third, of the studies that measured outcomes requiring either tactical and/or technical skills, most find benefits of sleep on performance. Tennis serving accuracy and basketball shooting were both improved by long-term sleep extension interventions,35,39 and tennis serving accuracy suffered when players were deprived of 2 to 2.5 hours of sleep at the beginning of the preceding night.37 Regarding studies conducted in players of team sports that incorporated tactics and decision-based outcomes to a broader extent, soccer as well as rugby players exhibited performance deficits after nights of decreased sleep duration.34 These results are in line with other literature demonstrating clear neurocognitive deficits in the setting of inadequate sleep in the general population, reviewed thoroughly elsewhere.59,60 Finally, when looking at the methodologies of the experimental studies, we found that the studies that altered sleep duration on a longer-term timescale were more likely to show an effect than those that altered sleep duration acutely. Interestingly although most acute sleep interventions involved sleep deprivation and yielded positive results, there were inconsistent results among the 2 acute sleep extension studies.15,38 Conversely, the majority of longer-term sleep intervention studies involved sleep extension and showed positive results.35,39,49 Taken together, these findings suggest that on a short timescale, sleep deprivation may be more harmful than sleep extension is beneficial to performance, although in the longer term, sleep extension may contribute to improved performance. On the other hand, more research is warranted regarding potential adverse effects of chronic sleep loss on athletic performance. The reliability and precision of the various measurements may present challenges in interpretation of these studies. For example, “maximal” voluntary muscle contraction and voluntarily chosen training load are variable across subjects.61,62 On the other hand, “running economy,” the oxygen cost associated with a given running velocity, has low variability among highly trained runners and is significantly correlated with cardiorespiratory para ...

# %% [markdown]
# ## 2.1

# %%
import traceback
import time
# from collections import OrderedDict

class Chaining:

    def __init__(self, text):
        self.text = text

    def summarize(self, task, model="gpt-3.5-turbo", temperature=0.7, n_choices=5, max_tokens=1000,
          text_key=['text_discussion'],
        system_role = "You are an expert at science communication."
        ):
        """
        SH 2023-04-11 12:18: Same as the user-defined `reply` function, but re-written as a class method.
        Send a ChatCompletion request to ChatGPT via the Chatbot class.

        Requrired paramaters:
            - task (str): Task to include in ChatGPT prompt.
            - text (str): Text to feed to GPT for summarization.

        Optional parameters
            - system_role (str): ChatGPT parameter. 
                Default is "You are an expert at science communication."
            - temperature (float): ChatGPT parameter. Default is 0.7.
            - n_choices (int): Number of ChatGPT responses to generate. Default is 5.
            - max_tokens (int): Token limit for ChatGPT response.
            - model (str): ChatGPT model to use. Default is "gpt-3.5-turbo".
        """
        chatbot = Chatbot(self.text,
            system_role=system_role, model=model, temperature=temperature, n_choices=n_choices,
            max_tokens=max_tokens
            )
        prompt = chatbot.create_prompt(task)
        firstline_pattern = r'\s?(\S*)(\n*)(.+)'
        title = re.match(firstline_pattern, self.text)[0]
        self.qna = dict() 
        self.qna['article_title'] = title
        self.qna['system_role'] = system_role
        self.qna['prompt'] = task
        self.qna['model'] = model
        self.summaries_dict = dict()
        self.article_title = title

        try:
            response = chatbot.gpt(prompt)
        except:
            print('\t**API request failed**')
            return self.qna
        try:
            for index, choice in enumerate(response.choices):
                self.qna[f'response_{"{:02d}".format(index+1)}'] = choice["message"]["content"]
                self.summaries_dict[f'response_{"{:02d}".format(index+1)}'] = choice["message"]["content"]
            self.qna[f'text'] = self.text
            return self.qna
        except:
            print('\t**Error with response parsing**')
            return self.qna


    def simplify(self, simplify_task, system_role='You are an expert at science communication.',
                    model="gpt-3.5-turbo", temperature=0.0, n_choices=1, max_tokens=1000, 
                    simplify_iteration=None
                    ):
        self.simplify_bot_dict = dict()
        self.simple_summary_dict = dict()
        for key, summary in self.summaries_dict.items():
            new_key = re.sub(r'response', rf'simple_summary{str(simplify_iteration)}', key)
            print(f'\t\t...Preparing to summarize {key}')
            self.simplify_bot_dict[new_key] = Chatbot(
                summary, system_role=system_role,
                model=model, temperature=temperature, n_choices=n_choices, max_tokens=max_tokens
                )
            simplify_prompt = self.simplify_bot_dict[new_key].create_prompt(simplify_task)
            try:
                self.simple_summary_dict[new_key] = self.simplify_bot_dict[new_key].gpt(simplify_prompt).choices[0]["message"]["content"]
                print(f'\t...Summary given')
            except:
                self.simple_summary_dict[new_key] = self.simplify_bot_dict[new_key].gpt(simplify_prompt)
                print(f'\t...Error parsing response for summary request')
        self.simple_summary_dict['simplify_task'] = simplify_task
        self.qna = {**self.qna, **self.simple_summary_dict}
        try:
            self.qna.update({'text': self.qna.pop('text')})
        except:
            pass
        return self.simple_summary_dict
    
    def add_relevance(self, task, system_role='You are an expert at science communication.',
                    model="gpt-3.5-turbo", temperature=0.0, n_choices=1, max_tokens=1000, 
                    relevance_iteration=None, pause_per_request=20
                    ):
        self.relevance_bot_dict = dict()
        self.relevance_dict = dict()
        if relevance_iteration == None:
            relevance_iteration = 1
        for key, summary in self.summaries_dict.items():
            new_key = re.sub(r'response', rf'relevance{str(relevance_iteration)}', key)
            print(f'\t\t...Preparing to summarize {key}')
            self.relevance_bot_dict[new_key] = Chatbot(
                summary, system_role=system_role,
                model=model, temperature=temperature, n_choices=n_choices, max_tokens=max_tokens
                )
            relevance_prompt = self.relevance_bot_dict[new_key].create_prompt(task)
            try:
                for index, choice in enumerate(self.relevance_bot_dict[new_key].gpt(relevance_prompt).choices):
                    self.relevance_dict[f'{new_key}_{"{:02d}".format(index+1)}'] = choice["message"]["content"]
                    print(f'\t...Relevance given')
            except:
                try:
                    self.relevance_dict[new_key] = self.relevance_bot_dict[new_key].gpt(relevance_prompt).choices[0]["message"]["content"]
                    print(f'\t...First relevance response given')
                except:
                    self.relevance_dict[new_key] = self.relevance_bot_dict[new_key].gpt(relevance_prompt)
                    print(f'\t...Error parsing response for added relevance request')
            print(f'[add_relevance method] Sleeping {pause_per_request} sec to avoid exceeding API rate limit')
            time.sleep(pause_per_request) # Account for API rate limit of 3 API requests/limit 
        self.relevance_dict[f'relevance_task{"{:02d}".format(relevance_iteration)}'] = task
        self.qna = {**self.qna, **self.relevance_dict}
        try:
            self.qna.update({'text': self.qna.pop('text')})
        except:
            pass
        return self.relevance_dict

def batch_summarize_chain(text_dict, prompts_df, qna_dict,  chaining_bot_dict, iteration_id, n_choices=5,
    prompt_column='prompt',
    save_outputs=False, filename=None, append_version=False,
    csv_path=r'C:\Users\silvh\OneDrive\lighthouse\Ginkgo coding\content-summarization\output',
    pickle_path=r'C:\Users\silvh\OneDrive\lighthouse\Ginkgo coding\content-summarization\output\pickles'
    ):
    """
    Summarize multiple texts using the same prompts.
    Parameters:
        - prompts_df: DataFrame containing the prompts.
        - qna_dict: Dictionary to store the input and outputs.
        - iteration_id (int, float, or string): Unique ID serving as the key for results in the qna_dict
        - prompt_column (str): Name of the column in the prompts_df containing the user input.

    """
    temp_qna_dict = dict()
    prompts_df = prompts_df.reset_index(drop=True)
    qna_dfs_list = []
    chaining_bot_dict[iteration_id] = dict()
    for key in text_dict:
        text = text_dict[key]
        temp_qna_dict[key] = dict()
        for index, input in prompts_df[prompt_column].items():
            print(f'**Text #{key} prompt #{index} of {prompts_df.index.max()}**')
            try:
                chatbot = Chaining(text)
                temp_qna_dict[key][index] = chatbot.summarize(input, n_choices=n_choices)
                chatbot_dict[iteration_id][f'text{key}_prompt{"{:02d}".format(index)}'] = chatbot
                print('\t...Success!')
            except:
                print('\t...Error making chatbot request')
                break
        try:
            prompts_df = prompts_df.drop(prompt_column)
        except:
            pass
        try:
            updated_qna_dict = pd.concat([
                pd.DataFrame(temp_qna_dict[key]),
                prompts_df.transpose()
            ])
        except Exception as error:
            exc_type, exc_obj, tb = sys.exc_info()
            f = tb.tb_frame
            lineno = tb.tb_lineno
            filename = f.f_code.co_filename
            print("An error occurred on line", lineno, "in", filename, ":", error)
            print('Error concatenating prompts DataFrame')
            return temp_qna_dict, chatbot_dict
        try:
            qna_dfs_list.append(updated_qna_dict)
            qna_dict[iteration_id] = pd.concat(qna_dfs_list, axis=1)
            if save_outputs:
                try:
                    append_version = append_version if filename else False
                    filename = filename if filename else f'{datetime.now().strftime("%Y-%m-%d_%H%M")}_prompt_experiments_{"{:02d}".format(iteration_id)}'
                    savepickle(qna_dict[iteration_id], filename=filename, path=pickle_path, append_version=append_version)
                    save_csv(qna_dict[iteration_id], filename=filename, path=pickle_path, append_version=append_version)
                except:
                    print('Unable to save outputs')
        except:
            print('Error concatenating DataFrames')
    return qna_dict, chatbot_dict

def prompt_chaining_dict(simplify_prompts, qna_chain_dict, chaining_bot_dict, iteration_id,
    summary_iteration_id=None, n_choices=None, pause_per_request=20,
    prompt_column='simplify', simplify_iteration=None
    ):
    """
    Simplify or add context to a summary.
    """
    summary_iteration_id = summary_iteration_id if summary_iteration_id else iteration_id
    print('summary_iteration_id:', summary_iteration_id)
    if n_choices == None:
        n_choices = 1 if prompt_column == 'simplify' else 5
    print('n_choices:', n_choices)
    simple_summaries_dict = dict()
    if type(simplify_prompts) == str:
        simplify_prompts = [simplify_prompts]
    elif type(simplify_prompts) == pd.core.frame.DataFrame:
        simplify_prompts = [prompt for prompt in simplify_prompts[prompt_column].unique() if len(prompt) >1]
    else:
        simplify_prompts = list(set([prompt for prompt in simplify_prompts if len(prompt) >1]))
    simple_summaries_master_dict = dict()
    simple_summaries_df = pd.DataFrame()
    for column, text_prompt_key in enumerate(chaining_bot_dict):
        print(f'**{text_prompt_key}')
        simple_summaries_master_dict[text_prompt_key] = dict()

        for index, prompt in enumerate(simplify_prompts):
            relevance_iteration=index if len(simplify_prompts) > 1 else simplify_iteration
            print(f'\t...Prompt: {prompt}, iteration {relevance_iteration}')
            # simple_summaries_dict[index] = dict()
            if prompt_column == 'simplify':
                summary_dict = chaining_bot_dict[text_prompt_key].simplify(
                    prompt, n_choices=n_choices,
                    simplify_iteration=index if len(simplify_prompts) > 1 else simplify_iteration
                    )
                simple_summaries_master_dict[text_prompt_key].append(summary_dict)
            else: 
                summary_dict = chaining_bot_dict[text_prompt_key].add_relevance(
                    prompt, n_choices=n_choices, pause_per_request=pause_per_request, 
                    relevance_iteration=index if len(simplify_prompts) > 1 else simplify_iteration
                    )
            simple_summaries_master_dict[text_prompt_key] = {**simple_summaries_master_dict[text_prompt_key], **summary_dict}
        simple_summaries_df[column] = pd.concat([
            pd.Series(value) for key, value in simple_summaries_master_dict[text_prompt_key].items()
        ])   
    # qna_dict[iteration_id] = simple_summaries_master_dict
    # return qna_dict
    try:
        qna_chain_dict[summary_iteration_id].columns = [i for i in range(len(qna_chain_dict[summary_iteration_id].columns))]
        
        # simple_summaries_df = pd.concat([pd.DataFrame(value) for key, value in simple_summaries_master_dict.items()])
        # simple_summaries_df.columns = [i for i in range(simple_summaries_df.shape[1])]
        temp_qna_chain_dict = pd.concat([
            qna_chain_dict[summary_iteration_id], 
            simple_summaries_df
            ])
        qna_chain_dict[iteration_id] = temp_qna_chain_dict
        print(f"{'Simple summaries' if prompt_column=='simplify' else 'Article relevance for user'} added to original DataFrame")
    except Exception as error:
        exc_type, exc_obj, tb = sys.exc_info()
        f = tb.tb_frame
        lineno = tb.tb_lineno
        filename = f.f_code.co_filename
        print("An error occurred on line", lineno, "in", filename, ":", error)
        print('Unable to concatenate simple summary DataFrame to original DataFrame')
        qna_chain_dict[iteration_id+0.001] = simple_summaries_master_dict

    return qna_chain_dict

iteration_id = 2.1
n_choices = 2
# qna_dict = dict()
# qna_chain_dict = dict()
# chatbot_dict = dict()

# qna_dict, chaining_dict = batch_summarize_chain(text_dict, prompts_df, qna_dict, chatbot_dict, 
#     iteration_id=iteration_id, n_choices=n_choices)

# simplify_prompts = task_part2
# qna_dict = simplify_chaining_dict(simplify_prompts, qna_dict, chaining_dict[iteration_id], iteration_id,
#     simplify_iteration=1, summary_iteration_id=None
#     )



# summary_iteration_id = iteration_id
summary_iteration_id = 2
n_choices = 2
relevance_prompts = relevance_prompts_df
pause_per_request=20
qna_dict = prompt_chaining_dict(relevance_prompts, qna_dict, chaining_dict[summary_iteration_id], iteration_id,
    prompt_column='relevance', n_choices=n_choices, pause_per_request=pause_per_request,
    simplify_iteration=2, summary_iteration_id=summary_iteration_id
    )
# Out:
# summary_iteration_id: 2
# n_choices: 2
# **text1_prompt00
# 	...Prompt:  Add 1-2 sentences to make this relevant for seniors , iteration 0
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 	...Prompt:  Add 1-2 sentences to make this relevant for people who enjoy sports , iteration 1
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# **text1_prompt01
# 	...Prompt:  Add 1-2 sentences to make this relevant for seniors , iteration 0
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 	...Prompt:  Add 1-2 sentences to make this relevant for people who enjoy sports , iteration 1
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# **text2_prompt00
# 	...Prompt:  Add 1-2 sentences to make this relevant for seniors , iteration 0
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 	...Prompt:  Add 1-2 sentences to make this relevant for people who enjoy sports , iteration 1
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# **text2_prompt01
# 	...Prompt:  Add 1-2 sentences to make this relevant for seniors , iteration 0
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 	...Prompt:  Add 1-2 sentences to make this relevant for people who enjoy sports , iteration 1
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# Article relevance for user added to original DataFrame

# %%
qna_dict[iteration_id]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# article_title                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# system_role                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# prompt                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# model                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# response_01                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# response_02                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# text           The Impact of Sleep Duration on Performance Among Competitive Athletes: A Systematic Literature Review\n\nDISCUSSION \nThis literature review, although diverse in the range of sports, methods, and outcomes studied, provides several stylized facts that can inform sleep research and competitive athletes. First, out of all the published studies we reviewed, none found a negative association between sleep duration and any performance outcome. All of the results reviewed showed that either the increased sleep duration has a positive effect on athletic performance or the results were neutral. Note that among studies reporting significant positive results, effect sizes varied considerably (Tables 2-4), likely due to differences in the duration of sleep deprivation/extension experienced as well as differences in outcome measures. Second, when considering the aerobic and anaerobic characteristics of sports, it seems that aerobic activity is more sensitive to sleep duration compared to anaerobic activity, including strength testing. For instance, Mejri et al40 found that depriving competitive taekwondo boxers of a mere 3 to 4 hours of sleep significantly impaired performance on the Yo-Yo intermittent recovery test. By contrast, Blumert et al33 employed a relatively severe sleep deprivation protocol by depriving 9 national-caliber collegiate weightlifters of 24 hours of sleep and yet failed to identify adverse effects on any of the various weightlifting exercises examined. Relatedly, for both endurance and explosive, power-based exercises, it has been well documented that sleep deprivation is associated with increased perceived effort.56–58 Still, the relationship between perceived effort and objective performance has not been widely validated and is a topic for future investigation. Third, of the studies that measured outcomes requiring either tactical and/or technical skills, most find benefits of sleep on performance. Tennis serving accuracy and basketball shooting were both improved by long-term sleep extension interventions,35,39 and tennis serving accuracy suffered when players were deprived of 2 to 2.5 hours of sleep at the beginning of the preceding night.37 Regarding studies conducted in players of team sports that incorporated tactics and decision-based outcomes to a broader extent, soccer as well as rugby players exhibited performance deficits after nights of decreased sleep duration.34 These results are in line with other literature demonstrating clear neurocognitive deficits in the setting of inadequate sleep in the general population, reviewed thoroughly elsewhere.59,60 Finally, when looking at the methodologies of the experimental studies, we found that the studies that altered sleep duration on a longer-term timescale were more likely to show an effect than those that altered sleep duration acutely. Interestingly although most acute sleep interventions involved sleep deprivation and yielded positive results, there were inconsistent results among the 2 acute sleep extension studies.15,38 Conversely, the majority of longer-term sleep intervention studies involved sleep extension and showed positive results.35,39,49 Taken together, these findings suggest that on a short timescale, sleep deprivation may be more harmful than sleep extension is beneficial to performance, although in the longer term, sleep extension may contribute to improved performance. On the other hand, more research is warranted regarding potential adverse effects of chronic sleep loss on athletic performance. The reliability and precision of the various measurements may present challenges in interpretation of these studies. For example, “maximal” voluntary muscle contraction and voluntarily chosen training load are variable across subjects.61,62 On the other hand, “running economy,” the oxygen cost associated with a given running velocity, has low variability among highly trained runners and is significantly correlated with cardiorespiratory ...
# prep_step                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# task part 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# prompt                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# ...
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...

# %% [markdown]
# ## 2.2

# %%
import traceback
import time
# from collections import OrderedDict

class Chaining:

    def __init__(self, text):
        self.text = text

    def summarize(self, task, model="gpt-3.5-turbo", temperature=0.7, n_choices=5, max_tokens=1000,
          text_key=['text_discussion'],
        system_role = "You are an expert at science communication."
        ):
        """
        SH 2023-04-11 12:18: Same as the user-defined `reply` function, but re-written as a class method.
        Send a ChatCompletion request to ChatGPT via the Chatbot class.

        Requrired paramaters:
            - task (str): Task to include in ChatGPT prompt.
            - text (str): Text to feed to GPT for summarization.

        Optional parameters
            - system_role (str): ChatGPT parameter. 
                Default is "You are an expert at science communication."
            - temperature (float): ChatGPT parameter. Default is 0.7.
            - n_choices (int): Number of ChatGPT responses to generate. Default is 5.
            - max_tokens (int): Token limit for ChatGPT response.
            - model (str): ChatGPT model to use. Default is "gpt-3.5-turbo".
        """
        chatbot = Chatbot(self.text,
            system_role=system_role, model=model, temperature=temperature, n_choices=n_choices,
            max_tokens=max_tokens
            )
        prompt = chatbot.create_prompt(task)
        firstline_pattern = r'\s?(\S*)(\n*)(.+)'
        title = re.match(firstline_pattern, self.text)[0]
        self.qna = dict() 
        self.qna['article_title'] = title
        self.qna['system_role'] = system_role
        self.qna['prompt'] = task
        self.qna['model'] = model
        self.summaries_dict = dict()
        self.article_title = title

        try:
            response = chatbot.gpt(prompt)
        except:
            print('\t**API request failed**')
            return self.qna
        try:
            for index, choice in enumerate(response.choices):
                self.qna[f'response_{"{:02d}".format(index+1)}'] = choice["message"]["content"]
                self.summaries_dict[f'response_{"{:02d}".format(index+1)}'] = choice["message"]["content"]
            self.qna[f'text'] = self.text
            return self.qna
        except:
            print('\t**Error with response parsing**')
            return self.qna


    def simplify(self, simplify_task, system_role='You are an expert at science communication.',
                    model="gpt-3.5-turbo", temperature=0.0, n_choices=1, max_tokens=1000, 
                    simplify_iteration=None
                    ):
        self.simplify_bot_dict = dict()
        self.simple_summary_dict = dict()
        for key, summary in self.summaries_dict.items():
            new_key = re.sub(r'response', rf'simple_summary{str(simplify_iteration)}', key)
            print(f'\t\t...Preparing to summarize {key}')
            self.simplify_bot_dict[new_key] = Chatbot(
                summary, system_role=system_role,
                model=model, temperature=temperature, n_choices=n_choices, max_tokens=max_tokens
                )
            simplify_prompt = self.simplify_bot_dict[new_key].create_prompt(simplify_task)
            try:
                self.simple_summary_dict[new_key] = self.simplify_bot_dict[new_key].gpt(simplify_prompt).choices[0]["message"]["content"]
                print(f'\t...Summary given')
            except:
                self.simple_summary_dict[new_key] = self.simplify_bot_dict[new_key].gpt(simplify_prompt)
                print(f'\t...Error parsing response for summary request')
        self.simple_summary_dict['simplify_task'] = simplify_task
        self.qna = {**self.qna, **self.simple_summary_dict}
        try:
            self.qna.update({'text': self.qna.pop('text')})
        except:
            pass
        return self.simple_summary_dict
    
    def add_relevance(self, task, system_role='You are an expert at science communication.',
                    model="gpt-3.5-turbo", temperature=0.0, n_choices=1, max_tokens=1000, 
                    relevance_iteration=None, pause_per_request=20
                    ):
        self.relevance_bot_dict = dict()
        self.relevance_dict = dict()
        if relevance_iteration == None:
            relevance_iteration = 1
        for key, summary in self.summaries_dict.items():
            new_key = re.sub(r'response', rf'relevance_prompt{str(relevance_iteration)}', key)
            print(f'\t\t...Preparing to summarize {key}')
            self.relevance_bot_dict[new_key] = Chatbot(
                summary, system_role=system_role,
                model=model, temperature=temperature, n_choices=n_choices, max_tokens=max_tokens
                )
            relevance_prompt = self.relevance_bot_dict[new_key].create_prompt(task)
            try:
                for index, choice in enumerate(self.relevance_bot_dict[new_key].gpt(relevance_prompt).choices):
                    self.relevance_dict[f'{new_key}_{"{:02d}".format(index+1)}'] = choice["message"]["content"]
                    print(f'\t...Relevance given')
            except:
                try:
                    self.relevance_dict[new_key] = self.relevance_bot_dict[new_key].gpt(relevance_prompt).choices[0]["message"]["content"]
                    print(f'\t...First relevance response given')
                except:
                    self.relevance_dict[new_key] = self.relevance_bot_dict[new_key].gpt(relevance_prompt)
                    print(f'\t...Error parsing response for added relevance request')
            print(f'[add_relevance method] Sleeping {pause_per_request} sec to avoid exceeding API rate limit')
            time.sleep(pause_per_request) # Account for API rate limit of 3 API requests/limit 
        self.relevance_dict[f'relevance_task{"{:02d}".format(relevance_iteration)}'] = task
        self.qna = {**self.qna, **self.relevance_dict}
        try:
            self.qna.update({'text': self.qna.pop('text')})
        except:
            pass
        return self.relevance_dict

def batch_summarize_chain(text_dict, prompts_df, qna_dict,  chaining_bot_dict, iteration_id, n_choices=5,
    prompt_column='prompt',
    save_outputs=False, filename=None, append_version=False,
    csv_path=r'C:\Users\silvh\OneDrive\lighthouse\Ginkgo coding\content-summarization\output',
    pickle_path=r'C:\Users\silvh\OneDrive\lighthouse\Ginkgo coding\content-summarization\output\pickles'
    ):
    """
    Summarize multiple texts using the same prompts.
    Parameters:
        - prompts_df: DataFrame containing the prompts.
        - qna_dict: Dictionary to store the input and outputs.
        - iteration_id (int, float, or string): Unique ID serving as the key for results in the qna_dict
        - prompt_column (str): Name of the column in the prompts_df containing the user input.

    """
    temp_qna_dict = dict()
    prompts_df = prompts_df.reset_index(drop=True)
    qna_dfs_list = []
    chaining_bot_dict[iteration_id] = dict()
    for key in text_dict:
        text = text_dict[key]
        temp_qna_dict[key] = dict()
        for index, input in prompts_df[prompt_column].items():
            print(f'**Text #{key} prompt #{index} of {prompts_df.index.max()}**')
            try:
                chatbot = Chaining(text)
                temp_qna_dict[key][index] = chatbot.summarize(input, n_choices=n_choices)
                chatbot_dict[iteration_id][f'text{key}_prompt{"{:02d}".format(index)}'] = chatbot
                print('\t...Success!')
            except:
                print('\t...Error making chatbot request')
                break
        try:
            prompts_df = prompts_df.drop(prompt_column)
        except:
            pass
        try:
            updated_qna_dict = pd.concat([
                pd.DataFrame(temp_qna_dict[key]),
                prompts_df.transpose()
            ])
        except Exception as error:
            exc_type, exc_obj, tb = sys.exc_info()
            f = tb.tb_frame
            lineno = tb.tb_lineno
            filename = f.f_code.co_filename
            print("An error occurred on line", lineno, "in", filename, ":", error)
            print('Error concatenating prompts DataFrame')
            return temp_qna_dict, chatbot_dict
        try:
            qna_dfs_list.append(updated_qna_dict)
            qna_dict[iteration_id] = pd.concat(qna_dfs_list, axis=1)
            if save_outputs:
                try:
                    append_version = append_version if filename else False
                    filename = filename if filename else f'{datetime.now().strftime("%Y-%m-%d_%H%M")}_prompt_experiments_{"{:02d}".format(iteration_id)}'
                    savepickle(qna_dict[iteration_id], filename=filename, path=pickle_path, append_version=append_version)
                    save_csv(qna_dict[iteration_id], filename=filename, path=pickle_path, append_version=append_version)
                except:
                    print('Unable to save outputs')
        except:
            print('Error concatenating DataFrames')
    return qna_dict, chatbot_dict

def prompt_chaining_dict(simplify_prompts, qna_chain_dict, chaining_bot_dict, iteration_id,
    summary_iteration_id=None, n_choices=None, pause_per_request=20,
    prompt_column='simplify', simplify_iteration=None
    ):
    """
    Simplify or add context to a summary.
    """
    summary_iteration_id = summary_iteration_id if summary_iteration_id else iteration_id
    print('summary_iteration_id:', summary_iteration_id)
    if n_choices == None:
        n_choices = 1 if prompt_column == 'simplify' else 5
    print('n_choices:', n_choices)
    simple_summaries_dict = dict()
    if type(simplify_prompts) == str:
        simplify_prompts = [simplify_prompts]
    elif type(simplify_prompts) == pd.core.frame.DataFrame:
        simplify_prompts = [prompt for prompt in simplify_prompts[prompt_column].unique() if len(prompt) >1]
    else:
        simplify_prompts = list(set([prompt for prompt in simplify_prompts if len(prompt) >1]))
    simple_summaries_master_dict = dict()
    simple_summaries_df = pd.DataFrame()
    for column, text_prompt_key in enumerate(chaining_bot_dict):
        print(f'**{text_prompt_key}')
        simple_summaries_master_dict[text_prompt_key] = dict()

        for index, prompt in enumerate(simplify_prompts):
            relevance_iteration=index if len(simplify_prompts) > 1 else simplify_iteration
            print(f'\t...Prompt: {prompt}, iteration {relevance_iteration}')
            if prompt_column == 'simplify':
                summary_dict = chaining_bot_dict[text_prompt_key].simplify(
                    prompt, n_choices=n_choices,
                    simplify_iteration=index if len(simplify_prompts) > 1 else simplify_iteration
                    )
                simple_summaries_master_dict[text_prompt_key].append(summary_dict)
            else: 
                summary_dict = chaining_bot_dict[text_prompt_key].add_relevance(
                    prompt, n_choices=n_choices, pause_per_request=pause_per_request, 
                    relevance_iteration=index if len(simplify_prompts) > 1 else simplify_iteration
                    )
            simple_summaries_master_dict[text_prompt_key] = {**simple_summaries_master_dict[text_prompt_key], **summary_dict}
        simple_summaries_df[column] = pd.DataFrame([
            pd.Series(value, name=key) for key, value in simple_summaries_master_dict[text_prompt_key].items()
        ])   
    # qna_dict[iteration_id] = simple_summaries_master_dict
    # return qna_dict
    try:
        qna_chain_dict[summary_iteration_id].columns = [i for i in range(len(qna_chain_dict[summary_iteration_id].columns))]
        temp_qna_chain_dict = pd.concat([
            qna_chain_dict[summary_iteration_id], 
            simple_summaries_df
            ])
        qna_chain_dict[iteration_id] = temp_qna_chain_dict
        print(f"{'Simple summaries' if prompt_column=='simplify' else 'Article relevance for user'} added to original DataFrame")
    except Exception as error:
        exc_type, exc_obj, tb = sys.exc_info()
        f = tb.tb_frame
        lineno = tb.tb_lineno
        filename = f.f_code.co_filename
        print("An error occurred on line", lineno, "in", filename, ":", error)
        print('Unable to concatenate simple summary DataFrame to original DataFrame')
        qna_chain_dict[iteration_id+0.001] = simple_summaries_master_dict

    return qna_chain_dict

iteration_id = 2.2
n_choices = 2
# qna_dict = dict()
# qna_chain_dict = dict()
# chatbot_dict = dict()

# qna_dict, chaining_dict = batch_summarize_chain(text_dict, prompts_df, qna_dict, chatbot_dict, 
#     iteration_id=iteration_id, n_choices=n_choices)

# simplify_prompts = task_part2
# qna_dict = simplify_chaining_dict(simplify_prompts, qna_dict, chaining_dict[iteration_id], iteration_id,
#     simplify_iteration=1, summary_iteration_id=None
#     )



# summary_iteration_id = iteration_id
summary_iteration_id = 2
n_choices = 2
relevance_prompts = relevance_prompts_df
pause_per_request=20
qna_dict = prompt_chaining_dict(relevance_prompts, qna_dict, chaining_dict[summary_iteration_id], iteration_id,
    prompt_column='relevance', n_choices=n_choices, pause_per_request=pause_per_request,
    simplify_iteration=2, summary_iteration_id=summary_iteration_id
    )
# Out:
# summary_iteration_id: 2
# n_choices: 2
# **text1_prompt00
# 	...Prompt:  Add 1-2 sentences to make this relevant for seniors , iteration 0
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 	...Prompt:  Add 1-2 sentences to make this relevant for people who enjoy sports , iteration 1
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# **text1_prompt01
# 	...Prompt:  Add 1-2 sentences to make this relevant for seniors , iteration 0
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 	...Prompt:  Add 1-2 sentences to make this relevant for people who enjoy sports , iteration 1
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# **text2_prompt00
# 	...Prompt:  Add 1-2 sentences to make this relevant for seniors , iteration 0
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 	...Prompt:  Add 1-2 sentences to make this relevant for people who enjoy sports , iteration 1
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# **text2_prompt01
# 	...Prompt:  Add 1-2 sentences to make this relevant for seniors , iteration 0
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 	...Prompt:  Add 1-2 sentences to make this relevant for people who enjoy sports , iteration 1
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [add_relevance method] Sleeping 20 sec to avoid exceeding API rate limit
# Article relevance for user added to original DataFrame

# %% [markdown]
# ### RESULTS: Relevance added successfully to dataframe

# %%
qna_dict[iteration_id].tail(12)
# Out:
#                                                                                                                                                                                                                                                                                                                                        0  \
# task part 1                                                                                                                                                                                                                                                                                                Summarize for a LinkedIn post
# prompt                                                                                                                                                                                                                                                   Take the key points and numerical descriptors to Summarize for a LinkedIn post.
# relevance0_01_01  For seniors who are involved in athletic activities, it is important to prioritize getting enough sleep as it has been found to have a positive impact on athletic performance. This review suggests that implementing strategies to improve sleep in the weeks leading up to an event can be particularly beneficial.
# relevance0_01_02  For seniors who are involved in athletic activities, it is important to prioritize getting enough sleep as it has been found to have a positive impact on athletic performance. This review suggests that implementing strategies to improve sleep in the weeks leading up to an event can be particularly beneficial.
# relevance0_02_01                                                          For seniors who are still active in sports or exercise, this study highlights the importance of getting enough sleep for optimal performance. It also suggests that longer-term changes in sleep habits may have a greater impact than short-term adjustments.
# relevance0_02_02                                                          For seniors who are still active in sports or exercise, this study highlights the importance of getting enough sleep for optimal performance. It also suggests that longer-term changes in sleep habits may have a greater impact than short-term adjustments.
# relevance_task00                                                                                                                                                                                                                                                                    Add 1-2 sentences to make this relevant for seniors
# relevance1_01_01                                 If you're an athlete looking to improve your performance, this review suggests that getting enough sleep is crucial. Not only should you prioritize getting a good night's sleep before a big event, but also make sure to consistently prioritize sleep in the weeks leading up to it.
# relevance1_01_02                                 If you're an athlete looking to improve your performance, this review suggests that getting enough sleep is crucial. Not only should you prioritize getting a good night's sleep before a big event, but also make sure to consistently prioritize sleep in the weeks leading up to it.
# relevance1_02_01                                                                If you're an athlete looking to improve your performance, this study suggests that getting enough sleep is crucial. Whether you're a runner, swimmer, or weightlifter, ensuring you get enough sleep can help you perform better and achieve your goals.
# relevance1_02_02                                                                If you're an athlete looking to improve your performance, this study suggests that getting enough sleep is crucial. Whether you're a runner, swimmer, or weightlifter, ensuring you get enough sleep can help you perform better and achieve your goals.
# relevance_task01                                                                                                                                                                                                                                                    Add 1-2 sentences to make this relevant for people who enjoy sports
#
#                                                                                                                                                                                                                                                                                                                                                                                  1  \
# task part 1                                                                                                                                                                                                                                                                                                   Describe the interesting points to your coworker at the water cooler
# prompt                                                                                                                                                                                                                                                      Take the key points and numerical descriptors to Describe the interesting points to your coworker at the water cooler.
# relevance0_01_01  This information is relevant for seniors as it highlights the importance of getting enough sleep for optimal performance, even in athletic activities. It also suggests that sleep may be particularly important for activities that require tactical and technical skills, which could be relevant for seniors who engage in activities such as golf or tennis.
# relevance0_01_02  This information is relevant for seniors as it highlights the importance of getting enough sleep for optimal performance, even in athletic activities. It also suggests that sleep may be particularly important for activities that require tactical and technical skills, which could be relevant for seniors who engage in activities such as golf or tennis.
# relevance0_02_01                                                                                                This information is also relevant for seniors who engage in physical activity. Adequate sleep duration can improve their athletic performance and overall health. It is important for seniors to prioritize their sleep to reap the benefits of physical activity.
# relevance0_02_02                                                                                                This information is also relevant for seniors who engage in physical activity. Adequate sleep duration can improve their athletic performance and overall health. It is important for seniors to prioritize their sleep to reap the benefits of physical activity.
# relevance_task00                                                                                                                                                                                                                                                                                                              Add 1-2 sentences to make this relevant for seniors
# relevance1_01_01                             So, if you're an athlete looking to improve your performance, it's important to prioritize getting enough sleep, especially if you're involved in aerobic activities or require tactical and technical skills. And remember, consistent long-term sleep habits may have a greater impact on your performance than short-term changes.
# relevance1_01_02                             So, if you're an athlete looking to improve your performance, it's important to prioritize getting enough sleep, especially if you're involved in aerobic activities or require tactical and technical skills. And remember, consistent long-term sleep habits may have a greater impact on your performance than short-term changes.
# relevance1_02_01                                                                                 So, if you're an athlete looking to improve your performance, getting enough sleep is crucial. This review shows that increasing your sleep duration can have a positive impact on your athletic abilities, especially for activities that require tactical and technical skills.
# relevance1_02_02                                                                                 So, if you're an athlete looking to improve your performance, getting enough sleep is crucial. This review shows that increasing your sleep duration can have a positive impact on your athletic abilities, especially for activities that require tactical and technical skills.
# relevance_task01                                                                                                                                                                                                                                                                                              Add 1-2 sentences to make this relevant for people who enjoy sports
#
#                                                                                                                                                                                                                                                                                                                                                                                                             2  \
# task part 1                                                                                                                                                                                                                                                                                                                                                                     Summarize for a LinkedIn post
# prompt                                                                                                                                                                                                                                                                                                                        Take the key points and numerical descriptors to Summarize for a LinkedIn post.
# relevance0_01_01                                                             These findings are particularly relevant for seniors who may be experiencing changes in their appetite and stress levels. Understanding the impact of food cues and stressors on food motivation and intake can help seniors make informed decisions about their diet and manage their weight-related physiological adaptations.
# relevance0_01_02                                                             These findings are particularly relevant for seniors who may be experiencing changes in their appetite and stress levels. Understanding the impact of food cues and stressors on food motivation and intake can help seniors make informed decisions about their diet and manage their weight-related physiological adaptations.
# relevance0_02_01                                                            These findings are particularly relevant for seniors who may be more susceptible to stress and have a higher risk of obesity. It is important for seniors to be aware of the impact of personal food cues and stressors on their food cravings and to make conscious choices to avoid highly palatable foods in these situations.
# relevance0_02_02                                                            These findings are particularly relevant for seniors who may be more susceptible to stress and have a higher risk of obesity. It is important for seniors to be aware of the impact of personal food cues and stressors on their food cravings and to make conscious choices to avoid highly palatable foods in these situations.
# relevance_task00                                                                                                                                                                                                                                                                                                                                         Add 1-2 sentences to make this relevant for seniors
# relevance1_01_01                                                                         These findings may be particularly relevant for athletes who need to maintain a healthy weight and diet to perform at their best. Understanding the biobehavioral processes that drive cravings and snacking can help athletes make informed decisions about their food choices and manage their weight effectively.
# relevance1_01_02                                                                         These findings may be particularly relevant for athletes who need to maintain a healthy weight and diet to perform at their best. Understanding the biobehavioral processes that drive cravings and snacking can help athletes make informed decisions about their food choices and manage their weight effectively.
# relevance1_02_01  For athletes and sports enthusiasts, understanding the impact of stress and food cues on HP food craving and intake can be crucial in maintaining a healthy diet and achieving optimal performance. This study sheds light on the biobehavioral processes that may contribute to weight-related adaptations and can inform strategies for managing food cravings in high-stress situations.
# relevance1_02_02  For athletes and sports enthusiasts, understanding the impact of stress and food cues on HP food craving and intake can be crucial in maintaining a healthy diet and achieving optimal performance. This study sheds light on the biobehavioral processes that may contribute to weight-related adaptations and can inform strategies for managing food cravings in high-stress situations.
# relevance_task01                                                                                                                                                                                                                                                                                                                         Add 1-2 sentences to make this relevant for people who enjoy sports
#
#                                                                                                                                                                                                                                                                                                                                                                                                             3
# task part 1                                                                                                                                                                                                                                                                                                                              Describe the interesting points to your coworker at the water cooler
# prompt                                                                                                                                                                                                                                                                                 Take the key points and numerical descriptors to Describe the interesting points to your coworker at the water cooler.
# relevance0_01_01                                             These findings are particularly relevant for seniors as they may experience higher levels of stress and have a greater risk of obesity and related health issues. Understanding the biobehavioral processes underlying food motivation and intake can help seniors make informed decisions about their diet and manage their weight effectively.
# relevance0_01_02                                             These findings are particularly relevant for seniors as they may experience higher levels of stress and have a greater risk of obesity and related health issues. Understanding the biobehavioral processes underlying food motivation and intake can help seniors make informed decisions about their diet and manage their weight effectively.
# relevance0_02_01                                            These findings are particularly relevant for seniors who may be experiencing stress-related food cravings and struggling with maintaining a healthy weight. Understanding the biobehavioral processes underlying food motivation and intake can help seniors make informed decisions about their diet and manage their stress levels effectively.
# relevance0_02_02                                            These findings are particularly relevant for seniors who may be experiencing stress-related food cravings and struggling with maintaining a healthy weight. Understanding the biobehavioral processes underlying food motivation and intake can help seniors make informed decisions about their diet and manage their stress levels effectively.
# relevance_task00                                                                                                                                                                                                                                                                                                                                         Add 1-2 sentences to make this relevant for seniors
# relevance1_01_01  For athletes and sports enthusiasts, understanding the factors that influence food motivation and intake can be crucial for maintaining a healthy diet and achieving optimal performance. This study highlights the potential impact of stress and food cues on highly palatable food craving and intake, which may have implications for athletes looking to manage their diet and weight.
# relevance1_01_02  For athletes and sports enthusiasts, understanding the factors that influence food motivation and intake can be crucial for maintaining a healthy diet and achieving optimal performance. This study highlights the potential impact of stress and food cues on highly palatable food craving and intake, which may have implications for athletes looking to manage their diet and weight.
# relevance1_02_01                                                                            Interestingly, these findings could have implications for athletes who may experience stress and food cravings during training or competition. Understanding the biobehavioral processes underlying food motivation and intake could potentially help athletes manage their cravings and maintain a healthy diet.
# relevance1_02_02                                                                            Interestingly, these findings could have implications for athletes who may experience stress and food cravings during training or competition. Understanding the biobehavioral processes underlying food motivation and intake could potentially help athletes manage their cravings and maintain a healthy diet.
# relevance_task01                                                                                                                                                                                                                                                                                                                         Add 1-2 sentences to make this relevant for people who enjoy sports

# %%
qna_dict[iteration_id].index
# Out:
# Index(['article_title', 'system_role', 'prompt', 'model', 'response_01',
#        'response_02', 'text', 'prep_step', 'task part 1', 'prompt',
#        'relevance0_01_01', 'relevance0_01_02', 'relevance0_02_01',
#        'relevance0_02_02', 'relevance_task00', 'relevance1_01_01',
#        'relevance1_01_02', 'relevance1_02_01', 'relevance1_02_02',
#        'relevance_task01'],
#       dtype='object')

# %%
re.sub(r'response_(.+)', r'simple_summary\1_option', 'response_02')
# Out:
# 'simple_summary02_option'

# %% [markdown]
# # Iteration 3: Clean up naming

# %%
import traceback
import time
# from collections import OrderedDict

class Chaining:

    def __init__(self, text):
        self.text = text

    def summarize(self, task, model="gpt-3.5-turbo", temperature=0.7, n_choices=5, max_tokens=1000,
          text_key=['text_discussion'],
        system_role = "You are an expert at science communication."
        ):
        """
        SH 2023-04-11 12:18: Same as the user-defined `reply` function, but re-written as a class method.
        Send a ChatCompletion request to ChatGPT via the Chatbot class.

        Requrired paramaters:
            - task (str): Task to include in ChatGPT prompt.
            - text (str): Text to feed to GPT for summarization.

        Optional parameters
            - system_role (str): ChatGPT parameter. 
                Default is "You are an expert at science communication."
            - temperature (float): ChatGPT parameter. Default is 0.7.
            - n_choices (int): Number of ChatGPT responses to generate. Default is 5.
            - max_tokens (int): Token limit for ChatGPT response.
            - model (str): ChatGPT model to use. Default is "gpt-3.5-turbo".
        """
        chatbot = Chatbot(self.text,
            system_role=system_role, model=model, temperature=temperature, n_choices=n_choices,
            max_tokens=max_tokens
            )
        prompt = chatbot.create_prompt(task)
        firstline_pattern = r'\s?(\S*)(\n*)(.+)'
        title = re.match(firstline_pattern, self.text)[0]
        self.qna = dict() 
        self.qna['article_title'] = title
        self.qna['system_role'] = system_role
        self.qna['prompt'] = task
        self.qna['model'] = model
        self.summaries_dict = dict()
        self.article_title = title
        self.response_regex = r'response_(.*)'

        try:
            response = chatbot.gpt(prompt)
        except:
            print('\t**API request failed**')
            return self.qna
        try:
            for index, choice in enumerate(response.choices):
                self.qna[f'response_{"{:02d}".format(index+1)}'] = choice["message"]["content"]
                self.summaries_dict[f'response_{"{:02d}".format(index+1)}'] = choice["message"]["content"]
            self.qna[f'text'] = self.text
            return self.qna
        except:
            print('\t**Error with response parsing**')
            return self.qna


    def simplify(self, simplify_task, system_role='You are an expert at science communication.',
                    model="gpt-3.5-turbo", temperature=0.0, n_choices=1, max_tokens=1000, 
                    simplify_iteration=None
                    ):
        self.simplify_bot_dict = dict()
        self.simple_summary_dict = dict()
        for key, summary in self.summaries_dict.items():
            new_key = re.sub(self.response_regex, rf'simple_summary\1_prompt{str(simplify_iteration)}', key)
            print(f'\t\t...Preparing to summarize {key}')
            self.simplify_bot_dict[new_key] = Chatbot(
                summary, system_role=system_role,
                model=model, temperature=temperature, n_choices=n_choices, max_tokens=max_tokens
                )
            simplify_prompt = self.simplify_bot_dict[new_key].create_prompt(simplify_task)
            try:
                for index, choice in enumerate(self.simplify_bot_dict[new_key].gpt(simplify_prompt).choices):
                    self.simple_summary_dict[f'{new_key}_option{"{:02d}".format(index+1)}'] = choice["message"]["content"]
                    print(f'\t...Summary given')
            except:
                self.simple_summary_dict[new_key] = self.simplify_bot_dict[new_key].gpt(simplify_prompt)
                print(f'\t...Error parsing response for summary request')
        self.simple_summary_dict['simplify_task'] = simplify_task
        self.qna = {**self.qna, **self.simple_summary_dict}
        try:
            self.qna.update({'text': self.qna.pop('text')})
        except:
            pass
        return self.simple_summary_dict
    
    def add_relevance(self, task, system_role='You are an expert at science communication.',
                    model="gpt-3.5-turbo", temperature=0.0, n_choices=1, max_tokens=1000, 
                    relevance_iteration=None, pause_per_request=20
                    ):
        self.relevance_bot_dict = dict()
        self.relevance_dict = dict()
        if relevance_iteration == None:
            relevance_iteration = 1
        for key, summary in self.summaries_dict.items():
            new_key = re.sub(self.response_regex, rf'relevance\1_prompt{str(relevance_iteration)}', key)
            print(f'\t\t...Preparing to summarize {key}')
            self.relevance_bot_dict[new_key] = Chatbot(
                summary, system_role=system_role,
                model=model, temperature=temperature, n_choices=n_choices, max_tokens=max_tokens
                )
            relevance_prompt = self.relevance_bot_dict[new_key].create_prompt(task)
            try:
                for index, choice in enumerate(self.relevance_bot_dict[new_key].gpt(relevance_prompt).choices):
                    self.relevance_dict[f'{new_key}_option{"{:02d}".format(index+1)}'] = choice["message"]["content"]
                    print(f'\t...Relevance given')
            except:
                try:
                    self.relevance_dict[new_key] = self.relevance_bot_dict[new_key].gpt(relevance_prompt).choices[0]["message"]["content"]
                    print(f'\t...First relevance response given')
                except:
                    self.relevance_dict[new_key] = self.relevance_bot_dict[new_key].gpt(relevance_prompt)
                    print(f'\t...Error parsing response for added relevance request')
            print(f'[add_relevance method] Sleeping {pause_per_request} sec to avoid exceeding API rate limit')
            time.sleep(pause_per_request) # Account for API rate limit of 3 API requests/limit 
        self.relevance_dict[f'relevance_task{"{:02d}".format(relevance_iteration)}'] = task
        self.qna = {**self.qna, **self.relevance_dict}
        try:
            self.qna.update({'text': self.qna.pop('text')})
        except:
            pass
        return self.relevance_dict

def batch_summarize_chain(text_dict, prompts_df, qna_dict,  chaining_bot_dict, iteration_id, n_choices=5,
    prompt_column='prompt',
    save_outputs=False, filename=None, append_version=False,
    csv_path=r'C:\Users\silvh\OneDrive\lighthouse\Ginkgo coding\content-summarization\output',
    pickle_path=r'C:\Users\silvh\OneDrive\lighthouse\Ginkgo coding\content-summarization\output\pickles'
    ):
    """
    Summarize multiple texts using the same prompts.
    Parameters:
        - prompts_df: DataFrame containing the prompts.
        - qna_dict: Dictionary to store the input and outputs.
        - iteration_id (int, float, or string): Unique ID serving as the key for results in the qna_dict
        - prompt_column (str): Name of the column in the prompts_df containing the user input.

    """
    temp_qna_dict = dict()
    prompts_df = prompts_df.reset_index(drop=True)
    qna_dfs_list = []
    chaining_bot_dict[iteration_id] = dict()
    for key in text_dict:
        text = text_dict[key]
        temp_qna_dict[key] = dict()
        for index, input in prompts_df[prompt_column].items():
            print(f'**Text #{key} prompt #{index} of {prompts_df.index.max()}**')
            try:
                chatbot = Chaining(text)
                temp_qna_dict[key][index] = chatbot.summarize(input, n_choices=n_choices)
                chatbot_dict[iteration_id][f'text{key}_prompt{"{:02d}".format(index)}'] = chatbot
                print('\t...Success!')
            except:
                print('\t...Error making chatbot request')
                break
        try:
            prompts_df = prompts_df.drop(prompt_column)
        except:
            pass
        try:
            updated_qna_dict = pd.concat([
                pd.DataFrame(temp_qna_dict[key]),
                prompts_df.transpose()
            ])
        except Exception as error:
            exc_type, exc_obj, tb = sys.exc_info()
            f = tb.tb_frame
            lineno = tb.tb_lineno
            filename = f.f_code.co_filename
            print("An error occurred on line", lineno, "in", filename, ":", error)
            print('Error concatenating prompts DataFrame')
            return temp_qna_dict, chatbot_dict
        try:
            qna_dfs_list.append(updated_qna_dict)
            qna_dict[iteration_id] = pd.concat(qna_dfs_list, axis=1)
            if save_outputs:
                try:
                    append_version = append_version if filename else False
                    filename = filename if filename else f'{datetime.now().strftime("%Y-%m-%d_%H%M")}_prompt_experiments_{"{:02d}".format(iteration_id)}'
                    savepickle(qna_dict[iteration_id], filename=filename, path=pickle_path, append_version=append_version)
                    save_csv(qna_dict[iteration_id], filename=filename, path=pickle_path, append_version=append_version)
                except:
                    print('Unable to save outputs')
        except:
            print('Error concatenating DataFrames')
    return qna_dict, chatbot_dict

def prompt_chaining_dict(simplify_prompts, qna_chain_dict, chaining_bot_dict, iteration_id,
    summary_iteration_id=None, n_choices=None, pause_per_request=20,
    prompt_column='simplify', simplify_iteration=None
    ):
    """
    Simplify or add context to a summary.
    """
    summary_iteration_id = summary_iteration_id if summary_iteration_id else iteration_id
    print('summary_iteration_id:', summary_iteration_id)
    if n_choices == None:
        n_choices = 1 if prompt_column == 'simplify' else 5
    print('n_choices:', n_choices)
    if type(simplify_prompts) == str:
        simplify_prompts = [simplify_prompts]
    elif type(simplify_prompts) == pd.core.frame.DataFrame:
        simplify_prompts = [prompt for prompt in simplify_prompts[prompt_column].unique() if len(prompt) >1]
    else:
        simplify_prompts = list(set([prompt for prompt in simplify_prompts if len(prompt) >1]))
    simple_summaries_master_dict = dict()
    simple_summaries_df = pd.DataFrame()
    for column, text_prompt_key in enumerate(chaining_bot_dict):
        print(f'**{text_prompt_key}')
        simple_summaries_master_dict[text_prompt_key] = dict()

        for index, prompt in enumerate(simplify_prompts):
            relevance_iteration=index if len(simplify_prompts) > 1 else simplify_iteration
            print(f'\t...Prompt: {prompt}, iteration {relevance_iteration}')
            if prompt_column == 'simplify':
                summary_dict = chaining_bot_dict[text_prompt_key].simplify(
                    prompt, n_choices=n_choices,
                    simplify_iteration=index if len(simplify_prompts) > 1 else simplify_iteration
                    )
                simple_summaries_master_dict[text_prompt_key].append(summary_dict)
            else: 
                summary_dict = chaining_bot_dict[text_prompt_key].add_relevance(
                    prompt, n_choices=n_choices, pause_per_request=pause_per_request, 
                    relevance_iteration=index if len(simplify_prompts) > 1 else simplify_iteration
                    )
            simple_summaries_master_dict[text_prompt_key] = {**simple_summaries_master_dict[text_prompt_key], **summary_dict}
        simple_summaries_df[column] = pd.DataFrame([
            pd.Series(value, name=key) for key, value in simple_summaries_master_dict[text_prompt_key].items()
        ])   
    try:
        qna_chain_dict[summary_iteration_id].columns = [i for i in range(len(qna_chain_dict[summary_iteration_id].columns))]
        temp_qna_chain_dict = pd.concat([
            qna_chain_dict[summary_iteration_id], 
            simple_summaries_df
            ])
        qna_chain_dict[iteration_id] = temp_qna_chain_dict
        print(f"{'Simple summaries' if prompt_column=='simplify' else 'Article relevance for user'} added to original DataFrame")
    except Exception as error:
        exc_type, exc_obj, tb = sys.exc_info()
        f = tb.tb_frame
        lineno = tb.tb_lineno
        filename = f.f_code.co_filename
        print("An error occurred on line", lineno, "in", filename, ":", error)
        print('Unable to concatenate simple summary DataFrame to original DataFrame')
        qna_chain_dict[iteration_id+0.001] = simple_summaries_master_dict

    return qna_chain_dict

iteration_id = 3
n_choices = 2
# qna_dict = dict()
# qna_chain_dict = dict()
# chatbot_dict = dict()

qna_dict, chaining_dict = batch_summarize_chain(text_dict, prompts_df, qna_dict, chatbot_dict, 
    iteration_id=iteration_id, n_choices=n_choices)


# simplify_prompts = task_part2
# summary_iteration_id = iteration_id
# qna_dict = prompt_chaining_dict(simplify_prompts, qna_dict, chaining_dict[summary_iteration_id], iteration_id,
#     summary_iteration_id=summary_iteration_id
#     )

# summary_iteration_id = iteration_id
# summary_iteration_id = 2
# n_choices = 2
# relevance_prompts = relevance_prompts_df
# pause_per_request=20
# qna_dict = prompt_chaining_dict(relevance_prompts, qna_dict, chaining_dict[summary_iteration_id], iteration_id,
#     prompt_column='relevance', n_choices=n_choices, pause_per_request=pause_per_request,
#     simplify_iteration=1, summary_iteration_id=summary_iteration_id
#     )
# Out:
# **Text #1 prompt #0 of 1**
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Success!
# **Text #1 prompt #1 of 1**
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Success!
# **Text #2 prompt #0 of 1**
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Success!
# **Text #2 prompt #1 of 1**
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Success!

# %%
qna_dict[iteration_id]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# article_title                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# system_role                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# prompt                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# model                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# response_01                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# response_02                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# text           The Impact of Sleep Duration on Performance Among Competitive Athletes: A Systematic Literature Review\n\nDISCUSSION \nThis literature review, although diverse in the range of sports, methods, and outcomes studied, provides several stylized facts that can inform sleep research and competitive athletes. First, out of all the published studies we reviewed, none found a negative association between sleep duration and any performance outcome. All of the results reviewed showed that either the increased sleep duration has a positive effect on athletic performance or the results were neutral. Note that among studies reporting significant positive results, effect sizes varied considerably (Tables 2-4), likely due to differences in the duration of sleep deprivation/extension experienced as well as differences in outcome measures. Second, when considering the aerobic and anaerobic characteristics of sports, it seems that aerobic activity is more sensitive to sleep duration compared to anaerobic activity, including strength testing. For instance, Mejri et al40 found that depriving competitive taekwondo boxers of a mere 3 to 4 hours of sleep significantly impaired performance on the Yo-Yo intermittent recovery test. By contrast, Blumert et al33 employed a relatively severe sleep deprivation protocol by depriving 9 national-caliber collegiate weightlifters of 24 hours of sleep and yet failed to identify adverse effects on any of the various weightlifting exercises examined. Relatedly, for both endurance and explosive, power-based exercises, it has been well documented that sleep deprivation is associated with increased perceived effort.56–58 Still, the relationship between perceived effort and objective performance has not been widely validated and is a topic for future investigation. Third, of the studies that measured outcomes requiring either tactical and/or technical skills, most find benefits of sleep on performance. Tennis serving accuracy and basketball shooting were both improved by long-term sleep extension interventions,35,39 and tennis serving accuracy suffered when players were deprived of 2 to 2.5 hours of sleep at the beginning of the preceding night.37 Regarding studies conducted in players of team sports that incorporated tactics and decision-based outcomes to a broader extent, soccer as well as rugby players exhibited performance deficits after nights of decreased sleep duration.34 These results are in line with other literature demonstrating clear neurocognitive deficits in the setting of inadequate sleep in the general population, reviewed thoroughly elsewhere.59,60 Finally, when looking at the methodologies of the experimental studies, we found that the studies that altered sleep duration on a longer-term timescale were more likely to show an effect than those that altered sleep duration acutely. Interestingly although most acute sleep interventions involved sleep deprivation and yielded positive results, there were inconsistent results among the 2 acute sleep extension studies.15,38 Conversely, the majority of longer-term sleep intervention studies involved sleep extension and showed positive results.35,39,49 Taken together, these findings suggest that on a short timescale, sleep deprivation may be more harmful than sleep extension is beneficial to performance, although in the longer term, sleep extension may contribute to improved performance. On the other hand, more research is warranted regarding potential adverse effects of chronic sleep loss on athletic performance. The reliability and precision of the various measurements may present challenges in interpretation of these studies. For example, “maximal” voluntary muscle contraction and voluntarily chosen training load are variable across subjects.61,62 On the other hand, “running economy,” the oxygen cost associated with a given running velocity, has low variability among highly trained runners and is significantly correlated with cardiorespiratory ...
# prep_step                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# task part 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# prompt                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
#
# ...
# prep_step                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# task part 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# prompt                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...

# %%
task_part2
# Out:
# ['', 'Use terms a 12-year-old can understand.']

# %%
simplify_prompts = task_part2
summary_iteration_id = iteration_id
qna_dict = prompt_chaining_dict(simplify_prompts, qna_dict, chaining_dict[summary_iteration_id], iteration_id,
    summary_iteration_id=summary_iteration_id, 
    )
# Out:
# summary_iteration_id: 3
# n_choices: 1
# **text1_prompt00
# 	...Prompt: Use terms a 12-year-old can understand., iteration None
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 1 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Summary given
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 1 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Summary given
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\silvh\OneDrive\lighthouse\Ginkgo coding\content-summarization\notebooks\2023-04-13 prompt chaining with user relevance added - part 2.ipynb Cell 52 in 3
#       <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/Ginkgo%20coding/content-summarization/notebooks/2023-04-13%20prompt%20chaining%20with%20user%20relevance%20added%20-%20part%202.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> simplify_prompts = task_part2
#       <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/Ginkgo%20coding/content-summarization/notebooks/2023-04-13%20prompt%20chaining%20with%20user%20relevance%20added%20-%20part%202.ipynb#X32sZmlsZQ%3D%3D?line=1'>2</a> summary_iteration_id = iteration_id
# ----> <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/Ginkgo%20coding/content-summarization/notebooks/2023-04-13%20prompt%20chaining%20with%20user%20relevance%20added%20-%20part%202.ipynb#X32sZmlsZQ%3D%3D?line=2'>3</a> qna_dict = prompt_chaining_dict(simplify_prompts, qna_dict, chaining_dict[summary_iteration_id], iteration_id,
#       <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/Ginkgo%20coding/content-summarization/notebooks/2023-04-13%20prompt%20chaining%20with%20user%20relevance%20added%20-%20part%202.ipynb#X32sZmlsZQ%3D%3D?line=3'>4</a>     summary_iteration_id=summary_iteration_id,
#       <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/Ginkgo%20coding/content-summarization/notebooks/2023-04-13%20prompt%20chaining%20with%20user%20relevance%20added%20-%20part%202.ipynb#X32sZmlsZQ%3D%3D?line=4'>5</a>     )
#
# c:\Users\silvh\OneDrive\lighthouse\Ginkgo coding\content-summarization\notebooks\2023-04-13 prompt chaining with user relevance added - part 2.ipynb Cell 52 in 2
#     <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/Ginkgo%20coding/content-summarization/notebooks/2023-04-13%20prompt%20chaining%20with%20user%20relevance%20added%20-%20part%202.ipynb#X32sZmlsZQ%3D%3D?line=218'>219</a> if prompt_column == 'simplify':
#     <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/Ginkgo%20coding/content-summarization/notebooks/2023-04-13%20prompt%20chaining%20with%20user%20relevance%20added%20-%20part%202.ipynb#X32sZmlsZQ%3D%3D?line=219'>220</a>     summary_dict = chaining_bot_dict[text_prompt_key].simplify(
#     <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/Ginkgo%20coding/content-summarization/notebooks/2023-04-13%20prompt%20chaining%20with%20user%20relevance%20added%20-%20part%202.ipynb#X32sZmlsZQ%3D%3D?line=220'>221</a>         prompt, n_choices=n_choices,
#     <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/Ginkgo%20coding/content-summarization/notebooks/2023-04-13%20prompt%20chaining%20with%20user%20relevance%20added%20-%20part%202.ipynb#X32sZmlsZQ%3D%3D?line=221'>222</a>         simplify_iteration=index if len(simplify_prompts) > 1 else simplify_iteration
#     <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/Ginkgo%20coding/content-summarization/notebooks/2023-04-13%20prompt%20chaining%20with%20user%20relevance%20added%20-%20part%202.ipynb#X32sZmlsZQ%3D%3D?line=222'>223</a>         )
# --> <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/Ginkgo%20coding/content-summarization/notebooks/2023-04-13%20prompt%20chaining%20with%20user%20relevance%20added%20-%20part%202.ipynb#X32sZmlsZQ%3D%3D?line=223'>224</a>     simple_summaries_master_dict[text_prompt_key].append(summary_dict)
#     <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/Ginkgo%20coding/content-summarization/notebooks/2023-04-13%20prompt%20chaining%20with%20user%20relevance%20added%20-%20part%202.ipynb#X32sZmlsZQ%3D%3D?line=224'>225</a> else:
#     <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/Ginkgo%20coding/content-summarization/notebooks/2023-04-13%20prompt%20chaining%20with%20user%20relevance%20added%20-%20part%202.ipynb#X32sZmlsZQ%3D%3D?line=225'>226</a>     summary_dict = chaining_bot_dict[text_prompt_key].add_relevance(
#     <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/Ginkgo%20coding/content-summarization/notebooks/2023-04-13%20prompt%20chaining%20with%20user%20relevance%20added%20-%20part%202.ipynb#X32sZmlsZQ%3D%3D?line=226'>227</a>         prompt, n_choices=n_choices, pause_per_request=pause_per_request,
#     <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/Ginkgo%20coding/content-summarization/notebooks/2023-04-13%20prompt%20chaining%20with%20user%20relevance%20added%20-%20part%202.ipynb#X32sZmlsZQ%3D%3D?line=227'>228</a>         relevance_iteration=index if len(simplify_prompts) > 1 else simplify_iteration
#     <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/Ginkgo%20coding/content-summarization/notebooks/2023-04-13%20prompt%20chaining%20with%20user%20relevance%20added%20-%20part%202.ipynb#X32sZmlsZQ%3D%3D?line=228'>229</a>         )
#
# AttributeError: 'dict' object has no attribute 'append'

# %% [markdown]
# ## 3.1

# %%
import traceback
import time
# from collections import OrderedDict

class Chaining:

    def __init__(self, text):
        self.text = text

    def summarize(self, task, model="gpt-3.5-turbo", temperature=0.7, n_choices=5, max_tokens=1000,
          text_key=['text_discussion'],
        system_role = "You are an expert at science communication."
        ):
        """
        SH 2023-04-11 12:18: Same as the user-defined `reply` function, but re-written as a class method.
        Send a ChatCompletion request to ChatGPT via the Chatbot class.

        Requrired paramaters:
            - task (str): Task to include in ChatGPT prompt.
            - text (str): Text to feed to GPT for summarization.

        Optional parameters
            - system_role (str): ChatGPT parameter. 
                Default is "You are an expert at science communication."
            - temperature (float): ChatGPT parameter. Default is 0.7.
            - n_choices (int): Number of ChatGPT responses to generate. Default is 5.
            - max_tokens (int): Token limit for ChatGPT response.
            - model (str): ChatGPT model to use. Default is "gpt-3.5-turbo".
        """
        chatbot = Chatbot(self.text,
            system_role=system_role, model=model, temperature=temperature, n_choices=n_choices,
            max_tokens=max_tokens
            )
        prompt = chatbot.create_prompt(task)
        firstline_pattern = r'\s?(\S*)(\n*)(.+)'
        title = re.match(firstline_pattern, self.text)[0]
        self.qna = dict() 
        self.qna['article_title'] = title
        self.qna['system_role'] = system_role
        self.qna['prompt'] = task
        self.qna['model'] = model
        self.summaries_dict = dict()
        self.article_title = title
        self.response_regex = r'response_(.*)'

        try:
            response = chatbot.gpt(prompt)
        except:
            print('\t**API request failed**')
            return self.qna
        try:
            for index, choice in enumerate(response.choices):
                self.qna[f'response_{"{:02d}".format(index+1)}'] = choice["message"]["content"]
                self.summaries_dict[f'response_{"{:02d}".format(index+1)}'] = choice["message"]["content"]
            self.qna[f'text'] = self.text
            return self.qna
        except:
            print('\t**Error with response parsing**')
            return self.qna


    def simplify(self, simplify_task, system_role='You are an expert at science communication.',
                    model="gpt-3.5-turbo", temperature=0.0, n_choices=1, max_tokens=1000, 
                    simplify_iteration=None
                    ):
        self.simplify_bot_dict = dict()
        self.simple_summary_dict = dict()
        for key, summary in self.summaries_dict.items():
            new_key = re.sub(self.response_regex, rf'simple_summary\1_prompt{str(simplify_iteration)}', key)
            print(f'\t\t...Preparing to summarize {key}')
            self.simplify_bot_dict[new_key] = Chatbot(
                summary, system_role=system_role,
                model=model, temperature=temperature, n_choices=n_choices, max_tokens=max_tokens
                )
            simplify_prompt = self.simplify_bot_dict[new_key].create_prompt(simplify_task)
            try:
                for index, choice in enumerate(self.simplify_bot_dict[new_key].gpt(simplify_prompt).choices):
                    self.simple_summary_dict[f'{new_key}_option{"{:02d}".format(index+1)}'] = choice["message"]["content"]
                    print(f'\t...Summary given')
            except:
                self.simple_summary_dict[new_key] = self.simplify_bot_dict[new_key].gpt(simplify_prompt)
                print(f'\t...Error parsing response for summary request')
        self.simple_summary_dict['simplify_task'] = simplify_task
        self.qna = {**self.qna, **self.simple_summary_dict}
        try:
            self.qna.update({'text': self.qna.pop('text')})
        except:
            pass
        return self.simple_summary_dict
    
    def add_relevance(self, task, system_role='You are an expert at science communication.',
                    model="gpt-3.5-turbo", temperature=0.0, n_choices=1, max_tokens=1000, 
                    relevance_iteration=None, pause_per_request=20
                    ):
        self.relevance_bot_dict = dict()
        self.relevance_dict = dict()
        if relevance_iteration == None:
            relevance_iteration = 1
        for key, summary in self.summaries_dict.items():
            new_key = re.sub(self.response_regex, rf'relevance\1_prompt{str(relevance_iteration)}', key)
            print(f'\t\t...Preparing to summarize {key}')
            self.relevance_bot_dict[new_key] = Chatbot(
                summary, system_role=system_role,
                model=model, temperature=temperature, n_choices=n_choices, max_tokens=max_tokens
                )
            relevance_prompt = self.relevance_bot_dict[new_key].create_prompt(task)
            try:
                for index, choice in enumerate(self.relevance_bot_dict[new_key].gpt(relevance_prompt).choices):
                    self.relevance_dict[f'{new_key}_option{"{:02d}".format(index+1)}'] = choice["message"]["content"]
                    print(f'\t...Relevance given')
            except:
                try:
                    self.relevance_dict[new_key] = self.relevance_bot_dict[new_key].gpt(relevance_prompt).choices[0]["message"]["content"]
                    print(f'\t...First relevance response given')
                except:
                    self.relevance_dict[new_key] = self.relevance_bot_dict[new_key].gpt(relevance_prompt)
                    print(f'\t...Error parsing response for added relevance request')
            print(f'[add_relevance method] Sleeping {pause_per_request} sec to avoid exceeding API rate limit')
            time.sleep(pause_per_request) # Account for API rate limit of 3 API requests/limit 
        self.relevance_dict[f'relevance_task{"{:02d}".format(relevance_iteration)}'] = task
        self.qna = {**self.qna, **self.relevance_dict}
        try:
            self.qna.update({'text': self.qna.pop('text')})
        except:
            pass
        return self.relevance_dict

def batch_summarize_chain(text_dict, prompts_df, qna_dict,  chaining_bot_dict, iteration_id, n_choices=5,
    prompt_column='prompt',
    save_outputs=False, filename=None, append_version=False,
    csv_path=r'C:\Users\silvh\OneDrive\lighthouse\Ginkgo coding\content-summarization\output',
    pickle_path=r'C:\Users\silvh\OneDrive\lighthouse\Ginkgo coding\content-summarization\output\pickles'
    ):
    """
    Summarize multiple texts using the same prompts.
    Parameters:
        - prompts_df: DataFrame containing the prompts.
        - qna_dict: Dictionary to store the input and outputs.
        - iteration_id (int, float, or string): Unique ID serving as the key for results in the qna_dict
        - prompt_column (str): Name of the column in the prompts_df containing the user input.

    """
    temp_qna_dict = dict()
    prompts_df = prompts_df.reset_index(drop=True)
    qna_dfs_list = []
    chaining_bot_dict[iteration_id] = dict()
    for key in text_dict:
        text = text_dict[key]
        temp_qna_dict[key] = dict()
        for index, input in prompts_df[prompt_column].items():
            print(f'**Text #{key} prompt #{index} of {prompts_df.index.max()}**')
            try:
                chatbot = Chaining(text)
                temp_qna_dict[key][index] = chatbot.summarize(input, n_choices=n_choices)
                chatbot_dict[iteration_id][f'text{key}_prompt{"{:02d}".format(index)}'] = chatbot
                print('\t...Success!')
            except:
                print('\t...Error making chatbot request')
                break
        try:
            prompts_df = prompts_df.drop(prompt_column)
        except:
            pass
        try:
            updated_qna_dict = pd.concat([
                pd.DataFrame(temp_qna_dict[key]),
                prompts_df.transpose()
            ])
        except Exception as error:
            exc_type, exc_obj, tb = sys.exc_info()
            f = tb.tb_frame
            lineno = tb.tb_lineno
            filename = f.f_code.co_filename
            print("An error occurred on line", lineno, "in", filename, ":", error)
            print('Error concatenating prompts DataFrame')
            return temp_qna_dict, chatbot_dict
        try:
            qna_dfs_list.append(updated_qna_dict)
            qna_dict[iteration_id] = pd.concat(qna_dfs_list, axis=1)
            if save_outputs:
                try:
                    append_version = append_version if filename else False
                    filename = filename if filename else f'{datetime.now().strftime("%Y-%m-%d_%H%M")}_prompt_experiments_{"{:02d}".format(iteration_id)}'
                    savepickle(qna_dict[iteration_id], filename=filename, path=pickle_path, append_version=append_version)
                    save_csv(qna_dict[iteration_id], filename=filename, path=pickle_path, append_version=append_version)
                except:
                    print('Unable to save outputs')
        except:
            print('Error concatenating DataFrames')
    return qna_dict, chatbot_dict

def prompt_chaining_dict(simplify_prompts, qna_chain_dict, chaining_bot_dict, iteration_id,
    summary_iteration_id=None, n_choices=None, pause_per_request=20,
    prompt_column='simplify', simplify_iteration=None
    ):
    """
    Simplify or add context to a summary.
    """
    summary_iteration_id = summary_iteration_id if summary_iteration_id else iteration_id
    print('summary_iteration_id:', summary_iteration_id)
    if n_choices == None:
        n_choices = 1 if prompt_column == 'simplify' else 5
    print('n_choices:', n_choices)
    if type(simplify_prompts) == str:
        simplify_prompts = [simplify_prompts]
    elif type(simplify_prompts) == pd.core.frame.DataFrame:
        simplify_prompts = [prompt for prompt in simplify_prompts[prompt_column].unique() if len(prompt) >1]
    else:
        simplify_prompts = list(set([prompt for prompt in simplify_prompts if len(prompt) >1]))
    simple_summaries_master_dict = dict()
    simple_summaries_df = pd.DataFrame()
    for column, text_prompt_key in enumerate(chaining_bot_dict):
        print(f'**{text_prompt_key}')
        simple_summaries_master_dict[text_prompt_key] = dict()

        for index, prompt in enumerate(simplify_prompts):
            relevance_iteration=index if len(simplify_prompts) > 1 else simplify_iteration
            print(f'\t...Prompt: {prompt}, iteration {relevance_iteration}')
            if prompt_column == 'simplify':
                summary_dict = chaining_bot_dict[text_prompt_key].simplify(
                    prompt, n_choices=n_choices,
                    simplify_iteration=index if len(simplify_prompts) > 1 else simplify_iteration
                    )
            else: 
                summary_dict = chaining_bot_dict[text_prompt_key].add_relevance(
                    prompt, n_choices=n_choices, pause_per_request=pause_per_request, 
                    relevance_iteration=index if len(simplify_prompts) > 1 else simplify_iteration
                    )
            simple_summaries_master_dict[text_prompt_key] = {**simple_summaries_master_dict[text_prompt_key], **summary_dict}
        try:
            simple_summaries_df[column] = pd.DataFrame([
                pd.Series(value, name=key) for key, value in simple_summaries_master_dict[text_prompt_key].items()
            ])   
        except Exception as error:
            exc_type, exc_obj, tb = sys.exc_info()
            f = tb.tb_frame
            lineno = tb.tb_lineno
            filename = f.f_code.co_filename
            print("An error occurred on line", lineno, "in", filename, ":", error)
            print('Unable to create results DataFrame')
            
            qna_chain_dict[iteration_id+0.001] = simple_summaries_master_dict
    try:
        qna_chain_dict[summary_iteration_id].columns = [i for i in range(len(qna_chain_dict[summary_iteration_id].columns))]
        temp_qna_chain_dict = pd.concat([
            qna_chain_dict[summary_iteration_id], 
            simple_summaries_df
            ])
        qna_chain_dict[iteration_id] = temp_qna_chain_dict
        print(f"{'Simple summaries' if prompt_column=='simplify' else 'Article relevance for user'} added to original DataFrame")
    except Exception as error:
        exc_type, exc_obj, tb = sys.exc_info()
        f = tb.tb_frame
        lineno = tb.tb_lineno
        filename = f.f_code.co_filename
        print("An error occurred on line", lineno, "in", filename, ":", error)
        print('Unable to concatenate simple summary DataFrame to original DataFrame')
        qna_chain_dict[iteration_id+0.001] = simple_summaries_master_dict

    return qna_chain_dict

iteration_id = 3
n_choices = 2
# qna_dict = dict()
# qna_chain_dict = dict()
# chatbot_dict = dict()

# qna_dict, chaining_dict = batch_summarize_chain(text_dict, prompts_df, qna_dict, chatbot_dict, 
#     iteration_id=iteration_id, n_choices=n_choices)


simplify_prompts = task_part2
summary_iteration_id = 3
qna_dict = prompt_chaining_dict(simplify_prompts, qna_dict, chaining_dict[summary_iteration_id], iteration_id,
    summary_iteration_id=summary_iteration_id
    )

# summary_iteration_id = iteration_id
# summary_iteration_id = 2
# n_choices = 2
# relevance_prompts = relevance_prompts_df
# pause_per_request=20
# qna_dict = prompt_chaining_dict(relevance_prompts, qna_dict, chaining_dict[summary_iteration_id], iteration_id,
#     prompt_column='relevance', n_choices=n_choices, pause_per_request=pause_per_request,
#     simplify_iteration=1, summary_iteration_id=summary_iteration_id
#     )
# Out:
# summary_iteration_id: 3
# n_choices: 1
# **text1_prompt00
# 	...Prompt: Use terms a 12-year-old can understand., iteration None
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 1 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Summary given
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 1 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Summary given
# **text1_prompt01
# 	...Prompt: Use terms a 12-year-old can understand., iteration None
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 1 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Summary given
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 1 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Summary given
# **text2_prompt00
# 	...Prompt: Use terms a 12-year-old can understand., iteration None
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 1 choices using gpt-3.5-turbo
# 	Sending request to GPT-3
# 		Requesting 1 choices using gpt-3.5-turbo
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# c:\Users\silvh\OneDrive\lighthouse\Ginkgo coding\content-summarization\notebooks\2023-04-13 prompt chaining with user relevance added - part 2.ipynb Cell 54 in 7
#      <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/Ginkgo%20coding/content-summarization/notebooks/2023-04-13%20prompt%20chaining%20with%20user%20relevance%20added%20-%20part%202.ipynb#Y120sZmlsZQ%3D%3D?line=75'>76</a> try:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/Ginkgo%20coding/content-summarization/notebooks/2023-04-13%20prompt%20chaining%20with%20user%20relevance%20added%20-%20part%202.ipynb#Y120sZmlsZQ%3D%3D?line=76'>77</a>     for index, choice in enumerate(self.simplify_bot_dict[new_key].gpt(simplify_prompt).choices):
#      <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/Ginkgo%20coding/content-summarization/notebooks/2023-04-13%20prompt%20chaining%20with%20user%20relevance%20added%20-%20part%202.ipynb#Y120sZmlsZQ%3D%3D?line=77'>78</a>         self.simple_summary_dict[f'{new_key}_option{"{:02d}".format(index+1)}'] = choice["message"]["content"]
#
# File ~\OneDrive\lighthouse\Ginkgo coding\content-summarization\src\summarization.py:53, in Chatbot.gpt(self, messages)
#      52 openai.api_key = os.getenv('api_openai')
# ---> 53 response = openai.ChatCompletion.create(
#      54     model=self.model, messages=messages,
#      55     temperature=self.temperature,
#      56     max_tokens=self.max_tokens,
#      57     n=self.n_choices
#      58     )
#      59 print('\tDone sending request to GPT-3')
#
# File c:\ProgramData\Anaconda3\envs\gingko2\lib\site-packages\openai\api_resources\chat_completion.py:25, in ChatCompletion.create(cls, *args, **kwargs)
#      24 try:
# ---> 25     return super().create(*args, **kwargs)
#      26 except TryAgain as e:
#
# File c:\ProgramData\Anaconda3\envs\gingko2\lib\site-packages\openai\api_resources\abstract\engine_api_resource.py:153, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     138 (
#     139     deployment_id,
#     140     engine,
#    (...)
#     150     api_key, api_base, api_type, api_version, organization, **params
#     151 )
# --> 153 response, _, api_key = requestor.request(
#     154     "post",
#     155     url,
#     156     params=params,
#     157     headers=headers,
#     158     stream=stream,
#     159     request_id=request_id,
#     160     request_timeout=request_timeout,
#     161 )
#     163 if stream:
#     164     # must be an iterator
#
# File c:\ProgramData\Anaconda3\envs\gingko2\lib\site-packages\openai\api_requestor.py:226, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     216 result = self.request_raw(
#     217     method.lower(),
#     218     url,
#    (...)
#     224     request_timeout=request_timeout,
#     225 )
# --> 226 resp, got_stream = self._interpret_response(result, stream)
#     227 return resp, got_stream, self.api_key
#
# File c:\ProgramData\Anaconda3\envs\gingko2\lib\site-packages\openai\api_requestor.py:620, in APIRequestor._interpret_response(self, result, stream)
#     618 else:
#     619     return (
# --> 620         self._interpret_response_line(
#     621             result.content.decode("utf-8"),
#     622             result.status_code,
#     623             result.headers,
#     624             stream=False,
#     625         ),
#     626         False,
#     627     )
#
# File c:\ProgramData\Anaconda3\envs\gingko2\lib\site-packages\openai\api_requestor.py:683, in APIRequestor._interpret_response_line(self, rbody, rcode, rheaders, stream)
#     682 if stream_error or not 200 <= rcode < 300:
# --> 683     raise self.handle_error_response(
#     684         rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     685     )
#     686 return resp
#
# RateLimitError: Rate limit reached for default-gpt-3.5-turbo in organization org-4l8HUKDtXhH0T7iFErf1JSJg on requests per min. Limit: 3 / min. Please try again in 20s. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method.
#
# During handling of the above exception, another exception occurred:
#
# RateLimitError                            Traceback (most recent call last)
# c:\Users\silvh\OneDrive\lighthouse\Ginkgo coding\content-summarization\notebooks\2023-04-13 prompt chaining with user relevance added - part 2.ipynb Cell 54 in 2
#     <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/Ginkgo%20coding/content-summarization/notebooks/2023-04-13%20prompt%20chaining%20with%20user%20relevance%20added%20-%20part%202.ipynb#Y120sZmlsZQ%3D%3D?line=271'>272</a> simplify_prompts = task_part2
#     <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/Ginkgo%20coding/content-summarization/notebooks/2023-04-13%20prompt%20chaining%20with%20user%20relevance%20added%20-%20part%202.ipynb#Y120sZmlsZQ%3D%3D?line=272'>273</a> summary_iteration_id = 3
# --> <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/Ginkgo%20coding/content-summarization/notebooks/2023-04-13%20prompt%20chaining%20with%20user%20relevance%20added%20-%20part%202.ipynb#Y120sZmlsZQ%3D%3D?line=273'>274</a> qna_dict = prompt_chaining_dict(simplify_prompts, qna_dict, chaining_dict[summary_iteration_id], iteration_id,
#     <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/Ginkgo%20coding/content-summarization/notebooks/2023-04-13%20prompt%20chaining%20with%20user%20relevance%20added%20-%20part%202.ipynb#Y120sZmlsZQ%3D%3D?line=274'>275</a>     summary_iteration_id=summary_iteration_id
#     <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/Ginkgo%20coding/content-summarization/notebooks/2023-04-13%20prompt%20chaining%20with%20user%20relevance%20added%20-%20part%202.ipynb#Y120sZmlsZQ%3D%3D?line=275'>276</a>     )
#
# c:\Users\silvh\OneDrive\lighthouse\Ginkgo coding\content-summarization\notebooks\2023-04-13 prompt chaining with user relevance added - part 2.ipynb Cell 54 in 2
#     <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/Ginkgo%20coding/content-summarization/notebooks/2023-04-13%20prompt%20chaining%20with%20user%20relevance%20added%20-%20part%202.ipynb#Y120sZmlsZQ%3D%3D?line=217'>218</a> print(f'\t...Prompt: {prompt}, iteration {relevance_iteration}')
#     <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/Ginkgo%20coding/content-summarization/notebooks/2023-04-13%20prompt%20chaining%20with%20user%20relevance%20added%20-%20part%202.ipynb#Y120sZmlsZQ%3D%3D?line=218'>219</a> if prompt_column == 'simplify':
# --> <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/Ginkgo%20coding/content-summarization/notebooks/2023-04-13%20prompt%20chaining%20with%20user%20relevance%20added%20-%20part%202.ipynb#Y120sZmlsZQ%3D%3D?line=219'>220</a>     summary_dict = chaining_bot_dict[text_prompt_key].simplify(
#     <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/Ginkgo%20coding/content-summarization/notebooks/2023-04-13%20prompt%20chaining%20with%20user%20relevance%20added%20-%20part%202.ipynb#Y120sZmlsZQ%3D%3D?line=220'>221</a>         prompt, n_choices=n_choices,
#     <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/Ginkgo%20coding/content-summarization/notebooks/2023-04-13%20prompt%20chaining%20with%20user%20relevance%20added%20-%20part%202.ipynb#Y120sZmlsZQ%3D%3D?line=221'>222</a>         simplify_iteration=index if len(simplify_prompts) > 1 else simplify_iteration
#     <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/Ginkgo%20coding/content-summarization/notebooks/2023-04-13%20prompt%20chaining%20with%20user%20relevance%20added%20-%20part%202.ipynb#Y120sZmlsZQ%3D%3D?line=222'>223</a>         )
#     <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/Ginkgo%20coding/content-summarization/notebooks/2023-04-13%20prompt%20chaining%20with%20user%20relevance%20added%20-%20part%202.ipynb#Y120sZmlsZQ%3D%3D?line=223'>224</a> else:
#     <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/Ginkgo%20coding/content-summarization/notebooks/2023-04-13%20prompt%20chaining%20with%20user%20relevance%20added%20-%20part%202.ipynb#Y120sZmlsZQ%3D%3D?line=224'>225</a>     summary_dict = chaining_bot_dict[text_prompt_key].add_relevance(
#     <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/Ginkgo%20coding/content-summarization/notebooks/2023-04-13%20prompt%20chaining%20with%20user%20relevance%20added%20-%20part%202.ipynb#Y120sZmlsZQ%3D%3D?line=225'>226</a>         prompt, n_choices=n_choices, pause_per_request=pause_per_request,
#     <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/Ginkgo%20coding/content-summarization/notebooks/2023-04-13%20prompt%20chaining%20with%20user%20relevance%20added%20-%20part%202.ipynb#Y120sZmlsZQ%3D%3D?line=226'>227</a>         relevance_iteration=index if len(simplify_prompts) > 1 else simplify_iteration
#     <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/Ginkgo%20coding/content-summarization/notebooks/2023-04-13%20prompt%20chaining%20with%20user%20relevance%20added%20-%20part%202.ipynb#Y120sZmlsZQ%3D%3D?line=227'>228</a>         )
#
# c:\Users\silvh\OneDrive\lighthouse\Ginkgo coding\content-summarization\notebooks\2023-04-13 prompt chaining with user relevance added - part 2.ipynb Cell 54 in 8
#      <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/Ginkgo%20coding/content-summarization/notebooks/2023-04-13%20prompt%20chaining%20with%20user%20relevance%20added%20-%20part%202.ipynb#Y120sZmlsZQ%3D%3D?line=78'>79</a>             print(f'\t...Summary given')
#      <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/Ginkgo%20coding/content-summarization/notebooks/2023-04-13%20prompt%20chaining%20with%20user%20relevance%20added%20-%20part%202.ipynb#Y120sZmlsZQ%3D%3D?line=79'>80</a>     except:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/Ginkgo%20coding/content-summarization/notebooks/2023-04-13%20prompt%20chaining%20with%20user%20relevance%20added%20-%20part%202.ipynb#Y120sZmlsZQ%3D%3D?line=80'>81</a>         self.simple_summary_dict[new_key] = self.simplify_bot_dict[new_key].gpt(simplify_prompt)
#      <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/Ginkgo%20coding/content-summarization/notebooks/2023-04-13%20prompt%20chaining%20with%20user%20relevance%20added%20-%20part%202.ipynb#Y120sZmlsZQ%3D%3D?line=81'>82</a>         print(f'\t...Error parsing response for summary request')
#      <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/Ginkgo%20coding/content-summarization/notebooks/2023-04-13%20prompt%20chaining%20with%20user%20relevance%20added%20-%20part%202.ipynb#Y120sZmlsZQ%3D%3D?line=82'>83</a> self.simple_summary_dict['simplify_task'] = simplify_task
#
# File ~\OneDrive\lighthouse\Ginkgo coding\content-summarization\src\summarization.py:53, in Chatbot.gpt(self, messages)
#      51 print(f'\t\tRequesting {self.n_choices} choices using {self.model}')
#      52 openai.api_key = os.getenv('api_openai')
# ---> 53 response = openai.ChatCompletion.create(
#      54     model=self.model, messages=messages,
#      55     temperature=self.temperature,
#      56     max_tokens=self.max_tokens,
#      57     n=self.n_choices
#      58     )
#      59 print('\tDone sending request to GPT-3')
#      60 return response
#
# File c:\ProgramData\Anaconda3\envs\gingko2\lib\site-packages\openai\api_resources\chat_completion.py:25, in ChatCompletion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# File c:\ProgramData\Anaconda3\envs\gingko2\lib\site-packages\openai\api_resources\abstract\engine_api_resource.py:153, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     127 @classmethod
#     128 def create(
#     129     cls,
#    (...)
#     136     **params,
#     137 ):
#     138     (
#     139         deployment_id,
#     140         engine,
#    (...)
#     150         api_key, api_base, api_type, api_version, organization, **params
#     151     )
# --> 153     response, _, api_key = requestor.request(
#     154         "post",
#     155         url,
#     156         params=params,
#     157         headers=headers,
#     158         stream=stream,
#     159         request_id=request_id,
#     160         request_timeout=request_timeout,
#     161     )
#     163     if stream:
#     164         # must be an iterator
#     165         assert not isinstance(response, OpenAIResponse)
#
# File c:\ProgramData\Anaconda3\envs\gingko2\lib\site-packages\openai\api_requestor.py:226, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     205 def request(
#     206     self,
#     207     method,
#    (...)
#     214     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     215 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
#     216     result = self.request_raw(
#     217         method.lower(),
#     218         url,
#    (...)
#     224         request_timeout=request_timeout,
#     225     )
# --> 226     resp, got_stream = self._interpret_response(result, stream)
#     227     return resp, got_stream, self.api_key
#
# File c:\ProgramData\Anaconda3\envs\gingko2\lib\site-packages\openai\api_requestor.py:620, in APIRequestor._interpret_response(self, result, stream)
#     612     return (
#     613         self._interpret_response_line(
#     614             line, result.status_code, result.headers, stream=True
#     615         )
#     616         for line in parse_stream(result.iter_lines())
#     617     ), True
#     618 else:
#     619     return (
# --> 620         self._interpret_response_line(
#     621             result.content.decode("utf-8"),
#     622             result.status_code,
#     623             result.headers,
#     624             stream=False,
#     625         ),
#     626         False,
#     627     )
#
# File c:\ProgramData\Anaconda3\envs\gingko2\lib\site-packages\openai\api_requestor.py:683, in APIRequestor._interpret_response_line(self, rbody, rcode, rheaders, stream)
#     681 stream_error = stream and "error" in resp.data
#     682 if stream_error or not 200 <= rcode < 300:
# --> 683     raise self.handle_error_response(
#     684         rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     685     )
#     686 return resp
#
# RateLimitError: Rate limit reached for default-gpt-3.5-turbo in organization org-4l8HUKDtXhH0T7iFErf1JSJg on requests per min. Limit: 3 / min. Please try again in 20s. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method.

# %% [markdown]
# # 4

# %%
import traceback
import time
# from collections import OrderedDict

class Chaining:

    def __init__(self, text):
        self.text = text

    def summarize(self, task, model="gpt-3.5-turbo", temperature=0.7, n_choices=5, max_tokens=1000,
          text_key=['text_discussion'],
        system_role = "You are an expert at science communication."
        ):
        """
        SH 2023-04-11 12:18: Same as the user-defined `reply` function, but re-written as a class method.
        Send a ChatCompletion request to ChatGPT via the Chatbot class.

        Requrired paramaters:
            - task (str): Task to include in ChatGPT prompt.
            - text (str): Text to feed to GPT for summarization.

        Optional parameters
            - system_role (str): ChatGPT parameter. 
                Default is "You are an expert at science communication."
            - temperature (float): ChatGPT parameter. Default is 0.7.
            - n_choices (int): Number of ChatGPT responses to generate. Default is 5.
            - max_tokens (int): Token limit for ChatGPT response.
            - model (str): ChatGPT model to use. Default is "gpt-3.5-turbo".
        """
        chatbot = Chatbot(self.text,
            system_role=system_role, model=model, temperature=temperature, n_choices=n_choices,
            max_tokens=max_tokens
            )
        prompt = chatbot.create_prompt(task)
        firstline_pattern = r'\s?(\S*)(\n*)(.+)'
        title = re.match(firstline_pattern, self.text)[0]
        self.qna = dict() 
        self.qna['article_title'] = title
        self.qna['system_role'] = system_role
        self.qna['prompt'] = task
        self.qna['model'] = model
        self.summaries_dict = dict()
        self.article_title = title
        self.response_regex = r'response_(.*)'

        try:
            response = chatbot.gpt(prompt)
        except:
            print('\t**API request failed**')
            return self.qna
        try:
            for index, choice in enumerate(response.choices):
                self.qna[f'response_{"{:02d}".format(index+1)}'] = choice["message"]["content"]
                self.summaries_dict[f'response_{"{:02d}".format(index+1)}'] = choice["message"]["content"]
            self.qna[f'text'] = self.text
            return self.qna
        except:
            print('\t**Error with response parsing**')
            return self.qna


    def simplify(self, simplify_task, system_role='You are an expert at science communication.',
                    model="gpt-3.5-turbo", temperature=0.0, n_choices=1, max_tokens=1000, 
                    simplify_iteration=None
                    ):
        self.simplify_bot_dict = dict()
        self.simple_summary_dict = dict()
        for key, summary in self.summaries_dict.items():
            new_key = re.sub(self.response_regex, rf'simple_summary\1_prompt{str(simplify_iteration)}', key)
            print(f'\t\t...Preparing to summarize {key}')
            self.simplify_bot_dict[new_key] = Chatbot(
                summary, system_role=system_role,
                model=model, temperature=temperature, n_choices=n_choices, max_tokens=max_tokens
                )
            simplify_prompt = self.simplify_bot_dict[new_key].create_prompt(simplify_task)
            try:
                for index, choice in enumerate(self.simplify_bot_dict[new_key].gpt(simplify_prompt).choices):
                    self.simple_summary_dict[f'{new_key}_option{"{:02d}".format(index+1)}'] = choice["message"]["content"]
                    print(f'\t...Summary given')
            except:
                self.simple_summary_dict[new_key] = self.simplify_bot_dict[new_key].gpt(simplify_prompt)
                print(f'\t...Error parsing response for summary request')
        self.simple_summary_dict['simplify_task'] = simplify_task
        self.qna = {**self.qna, **self.simple_summary_dict}
        try:
            self.qna.update({'text': self.qna.pop('text')})
        except:
            pass
        return self.simple_summary_dict
    
    def add_relevance(self, task, system_role='You are an expert at science communication.',
                    model="gpt-3.5-turbo", temperature=0.0, n_choices=1, max_tokens=1000, 
                    relevance_iteration=None, pause_per_request=20
                    ):
        self.relevance_bot_dict = dict()
        self.relevance_dict = dict()
        if relevance_iteration == None:
            relevance_iteration = 1
        for key, summary in self.summaries_dict.items():
            new_key = re.sub(self.response_regex, rf'relevance\1_prompt{str(relevance_iteration)}', key)
            print(f'\t\t...Preparing to summarize {key}')
            self.relevance_bot_dict[new_key] = Chatbot(
                summary, system_role=system_role,
                model=model, temperature=temperature, n_choices=n_choices, max_tokens=max_tokens
                )
            relevance_prompt = self.relevance_bot_dict[new_key].create_prompt(task)
            try:
                for index, choice in enumerate(self.relevance_bot_dict[new_key].gpt(relevance_prompt).choices):
                    self.relevance_dict[f'{new_key}_option{"{:02d}".format(index+1)}'] = choice["message"]["content"]
                    print(f'\t...Relevance given')
            except:
                try:
                    self.relevance_dict[new_key] = self.relevance_bot_dict[new_key].gpt(relevance_prompt).choices[0]["message"]["content"]
                    print(f'\t...First relevance response given')
                except:
                    self.relevance_dict[new_key] = self.relevance_bot_dict[new_key].gpt(relevance_prompt)
                    print(f'\t...Error parsing response for added relevance request')
            print(f'[add_relevance method] Sleeping {pause_per_request} sec to avoid exceeding API rate limit')
            time.sleep(pause_per_request) # Account for API rate limit of 3 API requests/limit 
        self.relevance_dict[f'relevance_task{"{:02d}".format(relevance_iteration)}'] = task
        self.qna = {**self.qna, **self.relevance_dict}
        try:
            self.qna.update({'text': self.qna.pop('text')})
        except:
            pass
        return self.relevance_dict

def batch_summarize_chain(text_dict, prompts_df, qna_dict,  chaining_bot_dict, iteration_id, n_choices=5,
    prompt_column='prompt',
    save_outputs=False, filename=None, append_version=False,
    csv_path=r'C:\Users\silvh\OneDrive\lighthouse\Ginkgo coding\content-summarization\output',
    pickle_path=r'C:\Users\silvh\OneDrive\lighthouse\Ginkgo coding\content-summarization\output\pickles'
    ):
    """
    Summarize multiple texts using the same prompts.
    Parameters:
        - prompts_df: DataFrame containing the prompts.
        - qna_dict: Dictionary to store the input and outputs.
        - iteration_id (int, float, or string): Unique ID serving as the key for results in the qna_dict
        - prompt_column (str): Name of the column in the prompts_df containing the user input.

    """
    temp_qna_dict = dict()
    prompts_df = prompts_df.reset_index(drop=True)
    qna_dfs_list = []
    chaining_bot_dict[iteration_id] = dict()
    for key in text_dict:
        text = text_dict[key]
        temp_qna_dict[key] = dict()
        for index, input in prompts_df[prompt_column].items():
            print(f'**Text #{key} prompt #{index} of {prompts_df.index.max()}**')
            try:
                chatbot = Chaining(text)
                temp_qna_dict[key][index] = chatbot.summarize(input, n_choices=n_choices)
                chatbot_dict[iteration_id][f'text{key}_prompt{"{:02d}".format(index)}'] = chatbot
                print('\t...Success!')
            except:
                print('\t...Error making chatbot request')
                break
        try:
            prompts_df = prompts_df.drop(prompt_column)
        except:
            pass
        try:
            updated_qna_dict = pd.concat([
                pd.DataFrame(temp_qna_dict[key]),
                prompts_df.transpose()
            ])
        except Exception as error:
            exc_type, exc_obj, tb = sys.exc_info()
            f = tb.tb_frame
            lineno = tb.tb_lineno
            filename = f.f_code.co_filename
            print("An error occurred on line", lineno, "in", filename, ":", error)
            print('Error concatenating prompts DataFrame')
            return temp_qna_dict, chatbot_dict
        try:
            qna_dfs_list.append(updated_qna_dict)
            qna_dict[iteration_id] = pd.concat(qna_dfs_list, axis=1)
            if save_outputs:
                try:
                    append_version = append_version if filename else False
                    filename = filename if filename else f'{datetime.now().strftime("%Y-%m-%d_%H%M")}_prompt_experiments_{"{:02d}".format(iteration_id)}'
                    savepickle(qna_dict[iteration_id], filename=filename, path=pickle_path, append_version=append_version)
                    save_csv(qna_dict[iteration_id], filename=filename, path=pickle_path, append_version=append_version)
                except:
                    print('Unable to save outputs')
        except:
            print('Error concatenating DataFrames')
    return qna_dict, chatbot_dict

def prompt_chaining_dict(simplify_prompts, qna_chain_dict, chaining_bot_dict, iteration_id,
    summary_iteration_id=None, n_choices=None, pause_per_request=20,
    prompt_column='simplify', simplify_iteration=None
    ):
    """
    Simplify or add context to a summary.
    """
    summary_iteration_id = summary_iteration_id if summary_iteration_id else iteration_id
    print('summary_iteration_id:', summary_iteration_id)
    if n_choices == None:
        n_choices = 1 if prompt_column == 'simplify' else 5
    print('n_choices:', n_choices)
    if type(simplify_prompts) == str:
        simplify_prompts = [simplify_prompts]
    elif type(simplify_prompts) == pd.core.frame.DataFrame:
        simplify_prompts = [prompt for prompt in simplify_prompts[prompt_column].unique() if len(prompt) >1]
    else:
        simplify_prompts = list(set([prompt for prompt in simplify_prompts if len(prompt) >1]))
    simple_summaries_master_dict = dict()
    simple_summaries_df = pd.DataFrame()
    for column, text_prompt_key in enumerate(chaining_bot_dict):
        print(f'**{text_prompt_key}')
        simple_summaries_master_dict[text_prompt_key] = dict()

        for index, prompt in enumerate(simplify_prompts):
            relevance_iteration=index if len(simplify_prompts) > 1 else simplify_iteration
            print(f'\t...Prompt: {prompt}, iteration {relevance_iteration}')
            if prompt_column == 'simplify':
                summary_dict = chaining_bot_dict[text_prompt_key].simplify(
                    prompt, n_choices=n_choices,
                    simplify_iteration=index if len(simplify_prompts) > 1 else simplify_iteration
                    )
            else: 
                summary_dict = chaining_bot_dict[text_prompt_key].add_relevance(
                    prompt, n_choices=n_choices, pause_per_request=pause_per_request, 
                    relevance_iteration=index if len(simplify_prompts) > 1 else simplify_iteration
                    )
            simple_summaries_master_dict[text_prompt_key] = {**simple_summaries_master_dict[text_prompt_key], **summary_dict}
        try:
            simple_summaries_df[column] = pd.DataFrame([
                pd.Series(value, name=key) for key, value in simple_summaries_master_dict[text_prompt_key].items()
            ])   
        except Exception as error:
            exc_type, exc_obj, tb = sys.exc_info()
            f = tb.tb_frame
            lineno = tb.tb_lineno
            filename = f.f_code.co_filename
            print("An error occurred on line", lineno, "in", filename, ":", error)
            print('Unable to create results DataFrame')
            
            qna_chain_dict[iteration_id+0.001] = simple_summaries_master_dict
    try:
        qna_chain_dict[summary_iteration_id].columns = [i for i in range(len(qna_chain_dict[summary_iteration_id].columns))]
        temp_qna_chain_dict = pd.concat([
            qna_chain_dict[summary_iteration_id], 
            simple_summaries_df
            ])
        qna_chain_dict[iteration_id] = temp_qna_chain_dict
        print(f"{'Simple summaries' if prompt_column=='simplify' else 'Article relevance for user'} added to original DataFrame")
    except Exception as error:
        exc_type, exc_obj, tb = sys.exc_info()
        f = tb.tb_frame
        lineno = tb.tb_lineno
        filename = f.f_code.co_filename
        print("An error occurred on line", lineno, "in", filename, ":", error)
        print('Unable to concatenate simple summary DataFrame to original DataFrame')
        qna_chain_dict[iteration_id+0.001] = simple_summaries_master_dict

    return qna_chain_dict

iteration_id = 4
n_choices = 2
# qna_dict = dict()
# qna_chain_dict = dict()
# chatbot_dict = dict()

qna_dict, chaining_dict = batch_summarize_chain(text_dict, prompts_df, qna_dict, chatbot_dict, 
    iteration_id=iteration_id, n_choices=n_choices)


# simplify_prompts = task_part2
# summary_iteration_id = 3
# qna_dict = prompt_chaining_dict(simplify_prompts, qna_dict, chaining_dict[summary_iteration_id], iteration_id,
#     summary_iteration_id=summary_iteration_id
#     )

# summary_iteration_id = iteration_id
# summary_iteration_id = 2
# n_choices = 2
# relevance_prompts = relevance_prompts_df
# pause_per_request=20
# qna_dict = prompt_chaining_dict(relevance_prompts, qna_dict, chaining_dict[summary_iteration_id], iteration_id,
#     prompt_column='relevance', n_choices=n_choices, pause_per_request=pause_per_request,
#     simplify_iteration=1, summary_iteration_id=summary_iteration_id
#     )
# Out:
# **Text #1 prompt #0 of 1**
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Success!
# **Text #1 prompt #1 of 1**
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Success!
# **Text #2 prompt #0 of 1**
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Success!
# **Text #2 prompt #1 of 1**
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Success!

# %% [markdown]
# ## 4.1 Add pause to .simplify()

# %%
import traceback
import time
# from collections import OrderedDict

class Chaining:

    def __init__(self, text):
        self.text = text

    def summarize(self, task, model="gpt-3.5-turbo", temperature=0.7, n_choices=5, max_tokens=1000,
          text_key=['text_discussion'],
        system_role = "You are an expert at science communication."
        ):
        """
        SH 2023-04-11 12:18: Same as the user-defined `reply` function, but re-written as a class method.
        Send a ChatCompletion request to ChatGPT via the Chatbot class.

        Requrired paramaters:
            - task (str): Task to include in ChatGPT prompt.
            - text (str): Text to feed to GPT for summarization.

        Optional parameters
            - system_role (str): ChatGPT parameter. 
                Default is "You are an expert at science communication."
            - temperature (float): ChatGPT parameter. Default is 0.7.
            - n_choices (int): Number of ChatGPT responses to generate. Default is 5.
            - max_tokens (int): Token limit for ChatGPT response.
            - model (str): ChatGPT model to use. Default is "gpt-3.5-turbo".
        """
        chatbot = Chatbot(self.text,
            system_role=system_role, model=model, temperature=temperature, n_choices=n_choices,
            max_tokens=max_tokens
            )
        prompt = chatbot.create_prompt(task)
        firstline_pattern = r'\s?(\S*)(\n*)(.+)'
        title = re.match(firstline_pattern, self.text)[0]
        self.qna = dict() 
        self.qna['article_title'] = title
        self.qna['system_role'] = system_role
        self.qna['prompt'] = task
        self.qna['model'] = model
        self.summaries_dict = dict()
        self.article_title = title
        self.response_regex = r'response_(.*)'

        try:
            response = chatbot.gpt(prompt)
        except:
            print('\t**API request failed**')
            return self.qna
        try:
            for index, choice in enumerate(response.choices):
                self.qna[f'response_{"{:02d}".format(index+1)}'] = choice["message"]["content"]
                self.summaries_dict[f'response_{"{:02d}".format(index+1)}'] = choice["message"]["content"]
            self.qna[f'text'] = self.text
            return self.qna
        except:
            print('\t**Error with response parsing**')
            return self.qna


    def simplify(self, simplify_task, system_role='You are an expert at science communication.',
                    model="gpt-3.5-turbo", temperature=0.0, n_choices=1, max_tokens=1000, 
                    simplify_iteration=None, pause_per_request=20
                    ):
        self.simplify_bot_dict = dict()
        self.simple_summary_dict = dict()
        for key, summary in self.summaries_dict.items():
            new_key = re.sub(self.response_regex, rf'simple_summary\1_prompt{str(simplify_iteration)}', key)
            print(f'\t\t...Preparing to summarize {key}')
            self.simplify_bot_dict[new_key] = Chatbot(
                summary, system_role=system_role,
                model=model, temperature=temperature, n_choices=n_choices, max_tokens=max_tokens
                )
            simplify_prompt = self.simplify_bot_dict[new_key].create_prompt(simplify_task)
            try:
                for index, choice in enumerate(self.simplify_bot_dict[new_key].gpt(simplify_prompt).choices):
                    self.simple_summary_dict[f'{new_key}_option{"{:02d}".format(index+1)}'] = choice["message"]["content"]
                    print(f'\t...Summary given')
            except:
                self.simple_summary_dict[new_key] = self.simplify_bot_dict[new_key].gpt(simplify_prompt)
                print(f'\t...Error parsing response for summary request')
            print(f'[.simplify()] Sleeping {pause_per_request} sec to avoid exceeding API rate limit')
            time.sleep(pause_per_request) # Account for API rate limit of 3 API requests/limit 
        self.simple_summary_dict['simplify_task'] = simplify_task
        self.qna = {**self.qna, **self.simple_summary_dict}
        try:
            self.qna.update({'text': self.qna.pop('text')})
        except:
            pass
        return self.simple_summary_dict
    
    def add_relevance(self, task, system_role='You are an expert at science communication.',
                    model="gpt-3.5-turbo", temperature=0.0, n_choices=1, max_tokens=1000, 
                    relevance_iteration=None, pause_per_request=20
                    ):
        self.relevance_bot_dict = dict()
        self.relevance_dict = dict()
        if relevance_iteration == None:
            relevance_iteration = 1
        for key, summary in self.summaries_dict.items():
            new_key = re.sub(self.response_regex, rf'relevance\1_prompt{str(relevance_iteration)}', key)
            print(f'\t\t...Preparing to summarize {key}')
            self.relevance_bot_dict[new_key] = Chatbot(
                summary, system_role=system_role,
                model=model, temperature=temperature, n_choices=n_choices, max_tokens=max_tokens
                )
            relevance_prompt = self.relevance_bot_dict[new_key].create_prompt(task)
            try:
                for index, choice in enumerate(self.relevance_bot_dict[new_key].gpt(relevance_prompt).choices):
                    self.relevance_dict[f'{new_key}_option{"{:02d}".format(index+1)}'] = choice["message"]["content"]
                    print(f'\t...Relevance given')
            except:
                try:
                    self.relevance_dict[new_key] = self.relevance_bot_dict[new_key].gpt(relevance_prompt).choices[0]["message"]["content"]
                    print(f'\t...First relevance response given')
                except:
                    self.relevance_dict[new_key] = self.relevance_bot_dict[new_key].gpt(relevance_prompt)
                    print(f'\t...Error parsing response for added relevance request')
            print(f'[.add_relevance()] Sleeping {pause_per_request} sec to avoid exceeding API rate limit')
            time.sleep(pause_per_request) # Account for API rate limit of 3 API requests/limit 
        self.relevance_dict[f'relevance_task{"{:02d}".format(relevance_iteration)}'] = task
        self.qna = {**self.qna, **self.relevance_dict}
        try:
            self.qna.update({'text': self.qna.pop('text')})
        except:
            pass
        return self.relevance_dict

def batch_summarize_chain(text_dict, prompts_df, qna_dict,  chaining_bot_dict, iteration_id, n_choices=5,
    prompt_column='prompt',
    save_outputs=False, filename=None, append_version=False,
    csv_path=r'C:\Users\silvh\OneDrive\lighthouse\Ginkgo coding\content-summarization\output',
    pickle_path=r'C:\Users\silvh\OneDrive\lighthouse\Ginkgo coding\content-summarization\output\pickles'
    ):
    """
    Summarize multiple texts using the same prompts.
    Parameters:
        - prompts_df: DataFrame containing the prompts.
        - qna_dict: Dictionary to store the input and outputs.
        - iteration_id (int, float, or string): Unique ID serving as the key for results in the qna_dict
        - prompt_column (str): Name of the column in the prompts_df containing the user input.

    """
    temp_qna_dict = dict()
    prompts_df = prompts_df.reset_index(drop=True)
    qna_dfs_list = []
    chaining_bot_dict[iteration_id] = dict()
    for key in text_dict:
        text = text_dict[key]
        temp_qna_dict[key] = dict()
        for index, input in prompts_df[prompt_column].items():
            print(f'**Text #{key} prompt #{index} of {prompts_df.index.max()}**')
            try:
                chatbot = Chaining(text)
                temp_qna_dict[key][index] = chatbot.summarize(input, n_choices=n_choices)
                chatbot_dict[iteration_id][f'text{key}_prompt{"{:02d}".format(index)}'] = chatbot
                print('\t...Success!')
            except:
                print('\t...Error making chatbot request')
                break
        try:
            prompts_df = prompts_df.drop(prompt_column)
        except:
            pass
        try:
            updated_qna_dict = pd.concat([
                pd.DataFrame(temp_qna_dict[key]),
                prompts_df.transpose()
            ])
        except Exception as error:
            exc_type, exc_obj, tb = sys.exc_info()
            f = tb.tb_frame
            lineno = tb.tb_lineno
            filename = f.f_code.co_filename
            print("An error occurred on line", lineno, "in", filename, ":", error)
            print('Error concatenating prompts DataFrame')
            return temp_qna_dict, chatbot_dict
        try:
            qna_dfs_list.append(updated_qna_dict)
            qna_dict[iteration_id] = pd.concat(qna_dfs_list, axis=1)
            if save_outputs:
                try:
                    append_version = append_version if filename else False
                    filename = filename if filename else f'{datetime.now().strftime("%Y-%m-%d_%H%M")}_prompt_experiments_{"{:02d}".format(iteration_id)}'
                    savepickle(qna_dict[iteration_id], filename=filename, path=pickle_path, append_version=append_version)
                    save_csv(qna_dict[iteration_id], filename=filename, path=pickle_path, append_version=append_version)
                except:
                    print('Unable to save outputs')
        except:
            print('Error concatenating DataFrames')
    return qna_dict, chatbot_dict

def prompt_chaining_dict(simplify_prompts, qna_chain_dict, chaining_bot_dict, iteration_id,
    summary_iteration_id=None, n_choices=None, pause_per_request=20,
    prompt_column='simplify', simplify_iteration=None
    ):
    """
    Simplify or add context to a summary.
    """
    summary_iteration_id = summary_iteration_id if summary_iteration_id else iteration_id
    print('summary_iteration_id:', summary_iteration_id)
    if n_choices == None:
        n_choices = 1 if prompt_column == 'simplify' else 5
    print('n_choices:', n_choices)
    if type(simplify_prompts) == str:
        simplify_prompts = [simplify_prompts]
    elif type(simplify_prompts) == pd.core.frame.DataFrame:
        simplify_prompts = [prompt for prompt in simplify_prompts[prompt_column].unique() if len(prompt) >1]
    else:
        simplify_prompts = list(set([prompt for prompt in simplify_prompts if len(prompt) >1]))
    simple_summaries_master_dict = dict()
    simple_summaries_df = pd.DataFrame()
    for column, text_prompt_key in enumerate(chaining_bot_dict):
        print(f'**{text_prompt_key}')
        simple_summaries_master_dict[text_prompt_key] = dict()

        for index, prompt in enumerate(simplify_prompts):
            relevance_iteration=index if len(simplify_prompts) > 1 else simplify_iteration
            print(f'\t...Prompt: {prompt}, iteration {relevance_iteration}')
            if prompt_column == 'simplify':
                summary_dict = chaining_bot_dict[text_prompt_key].simplify(
                    prompt, n_choices=n_choices, pause_per_request=pause_per_request, 
                    simplify_iteration=index if len(simplify_prompts) > 1 else simplify_iteration
                    )
            else: 
                summary_dict = chaining_bot_dict[text_prompt_key].add_relevance(
                    prompt, n_choices=n_choices, pause_per_request=pause_per_request, 
                    relevance_iteration=index if len(simplify_prompts) > 1 else simplify_iteration
                    )
            simple_summaries_master_dict[text_prompt_key] = {**simple_summaries_master_dict[text_prompt_key], **summary_dict}
        try:
            simple_summaries_df[column] = pd.DataFrame([
                pd.Series(value, name=key) for key, value in simple_summaries_master_dict[text_prompt_key].items()
            ])   
        except Exception as error:
            exc_type, exc_obj, tb = sys.exc_info()
            f = tb.tb_frame
            lineno = tb.tb_lineno
            filename = f.f_code.co_filename
            print("An error occurred on line", lineno, "in", filename, ":", error)
            print('Unable to create results DataFrame')
            
            qna_chain_dict[iteration_id+0.001] = simple_summaries_master_dict
    try:
        qna_chain_dict[summary_iteration_id].columns = [i for i in range(len(qna_chain_dict[summary_iteration_id].columns))]
        temp_qna_chain_dict = pd.concat([
            qna_chain_dict[summary_iteration_id], 
            simple_summaries_df
            ])
        qna_chain_dict[iteration_id] = temp_qna_chain_dict
        print(f"{'Simple summaries' if prompt_column=='simplify' else 'Article relevance for user'} added to original DataFrame")
    except Exception as error:
        exc_type, exc_obj, tb = sys.exc_info()
        f = tb.tb_frame
        lineno = tb.tb_lineno
        filename = f.f_code.co_filename
        print("An error occurred on line", lineno, "in", filename, ":", error)
        print('Unable to concatenate simple summary DataFrame to original DataFrame')
        qna_chain_dict[iteration_id+0.001] = simple_summaries_master_dict

    return qna_chain_dict

iteration_id = 4.1
n_choices = 2
# qna_dict = dict()
# qna_chain_dict = dict()
# chatbot_dict = dict()

# qna_dict, chaining_dict = batch_summarize_chain(text_dict, prompts_df, qna_dict, chatbot_dict, 
#     iteration_id=iteration_id, n_choices=n_choices)


simplify_prompts = task_part2
summary_iteration_id = 4
# summary_iteration_id = iteration_id
qna_dict = prompt_chaining_dict(simplify_prompts, qna_dict, chaining_dict[summary_iteration_id], iteration_id,
    summary_iteration_id=summary_iteration_id
    )

# summary_iteration_id = iteration_id
# summary_iteration_id = 2
# n_choices = 2
# relevance_prompts = relevance_prompts_df
# pause_per_request=20
# qna_dict = prompt_chaining_dict(relevance_prompts, qna_dict, chaining_dict[summary_iteration_id], iteration_id,
#     prompt_column='relevance', n_choices=n_choices, pause_per_request=pause_per_request,
#     simplify_iteration=1, summary_iteration_id=summary_iteration_id
#     )
# Out:
# summary_iteration_id: 4
# n_choices: 1
# **text1_prompt00
# 	...Prompt: Use terms a 12-year-old can understand., iteration None
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 1 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Summary given
# [.simplify()] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 1 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Summary given
# [.simplify()] Sleeping 20 sec to avoid exceeding API rate limit
# **text1_prompt01
# 	...Prompt: Use terms a 12-year-old can understand., iteration None
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 1 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Summary given
# [.simplify()] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 1 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Summary given
# [.simplify()] Sleeping 20 sec to avoid exceeding API rate limit
# **text2_prompt00
# 	...Prompt: Use terms a 12-year-old can understand., iteration None
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 1 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Summary given
# [.simplify()] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 1 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Summary given
# [.simplify()] Sleeping 20 sec to avoid exceeding API rate limit
# **text2_prompt01
# 	...Prompt: Use terms a 12-year-old can understand., iteration None
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 1 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Summary given
# [.simplify()] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 1 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Summary given
# [.simplify()] Sleeping 20 sec to avoid exceeding API rate limit
# Simple summaries added to original DataFrame

# %% [markdown]
# ### Success

# %%
qna_dict[iteration_id].tail()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 0  \
# task part 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Summarize for a LinkedIn post
# prompt                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Take the key points and numerical descriptors to Summarize for a LinkedIn post.
# simple_summary01_promptNone_option01                                             A new study looked at how sleep affects athletes. They found that getting more sleep can help athletes perform better or not affect their performance at all. Doing exercises that use a lot of oxygen, like running, is more affected by sleep than exercises that don't, like weightlifting. Sleeping also helps athletes with their thinking and technical skills. If athletes get more sleep over a long time, it can help them do better. But if they don't get enough sleep for a short time, it can hurt their performance. The study says we need to look more into how not getting enough sleep for a long time can hurt athletes. So, if you're an athlete, getting more sleep can help you do better!
# simple_summary02_promptNone_option01  A study looked at how sleep affects how well athletes perform. They found that getting more sleep can help athletes do better, especially when doing activities that need a lot of oxygen. They also found that getting enough sleep can help with skills that need a lot of thinking and planning. Studies that looked at athletes who got more sleep for a longer time also showed good results. Not getting enough sleep can be worse for performance than getting more sleep is good. We need more research to know for sure how sleep affects how well athletes think they did and how well they actually did. It's a good idea for athletes to try to get enough sleep not just the night before a big event, but also in the weeks leading up to it.
# simplify_task                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Use terms a 12-year-old can understand.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    1  \
# task part 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Describe the interesting points to your coworker at the water cooler
# prompt                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Take the key points and numerical descriptors to Describe the interesting points to your coworker at the water cooler.
# simple_summary01_promptNone_option01  Hey there! Did you know that getting enough sleep is really important for athletes? A bunch of studies looked at how sleep affects how well athletes perform, and they found some cool stuff. None of the studies showed that getting more sleep made athletes do worse. Actually, all the studies showed that getting more sleep either helped athletes perform better or didn't make a difference. Doing exercises that make you breathe hard (like running) is more affected by sleep than exercises that don't (like lifting weights). Studies that looked at how sleep affects athletes over a long time showed more of an effect than studies that only looked at one night of sleep. Getting more sleep over a long time can really help athletes do better. Scientists still need to do more research to figure out exactly how sleep affects different parts of athletic performance.
# simple_summary02_promptNone_option01                                                                                                                            Did you know that getting enough sleep is really important for athletes? A study looked at lots of other studies and found that getting more sleep can actually help athletes perform better or at least doesn't hurt their performance. It seems like activities that require a lot of running or moving around are more affected by sleep than activities that don't. And if athletes need to use their brains a lot, like for strategy or technique, getting enough sleep is especially important. The study also found that getting more sleep over a longer period of time is better than just getting more sleep for one night. So, it's really important for athletes to make sure they get enough sleep, especially if they want to do well in the long run.
# simplify_task                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Use terms a 12-year-old can understand.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            2  \
# task part 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Summarize for a LinkedIn post
# prompt                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Take the key points and numerical descriptors to Summarize for a LinkedIn post.
# simple_summary01_promptNone_option01  Scientists did an experiment with people to see how food and stress affect our desire to eat yummy but unhealthy foods. They found that when people were exposed to pictures of delicious food and felt stressed, they wanted to eat more of those foods. Two hormones in our bodies, called ghrelin and cortisol, also played a big role in making us want to eat. The scientists think we need to study more about how our bodies and brains work together to make us crave and eat unhealthy foods, especially if we want to understand why some people struggle with their weight.
# simple_summary02_promptNone_option01                                                                                  A new study found that when people see or think about yummy food and feel stressed, they want to eat more of that kind of food. This is especially true for people who are overweight. The study also found that two hormones in our body, ghrelin and cortisol, can make us want to eat more. This means we need to learn more about how our body and mind work together when we want to eat unhealthy food, especially if we want to understand why some people gain weight more easily than others.
# simplify_task                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Use terms a 12-year-old can understand.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        3
# task part 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Describe the interesting points to your coworker at the water cooler
# prompt                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Take the key points and numerical descriptors to Describe the interesting points to your coworker at the water cooler.
# simple_summary01_promptNone_option01          Did you know that when we see or think about yummy food and feel stressed, we tend to eat more of that yummy food? This study found that people who were shown pictures of yummy food and felt stressed ate more of that food than people who were in a calm and relaxing environment. The study also found that people who were overweight were more likely to eat more of that yummy food when they were stressed compared to people who were not overweight. The study also found that hormones in our body, called ghrelin and cortisol, can affect how much we want to eat. This study suggests that we need to learn more about how our body and mind work together when it comes to eating yummy food, especially for people who are trying to manage their weight.
# simple_summary02_promptNone_option01  Hey! I just read about a study that looked at how seeing pictures of yummy food and feeling stressed affects how much people want to eat and actually eat. They found that both things make people want to eat more of the yummy food, but it affects people who are overweight and people who are not overweight differently. Two hormones in our body, ghrelin and cortisol, also affect how much we want to eat, but they work differently in people who are overweight and people who are not overweight. People who are overweight might not feel as stressed when they see pictures of yummy food, which could make them want to eat more of it. This study shows that we need to learn more about how our body and mind work together to make us want to eat certain foods.
# simplify_task                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Use terms a 12-year-old can understand.

# %%
# summary_iteration_id = iteration_id
# summary_iteration_id = 2
# n_choices = 2
# relevance_prompts = relevance_prompts_df
# pause_per_request=20
# qna_dict = prompt_chaining_dict(relevance_prompts, qna_dict, chaining_dict[summary_iteration_id], iteration_id,
#     prompt_column='relevance', n_choices=n_choices, pause_per_request=pause_per_request,
#     simplify_iteration=1, summary_iteration_id=summary_iteration_id
#     )

# %%
# summary_iteration_id = iteration_id
summary_iteration_id = 4
n_choices = 2
relevance_prompts = relevance_prompts_df
pause_per_request=20
qna_dict = prompt_chaining_dict(relevance_prompts, qna_dict, chaining_dict[summary_iteration_id], iteration_id,
    prompt_column='relevance', n_choices=n_choices, pause_per_request=pause_per_request,
    simplify_iteration=1, summary_iteration_id=summary_iteration_id
    )
# Out:
# summary_iteration_id: 4
# n_choices: 2
# **text1_prompt00
# 	...Prompt:  Add 1-2 sentences to make this relevant for seniors , iteration 0
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [.add_relevance()] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [.add_relevance()] Sleeping 20 sec to avoid exceeding API rate limit
# 	...Prompt:  Add 1-2 sentences to make this relevant for people who enjoy sports , iteration 1
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [.add_relevance()] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [.add_relevance()] Sleeping 20 sec to avoid exceeding API rate limit
# **text1_prompt01
# 	...Prompt:  Add 1-2 sentences to make this relevant for seniors , iteration 0
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [.add_relevance()] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [.add_relevance()] Sleeping 20 sec to avoid exceeding API rate limit
# 	...Prompt:  Add 1-2 sentences to make this relevant for people who enjoy sports , iteration 1
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [.add_relevance()] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [.add_relevance()] Sleeping 20 sec to avoid exceeding API rate limit
# **text2_prompt00
# 	...Prompt:  Add 1-2 sentences to make this relevant for seniors , iteration 0
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [.add_relevance()] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [.add_relevance()] Sleeping 20 sec to avoid exceeding API rate limit
# 	...Prompt:  Add 1-2 sentences to make this relevant for people who enjoy sports , iteration 1
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [.add_relevance()] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [.add_relevance()] Sleeping 20 sec to avoid exceeding API rate limit
# **text2_prompt01
# 	...Prompt:  Add 1-2 sentences to make this relevant for seniors , iteration 0
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [.add_relevance()] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [.add_relevance()] Sleeping 20 sec to avoid exceeding API rate limit
# 	...Prompt:  Add 1-2 sentences to make this relevant for people who enjoy sports , iteration 1
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [.add_relevance()] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Relevance given
# 	...Relevance given
# [.add_relevance()] Sleeping 20 sec to avoid exceeding API rate limit
# Article relevance for user added to original DataFrame

# %%
print(qna_dict[iteration_id].shape)
print(qna_dict[iteration_id].index)
# Out:
# (20, 4)
# Index(['article_title', 'system_role', 'prompt', 'model', 'response_01',
#        'response_02', 'text', 'prep_step', 'task part 1', 'prompt',
#        'relevance01_prompt0_option01', 'relevance01_prompt0_option02',
#        'relevance02_prompt0_option01', 'relevance02_prompt0_option02',
#        'relevance_task00', 'relevance01_prompt1_option01',
#        'relevance01_prompt1_option02', 'relevance02_prompt1_option01',
#        'relevance02_prompt1_option02', 'relevance_task01'],
#       dtype='object')

# %%
qna_dict[iteration_id].tail(10)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        0  \
# relevance01_prompt0_option01  For seniors who engage in physical activity, it is important to prioritize getting enough sleep as it can have a positive impact on their performance. This literature review suggests that longer-term sleep extension can be beneficial, while short-term sleep deprivation may be harmful. It is recommended that seniors prioritize their sleep to optimize their athletic performance. #seniors #sleepduration #performancetips #sportsmedicine #sciencecommunication
# relevance01_prompt0_option02  For seniors who engage in physical activity, it is important to prioritize getting enough sleep as it can have a positive impact on their performance. This literature review suggests that longer-term sleep extension can be beneficial, while short-term sleep deprivation may be harmful. It is recommended that seniors prioritize their sleep to optimize their athletic performance. #seniors #sleepduration #performancetips #sportsmedicine #sciencecommunication
# relevance02_prompt0_option01                                                                                                                                                      For seniors, getting enough sleep is crucial for maintaining physical and cognitive health. Studies have shown that sleep deprivation can lead to increased risk of falls, cognitive decline, and other health issues. Therefore, seniors should prioritize getting enough sleep to maintain their overall well-being.
# relevance02_prompt0_option02                                                                                                                                                      For seniors, getting enough sleep is crucial for maintaining physical and cognitive health. Studies have shown that sleep deprivation can lead to increased risk of falls, cognitive decline, and other health issues. Therefore, seniors should prioritize getting enough sleep to maintain their overall well-being.
# relevance_task00                                                                                                                                                                                                                                                                                                                                                                                                                                    Add 1-2 sentences to make this relevant for seniors
# relevance01_prompt1_option01                                                                                                                          If you're an athlete looking to improve your performance, this study suggests that getting more sleep could be a game-changer. Not only does it benefit your aerobic activity and technical skills, but longer-term sleep extension can also lead to positive results. So, make sure to prioritize your sleep to take your game to the next level!
# relevance01_prompt1_option02                                                                                                                          If you're an athlete looking to improve your performance, this study suggests that getting more sleep could be a game-changer. Not only does it benefit your aerobic activity and technical skills, but longer-term sleep extension can also lead to positive results. So, make sure to prioritize your sleep to take your game to the next level!
# relevance02_prompt1_option01                                                                                          If you're an athlete looking to improve your performance, getting enough sleep is crucial. Studies have shown that longer sleep duration can positively impact your athletic abilities, especially for activities that require tactical and technical skills. So, make sure to prioritize your sleep not just the night before a big game, but also in the weeks leading up to it.
# relevance02_prompt1_option02                                                                                          If you're an athlete looking to improve your performance, getting enough sleep is crucial. Studies have shown that longer sleep duration can positively impact your athletic abilities, especially for activities that require tactical and technical skills. So, make sure to prioritize your sleep not just the night before a big game, but also in the weeks leading up to it.
# relevance_task01                                                                                                                                                                                                                                                                                                                                                                                                                    Add 1-2 sentences to make this relevant for people who enjoy sports
#
#                                                                                                                                                                                                                                                                                                                                                                                                                  1  \
# relevance01_prompt0_option01                                                      For seniors, it is important to prioritize getting enough sleep as it can have a positive impact on their physical and cognitive performance. This literature review suggests that increasing sleep duration may be particularly beneficial for aerobic activities, which can help seniors maintain their cardiovascular health.
# relevance01_prompt0_option02                                                      For seniors, it is important to prioritize getting enough sleep as it can have a positive impact on their physical and cognitive performance. This literature review suggests that increasing sleep duration may be particularly beneficial for aerobic activities, which can help seniors maintain their cardiovascular health.
# relevance02_prompt0_option01                                           For seniors, it is important to prioritize getting enough sleep as it can have a positive impact on their physical and cognitive performance. This literature review suggests that increasing sleep duration may be particularly beneficial for seniors engaging in aerobic activities or those requiring tactical and/or technical skills.
# relevance02_prompt0_option02                                           For seniors, it is important to prioritize getting enough sleep as it can have a positive impact on their physical and cognitive performance. This literature review suggests that increasing sleep duration may be particularly beneficial for seniors engaging in aerobic activities or those requiring tactical and/or technical skills.
# relevance_task00                                                                                                                                                                                                                                                                                                                                              Add 1-2 sentences to make this relevant for seniors
# relevance01_prompt1_option01                          If you're an athlete looking to improve your performance, it's important to prioritize getting enough sleep. Studies have shown that increasing your sleep duration can have a positive impact on your athletic abilities, especially for aerobic activities. So, make sure to get those Z's in to help you reach your full potential on the field or court!
# relevance01_prompt1_option02                          If you're an athlete looking to improve your performance, it's important to prioritize getting enough sleep. Studies have shown that increasing your sleep duration can have a positive impact on your athletic abilities, especially for aerobic activities. So, make sure to get those Z's in to help you reach your full potential on the field or court!
# relevance02_prompt1_option01  So, if you're an athlete looking to improve your performance, it's important to prioritize getting enough sleep, especially if you're engaging in aerobic activities or require tactical and technical skills. And while short-term sleep deprivation can be harmful, making an effort to extend your sleep in the long term may contribute to better results on the field or court.
# relevance02_prompt1_option02  So, if you're an athlete looking to improve your performance, it's important to prioritize getting enough sleep, especially if you're engaging in aerobic activities or require tactical and technical skills. And while short-term sleep deprivation can be harmful, making an effort to extend your sleep in the long term may contribute to better results on the field or court.
# relevance_task01                                                                                                                                                                                                                                                                                                                              Add 1-2 sentences to make this relevant for people who enjoy sports
#
#                                                                                                                                                                                                                                                                                                                                                                                                                       2  \
# relevance01_prompt0_option01                                                         These findings are particularly relevant for seniors who may be experiencing changes in their appetite and food preferences. Understanding the biobehavioral processes that contribute to food cravings and intake can help seniors make informed decisions about their diet and potentially prevent weight-related health issues.
# relevance01_prompt0_option02                                                         These findings are particularly relevant for seniors who may be experiencing changes in their appetite and food preferences. Understanding the biobehavioral processes that contribute to food cravings and intake can help seniors make informed decisions about their diet and potentially prevent weight-related health issues.
# relevance02_prompt0_option01   These findings are particularly relevant for seniors who may experience stressors related to aging, such as health concerns or social isolation, which could increase their cravings for highly palatable foods. It is important for seniors to be aware of these biobehavioral processes and to make conscious choices about their food intake to maintain their health and well-being.
# relevance02_prompt0_option02   These findings are particularly relevant for seniors who may experience stressors related to aging, such as health concerns or social isolation, which could increase their cravings for highly palatable foods. It is important for seniors to be aware of these biobehavioral processes and to make conscious choices about their food intake to maintain their health and well-being.
# relevance_task00                                                                                                                                                                                                                                                                                                                                                   Add 1-2 sentences to make this relevant for seniors
# relevance01_prompt1_option01                               These findings may also be relevant for athletes who need to maintain a healthy diet and avoid overconsumption of HP foods that can negatively impact their performance. Understanding the biobehavioral processes that drive food motivation and intake can help athletes make informed decisions about their diet and optimize their athletic performance.
# relevance01_prompt1_option02                               These findings may also be relevant for athletes who need to maintain a healthy diet and avoid overconsumption of HP foods that can negatively impact their performance. Understanding the biobehavioral processes that drive food motivation and intake can help athletes make informed decisions about their diet and optimize their athletic performance.
# relevance02_prompt1_option01  For athletes and sports enthusiasts, understanding the biobehavioral processes underlying food motivation and intake can be crucial in maintaining a healthy diet and achieving optimal performance. This study highlights the impact of personal food cues and stressors on food craving and snacking, which can have implications for athletes looking to manage their diet and weight.
# relevance02_prompt1_option02  For athletes and sports enthusiasts, understanding the biobehavioral processes underlying food motivation and intake can be crucial in maintaining a healthy diet and achieving optimal performance. This study highlights the impact of personal food cues and stressors on food craving and snacking, which can have implications for athletes looking to manage their diet and weight.
# relevance_task01                                                                                                                                                                                                                                                                                                                                   Add 1-2 sentences to make this relevant for people who enjoy sports
#
#                                                                                                                                                                                                                                                                                                                                                                                                            3
# relevance01_prompt0_option01  These findings are particularly relevant for seniors who may experience stressors related to aging, such as health concerns or social isolation, which could increase their cravings for highly palatable foods. Understanding the biobehavioral processes underlying food motivation and intake can help seniors make informed decisions about their diet and overall health.
# relevance01_prompt0_option02  These findings are particularly relevant for seniors who may experience stressors related to aging, such as health concerns or social isolation, which could increase their cravings for highly palatable foods. Understanding the biobehavioral processes underlying food motivation and intake can help seniors make informed decisions about their diet and overall health.
# relevance02_prompt0_option01                This study is particularly relevant for seniors as they may be more susceptible to stress and food cues due to changes in their daily routines and social interactions. Understanding the biobehavioral processes underlying HP food motivation and intake can help seniors make informed decisions about their diet and manage their cravings more effectively.
# relevance02_prompt0_option02                This study is particularly relevant for seniors as they may be more susceptible to stress and food cues due to changes in their daily routines and social interactions. Understanding the biobehavioral processes underlying HP food motivation and intake can help seniors make informed decisions about their diet and manage their cravings more effectively.
# relevance_task00                                                                                                                                                                                                                                                                                                                                        Add 1-2 sentences to make this relevant for seniors
# relevance01_prompt1_option01                                                                          These findings may be particularly relevant for athletes who are looking to maintain a healthy weight and diet. Understanding the biobehavioral processes underlying HP food motivation and intake can help athletes make informed decisions about their food choices and avoid stress-induced eating.
# relevance01_prompt1_option02                                                                          These findings may be particularly relevant for athletes who are looking to maintain a healthy weight and diet. Understanding the biobehavioral processes underlying HP food motivation and intake can help athletes make informed decisions about their food choices and avoid stress-induced eating.
# relevance02_prompt1_option01                                                                                                                      This study could be relevant for athletes who are trying to maintain a healthy weight and diet. Understanding the impact of stress and food cues on food cravings and intake can help athletes make informed decisions about their nutrition and training.
# relevance02_prompt1_option02                                                                                                                      This study could be relevant for athletes who are trying to maintain a healthy weight and diet. Understanding the impact of stress and food cues on food cravings and intake can help athletes make informed decisions about their nutrition and training.
# relevance_task01                                                                                                                                                                                                                                                                                                                        Add 1-2 sentences to make this relevant for people who enjoy sports

# %%
qna_dict[summary_iteration_id].index
# Out:
# Index(['article_title', 'system_role', 'prompt', 'model', 'response_01',
#        'response_02', 'text', 'prep_step', 'task part 1', 'prompt'],
#       dtype='object')

# %% [markdown]
# ## repeat with correct summary_iteration_id

# %%
# summary_iteration_id = iteration_id
summary_iteration_id = 4.1
n_choices = 2
relevance_prompts = relevance_prompts_df
pause_per_request=20
qna_dict = prompt_chaining_dict(relevance_prompts, qna_dict, chaining_dict[summary_iteration_id], iteration_id,
    prompt_column='relevance', n_choices=n_choices, pause_per_request=pause_per_request,
    simplify_iteration=1, summary_iteration_id=summary_iteration_id
    )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\silvh\OneDrive\lighthouse\Ginkgo coding\content-summarization\notebooks\2023-04-13 prompt chaining with user relevance added - part 2.ipynb Cell 67 in 6
#       <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/Ginkgo%20coding/content-summarization/notebooks/2023-04-13%20prompt%20chaining%20with%20user%20relevance%20added%20-%20part%202.ipynb#Y135sZmlsZQ%3D%3D?line=3'>4</a> relevance_prompts = relevance_prompts_df
#       <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/Ginkgo%20coding/content-summarization/notebooks/2023-04-13%20prompt%20chaining%20with%20user%20relevance%20added%20-%20part%202.ipynb#Y135sZmlsZQ%3D%3D?line=4'>5</a> pause_per_request=20
# ----> <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/Ginkgo%20coding/content-summarization/notebooks/2023-04-13%20prompt%20chaining%20with%20user%20relevance%20added%20-%20part%202.ipynb#Y135sZmlsZQ%3D%3D?line=5'>6</a> qna_dict = prompt_chaining_dict(relevance_prompts, qna_dict, chaining_dict[summary_iteration_id], iteration_id,
#       <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/Ginkgo%20coding/content-summarization/notebooks/2023-04-13%20prompt%20chaining%20with%20user%20relevance%20added%20-%20part%202.ipynb#Y135sZmlsZQ%3D%3D?line=6'>7</a>     prompt_column='relevance', n_choices=n_choices, pause_per_request=pause_per_request,
#       <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/Ginkgo%20coding/content-summarization/notebooks/2023-04-13%20prompt%20chaining%20with%20user%20relevance%20added%20-%20part%202.ipynb#Y135sZmlsZQ%3D%3D?line=7'>8</a>     simplify_iteration=1, summary_iteration_id=summary_iteration_id
#       <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/Ginkgo%20coding/content-summarization/notebooks/2023-04-13%20prompt%20chaining%20with%20user%20relevance%20added%20-%20part%202.ipynb#Y135sZmlsZQ%3D%3D?line=8'>9</a>     )
#
# KeyError: 4.1

# %% [markdown]
# # Iteration 5 Make it save outputs

# %%
import traceback
import time
# from collections import OrderedDict

class Chaining:

    def __init__(self, text):
        self.text = text

    def summarize(self, task, model="gpt-3.5-turbo", temperature=0.7, n_choices=5, max_tokens=1000,
          text_key=['text_discussion'],
        system_role = "You are an expert at science communication."
        ):
        """
        SH 2023-04-11 12:18: Same as the user-defined `reply` function, but re-written as a class method.
        Send a ChatCompletion request to ChatGPT via the Chatbot class.

        Requrired paramaters:
            - task (str): Task to include in ChatGPT prompt.
            - text (str): Text to feed to GPT for summarization.

        Optional parameters
            - system_role (str): ChatGPT parameter. 
                Default is "You are an expert at science communication."
            - temperature (float): ChatGPT parameter. Default is 0.7.
            - n_choices (int): Number of ChatGPT responses to generate. Default is 5.
            - max_tokens (int): Token limit for ChatGPT response.
            - model (str): ChatGPT model to use. Default is "gpt-3.5-turbo".
        """
        chatbot = Chatbot(self.text,
            system_role=system_role, model=model, temperature=temperature, n_choices=n_choices,
            max_tokens=max_tokens
            )
        prompt = chatbot.create_prompt(task)
        firstline_pattern = r'\s?(\S*)(\n*)(.+)'
        title = re.match(firstline_pattern, self.text)[0]
        self.qna = dict() 
        self.qna['article_title'] = title
        self.qna['system_role'] = system_role
        self.qna['prompt'] = task
        self.qna['model'] = model
        self.summaries_dict = dict()
        self.article_title = title
        self.response_regex = r'response_(.*)'

        try:
            response = chatbot.gpt(prompt)
        except:
            print('\t**API request failed**')
            return self.qna
        try:
            for index, choice in enumerate(response.choices):
                self.qna[f'response_{"{:02d}".format(index+1)}'] = choice["message"]["content"]
                self.summaries_dict[f'response_{"{:02d}".format(index+1)}'] = choice["message"]["content"]
            self.qna[f'text'] = self.text
            return self.qna
        except:
            print('\t**Error with response parsing**')
            return self.qna


    def simplify(self, simplify_task, system_role='You are an expert at science communication.',
                    model="gpt-3.5-turbo", temperature=0.0, n_choices=1, max_tokens=1000, 
                    simplify_iteration=None, pause_per_request=20
                    ):
        self.simplify_bot_dict = dict()
        self.simple_summary_dict = dict()
        for key, summary in self.summaries_dict.items():
            new_key = re.sub(self.response_regex, rf'simple_summary\1_prompt{str(simplify_iteration)}', key)
            print(f'\t\t...Preparing to summarize {key}')
            self.simplify_bot_dict[new_key] = Chatbot(
                summary, system_role=system_role,
                model=model, temperature=temperature, n_choices=n_choices, max_tokens=max_tokens
                )
            simplify_prompt = self.simplify_bot_dict[new_key].create_prompt(simplify_task)
            try:
                for index, choice in enumerate(self.simplify_bot_dict[new_key].gpt(simplify_prompt).choices):
                    self.simple_summary_dict[f'{new_key}_option{"{:02d}".format(index+1)}'] = choice["message"]["content"]
                    print(f'\t...Summary given')
            except:
                self.simple_summary_dict[new_key] = self.simplify_bot_dict[new_key].gpt(simplify_prompt)
                print(f'\t...Error parsing response for summary request')
            print(f'[.simplify()] Sleeping {pause_per_request} sec to avoid exceeding API rate limit')
            time.sleep(pause_per_request) # Account for API rate limit of 3 API requests/limit 
        self.simple_summary_dict['simplify_task'] = simplify_task
        self.qna = {**self.qna, **self.simple_summary_dict}
        try:
            self.qna.update({'text': self.qna.pop('text')})
        except:
            pass
        return self.simple_summary_dict
    
    def add_relevance(self, task, system_role='You are an expert at science communication.',
                    model="gpt-3.5-turbo", temperature=0.0, n_choices=1, max_tokens=1000, 
                    relevance_iteration=None, pause_per_request=20
                    ):
        self.relevance_bot_dict = dict()
        self.relevance_dict = dict()
        if relevance_iteration == None:
            relevance_iteration = 1
        for key, summary in self.summaries_dict.items():
            new_key = re.sub(self.response_regex, rf'relevance\1_prompt{str(relevance_iteration)}', key)
            print(f'\t\t...Preparing to summarize {key}')
            self.relevance_bot_dict[new_key] = Chatbot(
                summary, system_role=system_role,
                model=model, temperature=temperature, n_choices=n_choices, max_tokens=max_tokens
                )
            relevance_prompt = self.relevance_bot_dict[new_key].create_prompt(task)
            try:
                for index, choice in enumerate(self.relevance_bot_dict[new_key].gpt(relevance_prompt).choices):
                    self.relevance_dict[f'{new_key}_option{"{:02d}".format(index+1)}'] = choice["message"]["content"]
                    print(f'\t...Relevance given')
            except:
                try:
                    self.relevance_dict[new_key] = self.relevance_bot_dict[new_key].gpt(relevance_prompt).choices[0]["message"]["content"]
                    print(f'\t...First relevance response given')
                except:
                    self.relevance_dict[new_key] = self.relevance_bot_dict[new_key].gpt(relevance_prompt)
                    print(f'\t...Error parsing response for added relevance request')
            print(f'[.add_relevance()] Sleeping {pause_per_request} sec to avoid exceeding API rate limit')
            time.sleep(pause_per_request) # Account for API rate limit of 3 API requests/limit 
        self.relevance_dict[f'relevance_task{"{:02d}".format(relevance_iteration)}'] = task
        self.qna = {**self.qna, **self.relevance_dict}
        try:
            self.qna.update({'text': self.qna.pop('text')})
        except:
            pass
        return self.relevance_dict

def batch_summarize_chain(text_dict, prompts_df, qna_dict,  chaining_bot_dict, iteration_id, n_choices=5,
    prompt_column='prompt',
    save_outputs=False, filename=None, append_version=False,
    csv_path=r'C:\Users\silvh\OneDrive\lighthouse\Ginkgo coding\content-summarization\output',
    pickle_path=r'C:\Users\silvh\OneDrive\lighthouse\Ginkgo coding\content-summarization\output\pickles'
    ):
    """
    Summarize multiple texts using the same prompts.
    Parameters:
        - prompts_df: DataFrame containing the prompts.
        - qna_dict: Dictionary to store the input and outputs.
        - iteration_id (int, float, or string): Unique ID serving as the key for results in the qna_dict
        - prompt_column (str): Name of the column in the prompts_df containing the user input.

    """
    temp_qna_dict = dict()
    prompts_df = prompts_df.reset_index(drop=True)
    qna_dfs_list = []
    chaining_bot_dict[iteration_id] = dict()
    for key in text_dict:
        text = text_dict[key]
        temp_qna_dict[key] = dict()
        for index, input in prompts_df[prompt_column].items():
            print(f'**Text #{key} prompt #{index} of {prompts_df.index.max()}**')
            try:
                chatbot = Chaining(text)
                temp_qna_dict[key][index] = chatbot.summarize(input, n_choices=n_choices)
                chatbot_dict[iteration_id][f'text{key}_prompt{"{:02d}".format(index)}'] = chatbot
                print('\t...Success!')
            except:
                print('\t...Error making chatbot request')
                break
        try:
            prompts_df = prompts_df.drop(prompt_column)
        except:
            pass
        try:
            updated_qna_dict = pd.concat([
                pd.DataFrame(temp_qna_dict[key]),
                prompts_df.transpose()
            ])
        except Exception as error:
            exc_type, exc_obj, tb = sys.exc_info()
            f = tb.tb_frame
            lineno = tb.tb_lineno
            filename = f.f_code.co_filename
            print("An error occurred on line", lineno, "in", filename, ":", error)
            print('Error concatenating prompts DataFrame')
            return temp_qna_dict, chatbot_dict
        try:
            qna_dfs_list.append(updated_qna_dict)
            qna_dict[iteration_id] = pd.concat(qna_dfs_list, axis=1)
            if save_outputs:
                try:
                    append_version = append_version if filename else False
                    filename = filename if filename else f'{datetime.now().strftime("%Y-%m-%d_%H%M")}_prompt_experiments_{"{:02d}".format(iteration_id)}'
                    savepickle(qna_dict[iteration_id], filename=filename, path=pickle_path, append_version=append_version)
                    save_csv(qna_dict[iteration_id], filename=filename, path=pickle_path, append_version=append_version)
                except:
                    print('Unable to save outputs')
        except:
            print('Error concatenating DataFrames')
    return qna_dict, chatbot_dict

def prompt_chaining_dict(simplify_prompts, qna_chain_dict, chaining_bot_dict, iteration_id,
    summary_iteration_id=None, n_choices=None, pause_per_request=20,
    prompt_column='simplify', simplify_iteration=None, save_outputs=False,
    csv_path=r'C:\Users\silvh\OneDrive\lighthouse\Ginkgo coding\content-summarization\output',
    pickle_path=r'C:\Users\silvh\OneDrive\lighthouse\Ginkgo coding\content-summarization\output\pickles'
    ):
    """
    Simplify or add context to a summary.
    """
    summary_iteration_id = summary_iteration_id if summary_iteration_id else iteration_id
    print('summary_iteration_id:', summary_iteration_id)
    if n_choices == None:
        n_choices = 1 if prompt_column == 'simplify' else 5
    print('n_choices:', n_choices)
    if type(simplify_prompts) == str:
        simplify_prompts = [simplify_prompts]
    elif type(simplify_prompts) == pd.core.frame.DataFrame:
        simplify_prompts = [prompt for prompt in simplify_prompts[prompt_column].unique() if len(prompt) >1]
    else:
        simplify_prompts = list(set([prompt for prompt in simplify_prompts if len(prompt) >1]))
    simple_summaries_master_dict = dict()
    simple_summaries_df = pd.DataFrame()
    for column, text_prompt_key in enumerate(chaining_bot_dict):
        print(f'**{text_prompt_key}')
        simple_summaries_master_dict[text_prompt_key] = dict()

        for index, prompt in enumerate(simplify_prompts):
            relevance_iteration=index if len(simplify_prompts) > 1 else simplify_iteration
            print(f'\t...Prompt: {prompt}, iteration {relevance_iteration}')
            if prompt_column == 'simplify':
                summary_dict = chaining_bot_dict[text_prompt_key].simplify(
                    prompt, n_choices=n_choices, pause_per_request=pause_per_request, 
                    simplify_iteration=index if len(simplify_prompts) > 1 else simplify_iteration
                    )
            else: 
                summary_dict = chaining_bot_dict[text_prompt_key].add_relevance(
                    prompt, n_choices=n_choices, pause_per_request=pause_per_request, 
                    relevance_iteration=index if len(simplify_prompts) > 1 else simplify_iteration
                    )
            simple_summaries_master_dict[text_prompt_key] = {**simple_summaries_master_dict[text_prompt_key], **summary_dict}
        try:
            simple_summaries_df[column] = pd.DataFrame([
                pd.Series(value, name=key) for key, value in simple_summaries_master_dict[text_prompt_key].items()
            ])   
        except Exception as error:
            exc_type, exc_obj, tb = sys.exc_info()
            f = tb.tb_frame
            lineno = tb.tb_lineno
            filename = f.f_code.co_filename
            print("An error occurred on line", lineno, "in", filename, ":", error)
            print('Unable to create results DataFrame')
            
            qna_chain_dict[iteration_id+0.001] = simple_summaries_master_dict
    try:
        qna_chain_dict[summary_iteration_id].columns = [i for i in range(len(qna_chain_dict[summary_iteration_id].columns))]
        temp_qna_chain_dict = pd.concat([
            qna_chain_dict[summary_iteration_id], 
            simple_summaries_df
            ])
        qna_chain_dict[iteration_id] = temp_qna_chain_dict
        print(f"{'Simple summaries' if prompt_column=='simplify' else 'Article relevance for user'} added to original DataFrame")
        if save_outputs:
            try:
                save_output(
                    qna_chain_dict[iteration_id], description='prompt_chain_experiment',
                    csv_path=csv_path, pickle_path=pickle_path)
            except:
                print('[prompt_chaining_dict()] Unable to save outputs')
    except Exception as error:
        exc_type, exc_obj, tb = sys.exc_info()
        f = tb.tb_frame
        lineno = tb.tb_lineno
        filename = f.f_code.co_filename
        print("An error occurred on line", lineno, "in", filename, ":", error)
        print('Unable to concatenate simple summary DataFrame to original DataFrame')
        qna_chain_dict[iteration_id+0.001] = simple_summaries_master_dict

    return qna_chain_dict

iteration_id = 5
n_choices = 2
# qna_dict = dict()
# qna_chain_dict = dict()
# chatbot_dict = dict()

# qna_dict, chaining_dict = batch_summarize_chain(text_dict, prompts_df, qna_dict, chatbot_dict, 
#     iteration_id=iteration_id, n_choices=n_choices)


simplify_prompts = task_part2
summary_iteration_id = 4
# summary_iteration_id = iteration_id
qna_dict = prompt_chaining_dict(simplify_prompts, qna_dict, chaining_dict[summary_iteration_id], iteration_id,
    n_choices=n_choices, summary_iteration_id=summary_iteration_id, save_outputs=True
    )

# summary_iteration_id = iteration_id
# summary_iteration_id = 2
# n_choices = 2
# relevance_prompts = relevance_prompts_df
# pause_per_request=20
# qna_dict = prompt_chaining_dict(relevance_prompts, qna_dict, chaining_dict[summary_iteration_id], iteration_id,
#     prompt_column='relevance', n_choices=n_choices, pause_per_request=pause_per_request,
#     simplify_iteration=1, summary_iteration_id=summary_iteration_id
#     )
# Out:
# summary_iteration_id: 4
# n_choices: 2
# **text1_prompt00
# 	...Prompt: Use terms a 12-year-old can understand., iteration None
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Summary given
# 	...Summary given
# [.simplify()] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Summary given
# 	...Summary given
# [.simplify()] Sleeping 20 sec to avoid exceeding API rate limit
# **text1_prompt01
# 	...Prompt: Use terms a 12-year-old can understand., iteration None
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Summary given
# 	...Summary given
# [.simplify()] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Summary given
# 	...Summary given
# [.simplify()] Sleeping 20 sec to avoid exceeding API rate limit
# **text2_prompt00
# 	...Prompt: Use terms a 12-year-old can understand., iteration None
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Summary given
# 	...Summary given
# [.simplify()] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Summary given
# 	...Summary given
# [.simplify()] Sleeping 20 sec to avoid exceeding API rate limit
# **text2_prompt01
# 	...Prompt: Use terms a 12-year-old can understand., iteration None
# 		...Preparing to summarize response_01
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Summary given
# 	...Summary given
# [.simplify()] Sleeping 20 sec to avoid exceeding API rate limit
# 		...Preparing to summarize response_02
# 	Done creating prompt
# 	Sending request to GPT-3
# 		Requesting 2 choices using gpt-3.5-turbo
# 	Done sending request to GPT-3
# 	...Summary given
# 	...Summary given
# [.simplify()] Sleeping 20 sec to avoid exceeding API rate limit
# Simple summaries added to original DataFrame
# File saved:  C:/Users/silvh/OneDrive/lighthouse/Ginkgo coding/content-summarization/output/pickles/prompt_chain_experiment_2023-04-13_2319.sav
# Time completed: 2023-04-13 23:19:01.369972
# 	Object saved as pickle
# File saved:  C:/Users/silvh/OneDrive/lighthouse/Ginkgo coding/content-summarization/output/prompt_chain_experiment_2023-04-13_2319.csv
# Time completed: 2023-04-13 23:19:01.518516
# 	DataFrame saved as CSV

# %%
qna_dict[iteration_id].tail()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 0  \
# simple_summary01_promptNone_option01                                             A new study looked at how sleep affects athletes. They found that getting more sleep can help athletes perform better or not affect their performance at all. Doing exercises that use a lot of oxygen, like running, is more affected by sleep than exercises that don't, like weightlifting. Sleeping also helps athletes with their thinking and technical skills. If athletes get more sleep over a long time, it can help them do better. But if they don't get enough sleep for a short time, it can hurt their performance. The study says we need to look more into how not getting enough sleep for a long time can hurt athletes. So, if you're an athlete, getting more sleep can help you do better!
# simple_summary01_promptNone_option02                                             A new study looked at how sleep affects athletes. They found that getting more sleep can help athletes perform better or not affect their performance at all. Doing exercises that use a lot of oxygen, like running, is more affected by sleep than exercises that don't, like weightlifting. Sleeping also helps athletes with their thinking and technical skills. If athletes get more sleep over a long time, it can help them do better. But if they don't get enough sleep for a short time, it can hurt their performance. The study says we need to look more into how not getting enough sleep for a long time can hurt athletes. So, if you're an athlete, getting more sleep can help you do better!
# simple_summary02_promptNone_option01  A study looked at how sleep affects how well athletes perform. They found that getting more sleep can help athletes do better, especially when doing activities that need a lot of oxygen. They also found that getting enough sleep can help with skills that need a lot of thinking and planning. Studies that looked at athletes who got more sleep for a longer time also showed good results. Not getting enough sleep can be worse for performance than getting more sleep is good. We need more research to know for sure how sleep affects how well athletes think they did and how well they actually did. It's a good idea for athletes to try to get enough sleep not just the night before a big event, but also in the weeks leading up to it.
# simple_summary02_promptNone_option02  A study looked at how sleep affects how well athletes perform. They found that getting more sleep can help athletes do better, especially when doing activities that need a lot of oxygen. They also found that getting enough sleep can help with skills that need a lot of thinking and planning. Studies that looked at athletes who got more sleep for a longer time also showed good results. Not getting enough sleep can be worse for performance than getting more sleep is good. We need more research to know for sure how sleep affects how well athletes think they did and how well they actually did. It's a good idea for athletes to try to get enough sleep not just the night before a big event, but also in the weeks leading up to it.
# simplify_task                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Use terms a 12-year-old can understand.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    1  \
# simple_summary01_promptNone_option01  Hey there! Did you know that getting enough sleep is really important for athletes? A bunch of studies looked at how sleep affects how well athletes perform, and they found some cool stuff. None of the studies showed that getting more sleep made athletes do worse. Actually, all the studies showed that getting more sleep either helped athletes perform better or didn't make a difference. Doing exercises that make you breathe hard (like running) is more affected by sleep than exercises that don't (like lifting weights). Studies that looked at how sleep affects athletes over a long time showed more of an effect than studies that only looked at one night of sleep. Getting more sleep over a long time can really help athletes do better. Scientists still need to do more research to figure out exactly how sleep affects different parts of athletic performance.
# simple_summary01_promptNone_option02  Hey there! Did you know that getting enough sleep is really important for athletes? A bunch of studies looked at how sleep affects how well athletes perform, and they found some cool stuff. None of the studies showed that getting more sleep made athletes do worse. Actually, all the studies showed that getting more sleep either helped athletes perform better or didn't make a difference. Doing exercises that make you breathe hard (like running) is more affected by sleep than exercises that don't (like lifting weights). Studies that looked at how sleep affects athletes over a long time showed more of an effect than studies that only looked at one night of sleep. Getting more sleep over a long time can really help athletes do better. Scientists still need to do more research to figure out exactly how sleep affects different parts of athletic performance.
# simple_summary02_promptNone_option01                                                                                                                            Did you know that getting enough sleep is really important for athletes? A study looked at lots of other studies and found that getting more sleep can actually help athletes perform better or at least doesn't hurt their performance. It seems like activities that require a lot of running or moving around are more affected by sleep than activities that don't. And if athletes need to use their brains a lot, like for strategy or technique, getting enough sleep is especially important. The study also found that getting more sleep over a longer period of time is better than just getting more sleep for one night. So, it's really important for athletes to make sure they get enough sleep, especially if they want to do well in the long run.
# simple_summary02_promptNone_option02                                                                                                                            Did you know that getting enough sleep is really important for athletes? A study looked at lots of other studies and found that getting more sleep can actually help athletes perform better or at least doesn't hurt their performance. It seems like activities that require a lot of running or moving around are more affected by sleep than activities that don't. And if athletes need to use their brains a lot, like for strategy or technique, getting enough sleep is especially important. The study also found that getting more sleep over a longer period of time is better than just getting more sleep for one night. So, it's really important for athletes to make sure they get enough sleep, especially if they want to do well in the long run.
# simplify_task                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Use terms a 12-year-old can understand.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            2  \
# simple_summary01_promptNone_option01  Scientists did an experiment with people to see how food and stress affect our desire to eat yummy but unhealthy foods. They found that when people were exposed to pictures of delicious food and felt stressed, they wanted to eat more of those foods. Two hormones in our bodies, called ghrelin and cortisol, also played a big role in making us want to eat. The scientists think we need to study more about how our bodies and brains work together to make us crave and eat unhealthy foods, especially if we want to understand why some people struggle with their weight.
# simple_summary01_promptNone_option02  Scientists did an experiment with people to see how food and stress affect our desire to eat yummy but unhealthy foods. They found that when people were exposed to pictures of delicious food and felt stressed, they wanted to eat more of those foods. Two hormones in our bodies, called ghrelin and cortisol, also played a big role in making us want to eat. The scientists think we need to study more about how our bodies and brains work together to make us crave and eat unhealthy foods, especially if we want to understand why some people struggle with their weight.
# simple_summary02_promptNone_option01                                                                                                    A new study found that when people see or think about yummy food and feel stressed, they want to eat more of that kind of food. This is especially true for people who are overweight. The study also found that two hormones in our body, ghrelin and cortisol, can make us want to eat more. This means we need to learn more about how our body and mind work together when we want to eat unhealthy food, especially if we want to understand why some people become overweight.
# simple_summary02_promptNone_option02                                                                                                    A new study found that when people see or think about yummy food and feel stressed, they want to eat more of that kind of food. This is especially true for people who are overweight. The study also found that two hormones in our body, ghrelin and cortisol, can make us want to eat more. This means we need to learn more about how our body and mind work together when we want to eat unhealthy food, especially if we want to understand why some people become overweight.
# simplify_task                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Use terms a 12-year-old can understand.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        3
# simple_summary01_promptNone_option01                                                                    Did you know that when we see or think about yummy food and feel stressed, we tend to eat more of that yummy food? This study found that people who were shown pictures of yummy food and felt stressed ate more of that food than people who were in a calm and relaxing environment. The study also found that people who were overweight were more likely to eat more of that yummy food when they were stressed. The study also looked at two hormones, ghrelin and cortisol, which can affect how much we want to eat. The study suggests that we need to learn more about how our bodies and minds work together when it comes to eating yummy food, especially for people who struggle with their weight.
# simple_summary01_promptNone_option02                                                                    Did you know that when we see or think about yummy food and feel stressed, we tend to eat more of that yummy food? This study found that people who were shown pictures of yummy food and felt stressed ate more of that food than people who were in a calm and relaxing environment. The study also found that people who were overweight were more likely to eat more of that yummy food when they were stressed. The study also looked at two hormones, ghrelin and cortisol, which can affect how much we want to eat. The study suggests that we need to learn more about how our bodies and minds work together when it comes to eating yummy food, especially for people who struggle with their weight.
# simple_summary02_promptNone_option01  Hey! I just read about a study that looked at how seeing pictures of yummy food and feeling stressed affects how much people want to eat and actually eat. They found that both things make people want to eat more of the yummy food, but it affects people who are overweight and people who are not overweight differently. Two hormones in our body, ghrelin and cortisol, also affect how much we want to eat, but they work differently in people who are overweight and people who are not overweight. People who are overweight might not feel as stressed when they see pictures of yummy food, which could make them want to eat more of it. This study shows that we need to learn more about how our body and mind work together to make us want to eat certain foods.
# simple_summary02_promptNone_option02  Hey! I just read about a study that looked at how seeing pictures of yummy food and feeling stressed affects how much people want to eat and actually eat. They found that both things make people want to eat more of the yummy food, but it affects people who are overweight and people who are not overweight differently. Two hormones in our body, ghrelin and cortisol, also affect how much we want to eat, but they work differently in people who are overweight and people who are not overweight. People who are overweight might not feel as stressed when they see pictures of yummy food, which could make them want to eat more of it. This study shows that we need to learn more about how our body and mind work together to make us want to eat certain foods.
# simplify_task                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Use terms a 12-year-old can understand.

# %% [markdown]
# # *End of Page*
